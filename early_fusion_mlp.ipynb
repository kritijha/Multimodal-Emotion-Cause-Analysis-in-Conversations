# %%
#MLP on Complete Dataset

# %%
import os
import json
import pandas as pd

def read_json_file(file_path):
    """Reads a JSON file and returns the data."""
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            data = json.load(file)
        print(f"Successfully loaded data from {file_path}")
        return data
    except Exception as e:
        print(f"Failed to load data from {file_path}: {e}")
        return None

def extract_data_to_dataframe(data):
    """Extracts video name and emotion from the JSON data structure and returns a DataFrame."""
    video_names = []
    emotions = []
    
    if not data:
        print("No data provided to extract.")
        return pd.DataFrame()
    
    try:
        for conversation in data:
            for utterance in conversation['conversation']:
                video_name = utterance['video_name']
                emotion = utterance['emotion']
                video_names.append(video_name)
                emotions.append(emotion)
        df = pd.DataFrame({
            'video_name': video_names,
            'emotion': emotions
        })
        print("Data extraction successful.")
        return df
    except Exception as e:
        print(f"Error during data extraction: {e}")
        return pd.DataFrame()

def save_to_csv(df, file_name, directory):
    """Saves the DataFrame to a CSV file in the specified directory."""
    # Ensure the directory exists, create if it does not
    if not os.path.exists(directory):
        os.makedirs(directory)
    full_path = os.path.join(directory, file_name)
    
    try:
        df.to_csv(full_path, index=False)
        print(f"Data successfully saved to {full_path}")
    except Exception as e:
        print(f"Failed to save data to {full_path}: {e}")

def main():
    # Define paths
    train_file_path = '/project/msoleyma_1026/ecp-cause-pair/json_files/train.json'  # Update with the actual path
    test_file_path = '/project/msoleyma_1026/ecp-cause-pair/json_files/test.json'    # Update with the actual path
    save_directory = '/project/msoleyma_1026/ecp-cause-pair/script_mlp/assets'    # Define the directory to save CSV files
    
    # Load JSON data
    train_data = read_json_file(train_file_path)
    test_data = read_json_file(test_file_path)
    
    # Extract data and create DataFrames
    train_df = extract_data_to_dataframe(train_data)
    test_df = extract_data_to_dataframe(test_data)
    
    # Combine train and test datasets
    combined_df = pd.concat([train_df, test_df], ignore_index=True)
    
    # Save to CSV files in the specified directory
    save_to_csv(train_df, 'train.csv', save_directory)
    save_to_csv(test_df, 'test.csv', save_directory)
    save_to_csv(combined_df, 'video_emotion_combined.csv', save_directory)

if __name__ == "__main__":
    main()
# Out:
# Successfully loaded data from /project/msoleyma_1026/ecp-cause-pair/json_files/train.json
# Successfully loaded data from /project/msoleyma_1026/ecp-cause-pair/json_files/test.json
# Data extraction successful.
# Data extraction successful.
# Data successfully saved to /project/msoleyma_1026/ecp-cause-pair/script_mlp/assets/train.csv
# Data successfully saved to /project/msoleyma_1026/ecp-cause-pair/script_mlp/assets/test.csv
# Data successfully saved to /project/msoleyma_1026/ecp-cause-pair/script_mlp/assets/video_emotion_combined.csv

# %%
#loading concated train and test dataset from "split" folder
import os
import numpy as np

# train and test directories
train_dir = '/project/msoleyma_1026/ecp-cause-pair/concatenated_embedding/train_emotion'
test_dir = '/project/msoleyma_1026/ecp-cause-pair/concatenated_embedding/test_emotion'

# Function to load all .npy files from a directory
def load_embeddings(directory):
    embeddings = []
    for filename in os.listdir(directory):
        if filename.endswith('.npy'):
            file_path = os.path.join(directory, filename)
            embedding = np.load(file_path)
            embeddings.append(embedding)
            print(f'Loaded {filename}')
    return embeddings

# Load the embeddings
train_embeddings = load_embeddings(train_dir)
test_embeddings = load_embeddings(test_dir)

# Print the number of loaded embeddings
print(f'Loaded {len(train_embeddings)} train embeddings')
print(f'Loaded {len(test_embeddings)} test embeddings')
# Out:
# Loaded dia116utt4_concatenated.npy
# Loaded dia61utt2_concatenated.npy
# Loaded dia644utt8_concatenated.npy
# Loaded dia21utt8_concatenated.npy
# Loaded dia983utt2_concatenated.npy
# Loaded dia607utt15_concatenated.npy
# Loaded dia860utt4_concatenated.npy
# Loaded dia690utt4_concatenated.npy
# Loaded dia530utt12_concatenated.npy
# Loaded dia917utt4_concatenated.npy
# Loaded dia182utt2_concatenated.npy
# Loaded dia409utt11_concatenated.npy
# Loaded dia773utt2_concatenated.npy
# Loaded dia1279utt5_concatenated.npy
# Loaded dia1031utt12_concatenated.npy
# Loaded dia38utt6_concatenated.npy
# Loaded dia1097utt5_concatenated.npy
# Loaded dia1108utt11_concatenated.npy
# Loaded dia1134utt9_concatenated.npy
# Loaded dia1203utt12_concatenated.npy
# Loaded dia1003utt3_concatenated.npy
# Loaded dia168utt16_concatenated.npy
# Loaded dia509utt4_concatenated.npy
# Loaded dia1220utt1_concatenated.npy
# Loaded dia389utt12_concatenated.npy
# Loaded dia149utt3_concatenated.npy
# Loaded dia1091utt6_concatenated.npy
# Loaded dia1351utt2_concatenated.npy
# Loaded dia478utt7_concatenated.npy
# Loaded dia948utt3_concatenated.npy
# Loaded dia1049utt11_concatenated.npy
# Loaded dia227utt12_concatenated.npy
# Loaded dia1226utt2_concatenated.npy
# Loaded dia1170utt12_concatenated.npy
# Loaded dia1088utt8_concatenated.npy
# Loaded dia985utt1_concatenated.npy
# Loaded dia602utt1_concatenated.npy
# Loaded dia1308utt6_concatenated.npy
# Loaded dia471utt12_concatenated.npy
# Loaded dia795utt11_concatenated.npy
# Loaded dia911utt7_concatenated.npy
# Loaded dia556utt3_concatenated.npy
# Loaded dia244utt5_concatenated.npy
# Loaded dia184utt1_concatenated.npy
# Loaded dia775utt1_concatenated.npy
# Loaded dia597utt7_concatenated.npy
# Loaded dia617utt9_concatenated.npy
# Loaded dia72utt9_concatenated.npy
# Loaded dia32utt3_concatenated.npy
# Loaded dia285utt1_concatenated.npy
# Loaded dia618utt18_concatenated.npy
# Loaded dia474utt1_concatenated.npy
# Loaded dia503utt1_concatenated.npy
# Loaded dia1009utt6_concatenated.npy
# Loaded dia928utt18_concatenated.npy
# Loaded dia453utt20_concatenated.npy
# Loaded dia989utt7_concatenated.npy
# Loaded dia1167utt8_concatenated.npy
# Loaded dia1127utt2_concatenated.npy
# Loaded dia1016utt11_concatenated.npy
# Loaded dia248utt3_concatenated.npy
# Loaded dia1319utt18_concatenated.npy
# Loaded dia1050utt2_concatenated.npy
# Loaded dia1224utt11_concatenated.npy
# Loaded dia1302utt3_concatenated.npy
# Loaded dia608utt4_concatenated.npy
# Loaded dia1081utt12_concatenated.npy
# Loaded dia1121utt1_concatenated.npy
# Loaded dia1260utt16_concatenated.npy
# Loaded dia1056utt1_concatenated.npy
# Loaded dia339utt12_concatenated.npy
# Loaded dia1275utt3_concatenated.npy
# Loaded dia305utt16_concatenated.npy
# Loaded dia456utt11_concatenated.npy
# Loaded dia283utt2_concatenated.npy
# Loaded dia472utt2_concatenated.npy
# Loaded dia432utt8_concatenated.npy
# Loaded dia1178utt5_concatenated.npy
# Loaded dia360utt4_concatenated.npy
# Loaded dia505utt2_concatenated.npy
# Loaded dia93utt13_concatenated.npy
# Loaded dia741utt6_concatenated.npy
# Loaded dia945utt17_concatenated.npy
# Loaded dia979utt13_concatenated.npy
# Loaded dia393utt4_concatenated.npy
# Loaded dia562utt4_concatenated.npy
# Loaded dia1068utt3_concatenated.npy
# Loaded dia270utt2_concatenated.npy
# Loaded dia307utt2_concatenated.npy
# Loaded dia347utt8_concatenated.npy
# Loaded dia82utt15_concatenated.npy
# Loaded dia53utt6_concatenated.npy
# Loaded dia1212utt5_concatenated.npy
# Loaded dia1090utt14_concatenated.npy
# Loaded dia8utt7_concatenated.npy
# Loaded dia1031utt7_concatenated.npy
# Loaded dia229utt6_concatenated.npy
# Loaded dia1271utt10_concatenated.npy
# Loaded dia1146utt7_concatenated.npy
# Loaded dia899utt1_concatenated.npy
# Loaded dia1214utt6_concatenated.npy
# Loaded dia1102utt10_concatenated.npy
# Loaded dia255utt10_concatenated.npy
# Loaded dia98utt7_concatenated.npy
# Loaded dia1037utt4_concatenated.npy
# Loaded dia1140utt4_concatenated.npy
# Loaded dia1330utt10_concatenated.npy
# Loaded dia1363utt6_concatenated.npy
# Loaded dia669utt1_concatenated.npy
# Loaded dia487utt1_concatenated.npy
# Loaded dia747utt5_concatenated.npy
# Loaded dia81utt9_concatenated.npy
# Loaded dia564utt7_concatenated.npy
# Loaded dia963utt9_concatenated.npy
# Loaded dia923utt3_concatenated.npy
# Loaded dia708utt13_concatenated.npy
# Loaded dia301utt1_concatenated.npy
# Loaded dia413utt7_concatenated.npy
# Loaded dia814utt9_concatenated.npy
# Loaded dia403utt10_concatenated.npy
# Loaded dia15utt16_concatenated.npy
# Loaded dia162utt9_concatenated.npy
# Loaded dia55utt5_concatenated.npy
# Loaded dia863utt19_concatenated.npy
# Loaded dia2utt2_concatenated.npy
# Loaded dia895utt7_concatenated.npy
# Loaded dia712utt7_concatenated.npy
# Loaded dia76utt12_concatenated.npy
# Loaded dia263utt9_concatenated.npy
# Loaded dia223utt3_concatenated.npy
# Loaded dia94utt1_concatenated.npy
# Loaded dia976utt1_concatenated.npy
# Loaded dia446utt5_concatenated.npy
# Loaded dia757utt13_concatenated.npy
# Loaded dia786utt1_concatenated.npy
# Loaded dia354utt3_concatenated.npy
# Loaded dia99utt12_concatenated.npy
# Loaded dia652utt14_concatenated.npy
# Loaded dia177utt1_concatenated.npy
# Loaded dia399utt1_concatenated.npy
# Loaded dia1241utt4_concatenated.npy
# Loaded dia1062utt6_concatenated.npy
# Loaded dia568utt1_concatenated.npy
# Loaded dia1115utt6_concatenated.npy
# Loaded dia236utt14_concatenated.npy
# Loaded dia59utt3_concatenated.npy
# Loaded dia1336utt4_concatenated.npy
# Loaded dia19utt9_concatenated.npy
# Loaded dia1247utt7_concatenated.npy
# Loaded dia1121utt19_concatenated.npy
# Loaded dia272utt13_concatenated.npy
# Loaded dia929utt6_concatenated.npy
# Loaded dia459utt8_concatenated.npy
# Loaded dia1113utt5_concatenated.npy
# Loaded dia419utt2_concatenated.npy
# Loaded dia1330utt7_concatenated.npy
# Loaded dia398utt14_concatenated.npy
# Loaded dia128utt6_concatenated.npy
# Loaded dia714utt4_concatenated.npy
# Loaded dia4utt1_concatenated.npy
# Loaded dia893utt4_concatenated.npy
# Loaded dia970utt2_concatenated.npy
# Loaded dia930utt8_concatenated.npy
# Loaded dia537utt6_concatenated.npy
# Loaded dia92utt2_concatenated.npy
# Loaded dia780utt2_concatenated.npy
# Loaded dia521utt14_concatenated.npy
# Loaded dia847utt8_concatenated.npy
# Loaded dia440utt6_concatenated.npy
# Loaded dia663utt4_concatenated.npy
# Loaded dia926utt13_concatenated.npy
# Loaded dia1369utt3_concatenated.npy
# Loaded dia171utt2_concatenated.npy
# Loaded dia131utt8_concatenated.npy
# Loaded dia1006utt12_concatenated.npy
# Loaded dia1027utt1_concatenated.npy
# Loaded dia1103utt15_concatenated.npy
# Loaded dia268utt11_concatenated.npy
# Loaded dia1204utt3_concatenated.npy
# Loaded dia1244utt9_concatenated.npy
# Loaded dia1230utt18_concatenated.npy
# Loaded dia1373utt3_concatenated.npy
# Loaded dia679utt4_concatenated.npy
# Loaded dia287utt11_concatenated.npy
# Loaded dia1290utt5_concatenated.npy
# Loaded dia382utt16_concatenated.npy
# Loaded dia266utt4_concatenated.npy
# Loaded dia709utt16_concatenated.npy
# Loaded dia735utt12_concatenated.npy
# Loaded dia574utt2_concatenated.npy
# Loaded dia385utt2_concatenated.npy
# Loaded dia497utt4_concatenated.npy
# Loaded dia839utt16_concatenated.npy
# Loaded dia132utt6_concatenated.npy
# Loaded dia14utt13_concatenated.npy
# Loaded dia403utt2_concatenated.npy
# Loaded dia1109utt5_concatenated.npy
# Loaded dia311utt4_concatenated.npy
# Loaded dia260utt7_concatenated.npy
# Loaded dia1078utt6_concatenated.npy
# Loaded dia935utt5_concatenated.npy
# Loaded dia383utt1_concatenated.npy
# Loaded dia446utt12_concatenated.npy
# Loaded dia491utt7_concatenated.npy
# Loaded dia711utt9_concatenated.npy
# Loaded dia751utt3_concatenated.npy
# Loaded dia666utt9_concatenated.npy
# Loaded dia626utt3_concatenated.npy
# Loaded dia771utt15_concatenated.npy
# Loaded dia997utt16_concatenated.npy
# Loaded dia83utt10_concatenated.npy
# Loaded dia405utt1_concatenated.npy
# Loaded dia842utt5_concatenated.npy
# Loaded dia317utt7_concatenated.npy
# Loaded dia127utt15_concatenated.npy
# Loaded dia1270utt15_concatenated.npy
# Loaded dia1021utt2_concatenated.npy
# Loaded dia708utt7_concatenated.npy
# Loaded dia329utt11_concatenated.npy
# Loaded dia1296utt6_concatenated.npy
# Loaded dia979utt9_concatenated.npy
# Loaded dia1197utt6_concatenated.npy
# Loaded dia1217utt8_concatenated.npy
# Loaded dia1257utt2_concatenated.npy
# Loaded dia232utt20_concatenated.npy
# Loaded dia376utt11_concatenated.npy
# Loaded dia138utt3_concatenated.npy
# Loaded dia1316utt16_concatenated.npy
# Loaded dia409utt7_concatenated.npy
# Loaded dia144utt11_concatenated.npy
# Loaded dia82utt7_concatenated.npy
# Loaded dia527utt3_concatenated.npy
# Loaded dia235utt5_concatenated.npy
# Loaded dia704utt1_concatenated.npy
# Loaded dia396utt9_concatenated.npy
# Loaded dia673utt1_concatenated.npy
# Loaded dia33utt10_concatenated.npy
# Loaded dia520utt11_concatenated.npy
# Loaded dia450utt3_concatenated.npy
# Loaded dia822utt11_concatenated.npy
# Loaded dia966utt4_concatenated.npy
# Loaded dia84utt4_concatenated.npy
# Loaded dia785utt12_concatenated.npy
# Loaded dia233utt6_concatenated.npy
# Loaded dia1208utt5_concatenated.npy
# Loaded dia167utt4_concatenated.npy
# Loaded dia675utt2_concatenated.npy
# Loaded dia10utt2_concatenated.npy
# Loaded dia344utt6_concatenated.npy
# Loaded dia796utt4_concatenated.npy
# Loaded dia811utt4_concatenated.npy
# Loaded dia1072utt3_concatenated.npy
# Loaded dia1032utt9_concatenated.npy
# Loaded dia1251utt1_concatenated.npy
# Loaded dia389utt4_concatenated.npy
# Loaded dia1326utt1_concatenated.npy
# Loaded dia1105utt3_concatenated.npy
# Loaded dia1145utt9_concatenated.npy
# Loaded dia1162utt5_concatenated.npy
# Loaded dia468utt2_concatenated.npy
# Loaded dia1081utt3_concatenated.npy
# Loaded dia1048utt14_concatenated.npy
# Loaded dia1015utt5_concatenated.npy
# Loaded dia323utt10_concatenated.npy
# Loaded dia876utt2_concatenated.npy
# Loaded dia77utt4_concatenated.npy
# Loaded dia612utt4_concatenated.npy
# Loaded dia995utt4_concatenated.npy
# Loaded dia100utt2_concatenated.npy
# Loaded dia877utt10_concatenated.npy
# Loaded dia140utt8_concatenated.npy
# Loaded dia575utt10_concatenated.npy
# Loaded dia549utt14_concatenated.npy
# Loaded dia765utt4_concatenated.npy
# Loaded dia194utt4_concatenated.npy
# Loaded dia747utt10_concatenated.npy
# Loaded dia686utt2_concatenated.npy
# Loaded dia546utt6_concatenated.npy
# Loaded dia941utt8_concatenated.npy
# Loaded dia870utt1_concatenated.npy
# Loaded dia437utt5_concatenated.npy
# Loaded dia606utt10_concatenated.npy
# Loaded dia325utt3_concatenated.npy
# Loaded dia594utt9_concatenated.npy
# Loaded dia614utt7_concatenated.npy
# Loaded dia71utt7_concatenated.npy
# Loaded dia106utt1_concatenated.npy
# Loaded dia763utt7_concatenated.npy
# Loaded dia434utt10_concatenated.npy
# Loaded dia408utt14_concatenated.npy
# Loaded dia252utt3_concatenated.npy
# Loaded dia907utt1_concatenated.npy
# Loaded dia680utt1_concatenated.npy
# Loaded dia186utt13_concatenated.npy
# Loaded dia1164utt6_concatenated.npy
# Loaded dia829utt5_concatenated.npy
# Loaded dia1109utt14_concatenated.npy
# Loaded dia28utt3_concatenated.npy
# Loaded dia1347utt4_concatenated.npy
# Loaded dia388utt17_concatenated.npy
# Loaded dia1230utt4_concatenated.npy
# Loaded dia1013utt6_concatenated.npy
# Loaded dia136utt13_concatenated.npy
# Loaded dia329utt5_concatenated.npy
# Loaded dia1131utt4_concatenated.npy
# Loaded dia1312utt6_concatenated.npy
# Loaded dia618utt1_concatenated.npy
# Loaded dia1265utt6_concatenated.npy
# Loaded dia1057utt19_concatenated.npy
# Loaded dia370utt1_concatenated.npy
# Loaded dia865utt9_concatenated.npy
# Loaded dia825utt3_concatenated.npy
# Loaded dia41utt12_concatenated.npy
# Loaded dia45utt18_concatenated.npy
# Loaded dia153utt3_concatenated.npy
# Loaded dia581utt1_concatenated.npy
# Loaded dia641utt5_concatenated.npy
# Loaded dia736utt5_concatenated.npy
# Loaded dia92utt16_concatenated.npy
# Loaded dia515utt7_concatenated.npy
# Loaded dia952utt3_concatenated.npy
# Loaded dia659utt10_concatenated.npy
# Loaded dia695utt9_concatenated.npy
# Loaded dia207utt1_concatenated.npy
# Loaded dia376utt2_concatenated.npy
# Loaded dia336utt8_concatenated.npy
# Loaded dia621utt13_concatenated.npy
# Loaded dia647utt6_concatenated.npy
# Loaded dia587utt2_concatenated.npy
# Loaded dia828utt10_concatenated.npy
# Loaded dia730utt6_concatenated.npy
# Loaded dia814utt14_concatenated.npy
# Loaded dia513utt4_concatenated.npy
# Loaded dia201utt2_concatenated.npy
# Loaded dia1137utt7_concatenated.npy
# Loaded dia1314utt5_concatenated.npy
# Loaded dia999utt2_concatenated.npy
# Loaded dia729utt8_concatenated.npy
# Loaded dia1219utt10_concatenated.npy
# Loaded dia769utt2_concatenated.npy
# Loaded dia1324utt19_concatenated.npy
# Loaded dia1040utt7_concatenated.npy
# Loaded dia198utt2_concatenated.npy
# Loaded dia258utt6_concatenated.npy
# Loaded dia393utt10_concatenated.npy
# Loaded dia469utt7_concatenated.npy
# Loaded dia142utt11_concatenated.npy
# Loaded dia1340utt2_concatenated.npy
# Loaded dia1328utt18_concatenated.npy
# Loaded dia1080utt6_concatenated.npy
# Loaded dia1310utt16_concatenated.npy
# Loaded dia158utt3_concatenated.npy
# Loaded dia1027utt11_concatenated.npy
# Loaded dia370utt11_concatenated.npy
# Loaded dia1277utt8_concatenated.npy
# Loaded dia249utt12_concatenated.npy
# Loaded dia877utt7_concatenated.npy
# Loaded dia470utt9_concatenated.npy
# Loaded dia1319utt6_concatenated.npy
# Loaded dia76utt1_concatenated.npy
# Loaded dia613utt1_concatenated.npy
# Loaded dia35utt10_concatenated.npy
# Loaded dia994utt1_concatenated.npy
# Loaded dia611utt16_concatenated.npy
# Loaded dia255utt5_concatenated.npy
# Loaded dia871utt4_concatenated.npy
# Loaded dia324utt6_concatenated.npy
# Loaded dia992utt2_concatenated.npy
# Loaded dia655utt11_concatenated.npy
# Loaded dia655utt8_concatenated.npy
# Loaded dia669utt15_concatenated.npy
# Loaded dia30utt8_concatenated.npy
# Loaded dia70utt2_concatenated.npy
# Loaded dia107utt4_concatenated.npy
# Loaded dia562utt16_concatenated.npy
# Loaded dia860utt16_concatenated.npy
# Loaded dia1268utt5_concatenated.npy
# Loaded dia762utt2_concatenated.npy
# Loaded dia686utt15_concatenated.npy
# Loaded dia30utt21_concatenated.npy
# Loaded dia253utt6_concatenated.npy
# Loaded dia965utt11_concatenated.npy
# Loaded dia467utt11_concatenated.npy
# Loaded dia193utt2_concatenated.npy
# Loaded dia906utt4_concatenated.npy
# Loaded dia681utt4_concatenated.npy
# Loaded dia1165utt3_concatenated.npy
# Loaded dia29utt6_concatenated.npy
# Loaded dia1282utt12_concatenated.npy
# Loaded dia1269utt18_concatenated.npy
# Loaded dia1231utt1_concatenated.npy
# Loaded dia1189utt11_concatenated.npy
# Loaded dia518utt4_concatenated.npy
# Loaded dia147utt20_concatenated.npy
# Loaded dia1130utt1_concatenated.npy
# Loaded dia165utt12_concatenated.npy
# Loaded dia1232utt12_concatenated.npy
# Loaded dia619utt4_concatenated.npy
# Loaded dia1224utt9_concatenated.npy
# Loaded dia1264utt3_concatenated.npy
# Loaded dia252utt15_concatenated.npy
# Loaded dia1139utt11_concatenated.npy
# Loaded dia1047utt1_concatenated.npy
# Loaded dia1004utt18_concatenated.npy
# Loaded dia371utt4_concatenated.npy
# Loaded dia438utt11_concatenated.npy
# Loaded dia1169utt5_concatenated.npy
# Loaded dia906utt15_concatenated.npy
# Loaded dia463utt2_concatenated.npy
# Loaded dia292utt2_concatenated.npy
# Loaded dia580utt4_concatenated.npy
# Loaded dia803utt12_concatenated.npy
# Loaded dia80utt21_concatenated.npy
# Loaded dia554utt8_concatenated.npy
# Loaded dia953utt6_concatenated.npy
# Loaded dia514utt2_concatenated.npy
# Loaded dia206utt4_concatenated.npy
# Loaded dia377utt7_concatenated.npy
# Loaded dia596utt11_concatenated.npy
# Loaded dia822utt5_concatenated.npy
# Loaded dia465utt1_concatenated.npy
# Loaded dia493utt16_concatenated.npy
# Loaded dia646utt3_concatenated.npy
# Loaded dia23utt3_concatenated.npy
# Loaded dia606utt9_concatenated.npy
# Loaded dia63utt9_concatenated.npy
# Loaded dia731utt3_concatenated.npy
# Loaded dia771utt9_concatenated.npy
# Loaded dia946utt18_concatenated.npy
# Loaded dia955utt5_concatenated.npy
# Loaded dia180utt9_concatenated.npy
# Loaded dia1176utt8_concatenated.npy
# Loaded dia1078utt11_concatenated.npy
# Loaded dia998utt7_concatenated.npy
# Loaded dia768utt7_concatenated.npy
# Loaded dia1041utt2_concatenated.npy
# Loaded dia1001utt8_concatenated.npy
# Loaded dia1276utt15_concatenated.npy
# Loaded dia199utt7_concatenated.npy
# Loaded dia259utt3_concatenated.npy
# Loaded dia1026utt4_concatenated.npy
# Loaded dia207utt14_concatenated.npy
# Loaded dia888utt1_concatenated.npy
# Loaded dia1069utt17_concatenated.npy
# Loaded dia678utt1_concatenated.npy
# Loaded dia1372utt6_concatenated.npy
# Loaded dia1183utt10_concatenated.npy
# Loaded dia130utt13_concatenated.npy
# Loaded dia267utt1_concatenated.npy
# Loaded dia575utt7_concatenated.npy
# Loaded dia90utt9_concatenated.npy
# Loaded dia482utt10_concatenated.npy
# Loaded dia756utt5_concatenated.npy
# Loaded dia496utt1_concatenated.npy
# Loaded dia44utt5_concatenated.npy
# Loaded dia621utt5_concatenated.npy
# Loaded dia856utt13_concatenated.npy
# Loaded dia429utt17_concatenated.npy
# Loaded dia1039utt9_concatenated.npy
# Loaded dia573utt4_concatenated.npy
# Loaded dia382utt4_concatenated.npy
# Loaded dia490utt2_concatenated.npy
# Loaded dia812utt14_concatenated.npy
# Loaded dia510utt14_concatenated.npy
# Loaded dia627utt6_concatenated.npy
# Loaded dia42utt6_concatenated.npy
# Loaded dia404utt4_concatenated.npy
# Loaded dia356utt8_concatenated.npy
# Loaded dia316utt2_concatenated.npy
# Loaded dia238utt6_concatenated.npy
# Loaded dia709utt2_concatenated.npy
# Loaded dia1203utt5_concatenated.npy
# Loaded dia243utt13_concatenated.npy
# Loaded dia1114utt13_concatenated.npy
# Loaded dia1157utt7_concatenated.npy
# Loaded dia325utt10_concatenated.npy
# Loaded dia938utt6_concatenated.npy
# Loaded dia1075utt5_concatenated.npy
# Loaded dia1196utt3_concatenated.npy
# Loaded dia1177utt17_concatenated.npy
# Loaded dia139utt6_concatenated.npy
# Loaded dia408utt2_concatenated.npy
# Loaded dia1102utt5_concatenated.npy
# Loaded dia83utt2_concatenated.npy
# Loaded dia741utt10_concatenated.npy
# Loaded dia961utt2_concatenated.npy
# Loaded dia644utt17_concatenated.npy
# Loaded dia882utt4_concatenated.npy
# Loaded dia678utt13_concatenated.npy
# Loaded dia120utt8_concatenated.npy
# Loaded dia573utt10_concatenated.npy
# Loaded dia160utt2_concatenated.npy
# Loaded dia871utt10_concatenated.npy
# Loaded dia17utt4_concatenated.npy
# Loaded dia697utt13_concatenated.npy
# Loaded dia948utt13_concatenated.npy
# Loaded dia856utt8_concatenated.npy
# Loaded dia451utt6_concatenated.npy
# Loaded dia792utt14_concatenated.npy
# Loaded dia791utt2_concatenated.npy
# Loaded dia520utt5_concatenated.npy
# Loaded dia967utt1_concatenated.npy
# Loaded dia85utt1_concatenated.npy
# Loaded dia232utt3_concatenated.npy
# Loaded dia272utt9_concatenated.npy
# Loaded dia432utt10_concatenated.npy
# Loaded dia18utt12_concatenated.npy
# Loaded dia930utt10_concatenated.npy
# Loaded dia703utt7_concatenated.npy
# Loaded dia483utt9_concatenated.npy
# Loaded dia884utt7_concatenated.npy
# Loaded dia739utt13_concatenated.npy
# Loaded dia305utt9_concatenated.npy
# Loaded dia797utt1_concatenated.npy
# Loaded dia810utt1_concatenated.npy
# Loaded dia579utt1_concatenated.npy
# Loaded dia1073utt6_concatenated.npy
# Loaded dia1250utt4_concatenated.npy
# Loaded dia388utt1_concatenated.npy
# Loaded dia1327utt4_concatenated.npy
# Loaded dia48utt3_concatenated.npy
# Loaded dia258utt14_concatenated.npy
# Loaded dia264utt10_concatenated.npy
# Loaded dia184utt19_concatenated.npy
# Loaded dia1104utt6_concatenated.npy
# Loaded dia849utt5_concatenated.npy
# Loaded dia740utt3_concatenated.npy
# Loaded dia700utt9_concatenated.npy
# Loaded dia887utt9_concatenated.npy
# Loaded dia1069utt6_concatenated.npy
# Loaded dia924utt5_concatenated.npy
# Loaded dia563utt1_concatenated.npy
# Loaded dia271utt7_concatenated.npy
# Loaded dia723utt11_concatenated.npy
# Loaded dia853utt5_concatenated.npy
# Loaded dia626utt16_concatenated.npy
# Loaded dia125utt5_concatenated.npy
# Loaded dia637utt3_concatenated.npy
# Loaded dia677utt9_concatenated.npy
# Loaded dia12utt9_concatenated.npy
# Loaded dia719utt7_concatenated.npy
# Loaded dia149utt15_concatenated.npy
# Loaded dia9utt2_concatenated.npy
# Loaded dia499utt9_concatenated.npy
# Loaded dia291utt12_concatenated.npy
# Loaded dia1030utt2_concatenated.npy
# Loaded dia268utt9_concatenated.npy
# Loaded dia347utt11_concatenated.npy
# Loaded dia1287utt6_concatenated.npy
# Loaded dia1147utt2_concatenated.npy
# Loaded dia1107utt8_concatenated.npy
# Loaded dia898utt4_concatenated.npy
# Loaded dia1255utt9_concatenated.npy
# Loaded dia303utt16_concatenated.npy
# Loaded dia1215utt3_concatenated.npy
# Loaded dia99utt2_concatenated.npy
# Loaded dia1036utt1_concatenated.npy
# Loaded dia206utt11_concatenated.npy
# Loaded dia131utt16_concatenated.npy
# Loaded dia1141utt1_concatenated.npy
# Loaded dia1281utt5_concatenated.npy
# Loaded dia1363utt11_concatenated.npy
# Loaded dia1362utt3_concatenated.npy
# Loaded dia486utt4_concatenated.npy
# Loaded dia394utt2_concatenated.npy
# Loaded dia483utt15_concatenated.npy
# Loaded dia922utt6_concatenated.npy
# Loaded dia525utt8_concatenated.npy
# Loaded dia565utt2_concatenated.npy
# Loaded dia884utt12_concatenated.npy
# Loaded dia277utt4_concatenated.npy
# Loaded dia857utt16_concatenated.npy
# Loaded dia300utt4_concatenated.npy
# Loaded dia1118utt5_concatenated.npy
# Loaded dia412utt2_concatenated.npy
# Loaded dia123utt6_concatenated.npy
# Loaded dia952utt11_concatenated.npy
# Loaded dia450utt11_concatenated.npy
# Loaded dia788utt16_concatenated.npy
# Loaded dia894utt2_concatenated.npy
# Loaded dia25utt13_concatenated.npy
# Loaded dia3utt7_concatenated.npy
# Loaded dia1219utt5_concatenated.npy
# Loaded dia713utt2_concatenated.npy
# Loaded dia95utt4_concatenated.npy
# Loaded dia977utt4_concatenated.npy
# Loaded dia787utt4_concatenated.npy
# Loaded dia355utt6_concatenated.npy
# Loaded dia624utt8_concatenated.npy
# Loaded dia41utt8_concatenated.npy
# Loaded dia664utt2_concatenated.npy
# Loaded dia738utt16_concatenated.npy
# Loaded dia176utt4_concatenated.npy
# Loaded dia398utt4_concatenated.npy
# Loaded dia1240utt1_concatenated.npy
# Loaded dia1063utt3_concatenated.npy
# Loaded dia1154utt9_concatenated.npy
# Loaded dia1114utt3_concatenated.npy
# Loaded dia1337utt1_concatenated.npy
# Loaded dia360utt12_concatenated.npy
# Loaded dia1246utt2_concatenated.npy
# Loaded dia1206utt8_concatenated.npy
# Loaded dia1186utt6_concatenated.npy
# Loaded dia928utt3_concatenated.npy
# Loaded dia318utt11_concatenated.npy
# Loaded dia418utt7_concatenated.npy
# Loaded dia1340utt18_concatenated.npy
# Loaded dia1344utt12_concatenated.npy
# Loaded dia169utt9_concatenated.npy
# Loaded dia129utt3_concatenated.npy
# Loaded dia387utt9_concatenated.npy
# Loaded dia679utt16_concatenated.npy
# Loaded dia715utt1_concatenated.npy
# Loaded dia892utt1_concatenated.npy
# Loaded dia224utt5_concatenated.npy
# Loaded dia93utt7_concatenated.npy
# Loaded dia781utt7_concatenated.npy
# Loaded dia441utt3_concatenated.npy
# Loaded dia806utt7_concatenated.npy
# Loaded dia1368utt6_concatenated.npy
# Loaded dia117utt1_concatenated.npy
# Loaded dia334utt3_concatenated.npy
# Loaded dia426utt5_concatenated.npy
# Loaded dia861utt1_concatenated.npy
# Loaded dia551utt5_concatenated.npy
# Loaded dia916utt1_concatenated.npy
# Loaded dia183utt7_concatenated.npy
# Loaded dia70utt12_concatenated.npy
# Loaded dia243utt3_concatenated.npy
# Loaded dia466utt14_concatenated.npy
# Loaded dia427utt22_concatenated.npy
# Loaded dia772utt7_concatenated.npy
# Loaded dia1283utt17_concatenated.npy
# Loaded dia1356utt4_concatenated.npy
# Loaded dia39utt3_concatenated.npy
# Loaded dia1175utt6_concatenated.npy
# Loaded dia1062utt13_concatenated.npy
# Loaded dia1355utt14_concatenated.npy
# Loaded dia1369utt10_concatenated.npy
# Loaded dia1188utt14_concatenated.npy
# Loaded dia1221utt4_concatenated.npy
# Loaded dia288utt2_concatenated.npy
# Loaded dia1090utt3_concatenated.npy
# Loaded dia1214utt14_concatenated.npy
# Loaded dia479utt2_concatenated.npy
# Loaded dia439utt8_concatenated.npy
# Loaded dia1173utt5_concatenated.npy
# Loaded dia949utt6_concatenated.npy
# Loaded dia1004utt5_concatenated.npy
# Loaded dia248utt17_concatenated.npy
# Loaded dia151utt8_concatenated.npy
# Loaded dia984utt4_concatenated.npy
# Loaded dia422utt13_concatenated.npy
# Loaded dia66utt4_concatenated.npy
# Loaded dia1349utt9_concatenated.npy
# Loaded dia819utt10_concatenated.npy
# Loaded dia420utt6_concatenated.npy
# Loaded dia827utt8_concatenated.npy
# Loaded dia825utt14_concatenated.npy
# Loaded dia910utt2_concatenated.npy
# Loaded dia697utt2_concatenated.npy
# Loaded dia185utt4_concatenated.npy
# Loaded dia774utt4_concatenated.npy
# Loaded dia8utt17_concatenated.npy
# Loaded dia729utt10_concatenated.npy
# Loaded dia596utt2_concatenated.npy
# Loaded dia656utt6_concatenated.npy
# Loaded dia33utt6_concatenated.npy
# Loaded dia84utt15_concatenated.npy
# Loaded dia284utt4_concatenated.npy
# Loaded dia367utt2_concatenated.npy
# Loaded dia544utt10_concatenated.npy
# Loaded dia1008utt3_concatenated.npy
# Loaded dia1048utt9_concatenated.npy
# Loaded dia721utt6_concatenated.npy
# Loaded dia1305utt5_concatenated.npy
# Loaded dia249utt6_concatenated.npy
# Loaded dia120utt10_concatenated.npy
# Loaded dia189utt2_concatenated.npy
# Loaded dia1372utt17_concatenated.npy
# Loaded dia778utt2_concatenated.npy
# Loaded dia738utt8_concatenated.npy
# Loaded dia1272utt5_concatenated.npy
# Loaded dia609utt1_concatenated.npy
# Loaded dia1083utt8_concatenated.npy
# Loaded dia1120utt4_concatenated.npy
# Loaded dia1336utt10_concatenated.npy
# Loaded dia385utt13_concatenated.npy
# Loaded dia338utt5_concatenated.npy
# Loaded dia1001utt17_concatenated.npy
# Loaded dia1057utt4_concatenated.npy
# Loaded dia253utt10_concatenated.npy
# Loaded dia1104utt10_concatenated.npy
# Loaded dia35utt5_concatenated.npy
# Loaded dia650utt5_concatenated.npy
# Loaded dia538utt19_concatenated.npy
# Loaded dia590utt1_concatenated.npy
# Loaded dia142utt3_concatenated.npy
# Loaded dia282utt7_concatenated.npy
# Loaded dia834utt3_concatenated.npy
# Loaded dia907utt10_concatenated.npy
# Loaded dia874utt9_concatenated.npy
# Loaded dia361utt1_concatenated.npy
# Loaded dia216utt1_concatenated.npy
# Loaded dia684utt9_concatenated.npy
# Loaded dia903utt9_concatenated.npy
# Loaded dia504utt7_concatenated.npy
# Loaded dia637utt10_concatenated.npy
# Loaded dia727utt5_concatenated.npy
# Loaded dia1208utt4_concatenated.npy
# Loaded dia84utt5_concatenated.npy
# Loaded dia785utt13_concatenated.npy
# Loaded dia521utt1_concatenated.npy
# Loaded dia966utt5_concatenated.npy
# Loaded dia233utt7_concatenated.npy
# Loaded dia344utt7_concatenated.npy
# Loaded dia456utt1_concatenated.npy
# Loaded dia811utt5_concatenated.npy
# Loaded dia796utt5_concatenated.npy
# Loaded dia167utt5_concatenated.npy
# Loaded dia675utt3_concatenated.npy
# Loaded dia10utt3_concatenated.npy
# Loaded dia1191utt4_concatenated.npy
# Loaded dia389utt5_concatenated.npy
# Loaded dia1032utt8_concatenated.npy
# Loaded dia1072utt2_concatenated.npy
# Loaded dia1145utt8_concatenated.npy
# Loaded dia1105utt2_concatenated.npy
# Loaded dia848utt1_concatenated.npy
# Loaded dia1257utt3_concatenated.npy
# Loaded dia232utt21_concatenated.npy
# Loaded dia1197utt7_concatenated.npy
# Loaded dia376utt10_concatenated.npy
# Loaded dia979utt8_concatenated.npy
# Loaded dia1074utt1_concatenated.npy
# Loaded dia144utt10_concatenated.npy
# Loaded dia409utt6_concatenated.npy
# Loaded dia1103utt1_concatenated.npy
# Loaded dia138utt2_concatenated.npy
# Loaded dia396utt8_concatenated.npy
# Loaded dia527utt2_concatenated.npy
# Loaded dia82utt6_concatenated.npy
# Loaded dia235utt4_concatenated.npy
# Loaded dia450utt2_concatenated.npy
# Loaded dia822utt10_concatenated.npy
# Loaded dia520utt10_concatenated.npy
# Loaded dia33utt11_concatenated.npy
# Loaded dia751utt2_concatenated.npy
# Loaded dia711utt8_concatenated.npy
# Loaded dia491utt6_concatenated.npy
# Loaded dia260utt6_concatenated.npy
# Loaded dia1078utt7_concatenated.npy
# Loaded dia935utt4_concatenated.npy
# Loaded dia842utt4_concatenated.npy
# Loaded dia317utt6_concatenated.npy
# Loaded dia771utt14_concatenated.npy
# Loaded dia626utt2_concatenated.npy
# Loaded dia666utt8_concatenated.npy
# Loaded dia83utt11_concatenated.npy
# Loaded dia997utt17_concatenated.npy
# Loaded dia708utt6_concatenated.npy
# Loaded dia1270utt14_concatenated.npy
# Loaded dia127utt14_concatenated.npy
# Loaded dia1296utt7_concatenated.npy
# Loaded dia329utt10_concatenated.npy
# Loaded dia268utt10_concatenated.npy
# Loaded dia1103utt14_concatenated.npy
# Loaded dia1244utt8_concatenated.npy
# Loaded dia1204utt2_concatenated.npy
# Loaded dia1290utt4_concatenated.npy
# Loaded dia382utt17_concatenated.npy
# Loaded dia679utt5_concatenated.npy
# Loaded dia1373utt2_concatenated.npy
# Loaded dia1230utt19_concatenated.npy
# Loaded dia287utt10_concatenated.npy
# Loaded dia385utt3_concatenated.npy
# Loaded dia86utt20_concatenated.npy
# Loaded dia757utt1_concatenated.npy
# Loaded dia735utt13_concatenated.npy
# Loaded dia266utt5_concatenated.npy
# Loaded dia574utt3_concatenated.npy
# Loaded dia1109utt4_concatenated.npy
# Loaded dia403utt3_concatenated.npy
# Loaded dia14utt12_concatenated.npy
# Loaded dia311utt5_concatenated.npy
# Loaded dia45utt1_concatenated.npy
# Loaded dia620utt1_concatenated.npy
# Loaded dia839utt17_concatenated.npy
# Loaded dia132utt7_concatenated.npy
# Loaded dia621utt12_concatenated.npy
# Loaded dia155utt1_concatenated.npy
# Loaded dia587utt3_concatenated.npy
# Loaded dia647utt7_concatenated.npy
# Loaded dia336utt9_concatenated.npy
# Loaded dia376utt3_concatenated.npy
# Loaded dia823utt1_concatenated.npy
# Loaded dia413utt12_concatenated.npy
# Loaded dia954utt1_concatenated.npy
# Loaded dia513utt5_concatenated.npy
# Loaded dia201utt3_concatenated.npy
# Loaded dia730utt7_concatenated.npy
# Loaded dia828utt11_concatenated.npy
# Loaded dia999utt3_concatenated.npy
# Loaded dia1314utt4_concatenated.npy
# Loaded dia1137utt6_concatenated.npy
# Loaded dia1040utt6_concatenated.npy
# Loaded dia1324utt18_concatenated.npy
# Loaded dia393utt11_concatenated.npy
# Loaded dia258utt7_concatenated.npy
# Loaded dia198utt3_concatenated.npy
# Loaded dia769utt3_concatenated.npy
# Loaded dia729utt9_concatenated.npy
# Loaded dia1219utt11_concatenated.npy
# Loaded dia329utt4_concatenated.npy
# Loaded dia136utt12_concatenated.npy
# Loaded dia1131utt5_concatenated.npy
# Loaded dia1057utt18_concatenated.npy
# Loaded dia1265utt7_concatenated.npy
# Loaded dia1053utt12_concatenated.npy
# Loaded dia153utt2_concatenated.npy
# Loaded dia113utt8_concatenated.npy
# Loaded dia41utt13_concatenated.npy
# Loaded dia641utt4_concatenated.npy
# Loaded dia825utt2_concatenated.npy
# Loaded dia1168utt1_concatenated.npy
# Loaded dia865utt8_concatenated.npy
# Loaded dia695utt8_concatenated.npy
# Loaded dia952utt2_concatenated.npy
# Loaded dia659utt11_concatenated.npy
# Loaded dia515utt6_concatenated.npy
# Loaded dia736utt4_concatenated.npy
# Loaded dia92utt17_concatenated.npy
# Loaded dia614utt6_concatenated.npy
# Loaded dia71utt6_concatenated.npy
# Loaded dia594utt8_concatenated.npy
# Loaded dia437utt4_concatenated.npy
# Loaded dia325utt2_concatenated.npy
# Loaded dia606utt11_concatenated.npy
# Loaded dia252utt2_concatenated.npy
# Loaded dia1269utt1_concatenated.npy
# Loaded dia763utt6_concatenated.npy
# Loaded dia1347utt5_concatenated.npy
# Loaded dia28utt2_concatenated.npy
# Loaded dia1087utt1_concatenated.npy
# Loaded dia1164utt7_concatenated.npy
# Loaded dia829utt4_concatenated.npy
# Loaded dia186utt12_concatenated.npy
# Loaded dia1109utt15_concatenated.npy
# Loaded dia388utt16_concatenated.npy
# Loaded dia1230utt5_concatenated.npy
# Loaded dia1081utt2_concatenated.npy
# Loaded dia468utt3_concatenated.npy
# Loaded dia1162utt4_concatenated.npy
# Loaded dia323utt11_concatenated.npy
# Loaded dia1015utt4_concatenated.npy
# Loaded dia995utt5_concatenated.npy
# Loaded dia77utt5_concatenated.npy
# Loaded dia612utt5_concatenated.npy
# Loaded dia549utt15_concatenated.npy
# Loaded dia140utt9_concatenated.npy
# Loaded dia575utt11_concatenated.npy
# Loaded dia100utt3_concatenated.npy
# Loaded dia877utt11_concatenated.npy
# Loaded dia876utt3_concatenated.npy
# Loaded dia66utt10_concatenated.npy
# Loaded dia323utt1_concatenated.npy
# Loaded dia254utt1_concatenated.npy
# Loaded dia194utt5_concatenated.npy
# Loaded dia546utt7_concatenated.npy
# Loaded dia941utt9_concatenated.npy
# Loaded dia686utt3_concatenated.npy
# Loaded dia747utt11_concatenated.npy
# Loaded dia765utt5_concatenated.npy
# Loaded dia1260utt17_concatenated.npy
# Loaded dia339utt1_concatenated.npy
# Loaded dia608utt5_concatenated.npy
# Loaded dia1081utt13_concatenated.npy
# Loaded dia1302utt2_concatenated.npy
# Loaded dia1359utt14_concatenated.npy
# Loaded dia1275utt2_concatenated.npy
# Loaded dia339utt13_concatenated.npy
# Loaded dia432utt9_concatenated.npy
# Loaded dia1178utt4_concatenated.npy
# Loaded dia472utt3_concatenated.npy
# Loaded dia360utt5_concatenated.npy
# Loaded dia34utt1_concatenated.npy
# Loaded dia651utt1_concatenated.npy
# Loaded dia283utt3_concatenated.npy
# Loaded dia954utt10_concatenated.npy
# Loaded dia456utt10_concatenated.npy
# Loaded dia485utt14_concatenated.npy
# Loaded dia93utt12_concatenated.npy
# Loaded dia726utt1_concatenated.npy
# Loaded dia505utt3_concatenated.npy
# Loaded dia32utt2_concatenated.npy
# Loaded dia617utt8_concatenated.npy
# Loaded dia72utt8_concatenated.npy
# Loaded dia597utt6_concatenated.npy
# Loaded dia618utt19_concatenated.npy
# Loaded dia453utt21_concatenated.npy
# Loaded dia928utt19_concatenated.npy
# Loaded dia1009utt7_concatenated.npy
# Loaded dia1127utt3_concatenated.npy
# Loaded dia1167utt9_concatenated.npy
# Loaded dia1016utt10_concatenated.npy
# Loaded dia1304utt1_concatenated.npy
# Loaded dia989utt6_concatenated.npy
# Loaded dia1224utt10_concatenated.npy
# Loaded dia1273utt1_concatenated.npy
# Loaded dia248utt2_concatenated.npy
# Loaded dia1050utt3_concatenated.npy
# Loaded dia478utt6_concatenated.npy
# Loaded dia149utt2_concatenated.npy
# Loaded dia1351utt3_concatenated.npy
# Loaded dia1091utt7_concatenated.npy
# Loaded dia1170utt13_concatenated.npy
# Loaded dia1226utt3_concatenated.npy
# Loaded dia227utt13_concatenated.npy
# Loaded dia1049utt10_concatenated.npy
# Loaded dia948utt2_concatenated.npy
# Loaded dia1005utt1_concatenated.npy
# Loaded dia333utt4_concatenated.npy
# Loaded dia471utt13_concatenated.npy
# Loaded dia795utt10_concatenated.npy
# Loaded dia1308utt7_concatenated.npy
# Loaded dia1088utt9_concatenated.npy
# Loaded dia556utt2_concatenated.npy
# Loaded dia911utt6_concatenated.npy
# Loaded dia244utt4_concatenated.npy
# Loaded dia607utt14_concatenated.npy
# Loaded dia427utt1_concatenated.npy
# Loaded dia860utt5_concatenated.npy
# Loaded dia116utt5_concatenated.npy
# Loaded dia983utt3_concatenated.npy
# Loaded dia644utt9_concatenated.npy
# Loaded dia21utt9_concatenated.npy
# Loaded dia61utt3_concatenated.npy
# Loaded dia1279utt4_concatenated.npy
# Loaded dia773utt3_concatenated.npy
# Loaded dia409utt10_concatenated.npy
# Loaded dia917utt5_concatenated.npy
# Loaded dia690utt5_concatenated.npy
# Loaded dia182utt3_concatenated.npy
# Loaded dia1108utt10_concatenated.npy
# Loaded dia1134utt8_concatenated.npy
# Loaded dia839utt1_concatenated.npy
# Loaded dia1031utt13_concatenated.npy
# Loaded dia1097utt4_concatenated.npy
# Loaded dia389utt13_concatenated.npy
# Loaded dia1043utt8_concatenated.npy
# Loaded dia168utt17_concatenated.npy
# Loaded dia509utt5_concatenated.npy
# Loaded dia1003utt2_concatenated.npy
# Loaded dia1203utt13_concatenated.npy
# Loaded dia1121utt18_concatenated.npy
# Loaded dia272utt12_concatenated.npy
# Loaded dia929utt7_concatenated.npy
# Loaded dia1247utt6_concatenated.npy
# Loaded dia1330utt6_concatenated.npy
# Loaded dia128utt7_concatenated.npy
# Loaded dia398utt15_concatenated.npy
# Loaded dia419utt3_concatenated.npy
# Loaded dia459utt9_concatenated.npy
# Loaded dia1113utt4_concatenated.npy
# Loaded dia92utt3_concatenated.npy
# Loaded dia930utt9_concatenated.npy
# Loaded dia537utt7_concatenated.npy
# Loaded dia970utt3_concatenated.npy
# Loaded dia893utt5_concatenated.npy
# Loaded dia714utt5_concatenated.npy
# Loaded dia1369utt2_concatenated.npy
# Loaded dia926utt12_concatenated.npy
# Loaded dia131utt9_concatenated.npy
# Loaded dia171utt3_concatenated.npy
# Loaded dia847utt9_concatenated.npy
# Loaded dia440utt7_concatenated.npy
# Loaded dia521utt15_concatenated.npy
# Loaded dia780utt3_concatenated.npy
# Loaded dia352utt1_concatenated.npy
# Loaded dia223utt2_concatenated.npy
# Loaded dia263utt8_concatenated.npy
# Loaded dia76utt13_concatenated.npy
# Loaded dia863utt18_concatenated.npy
# Loaded dia1218utt1_concatenated.npy
# Loaded dia712utt6_concatenated.npy
# Loaded dia895utt6_concatenated.npy
# Loaded dia2utt3_concatenated.npy
# Loaded dia652utt15_concatenated.npy
# Loaded dia665utt6_concatenated.npy
# Loaded dia757utt12_concatenated.npy
# Loaded dia446utt4_concatenated.npy
# Loaded dia354utt2_concatenated.npy
# Loaded dia99utt13_concatenated.npy
# Loaded dia1062utt7_concatenated.npy
# Loaded dia1241utt5_concatenated.npy
# Loaded dia19utt8_concatenated.npy
# Loaded dia1336utt5_concatenated.npy
# Loaded dia236utt15_concatenated.npy
# Loaded dia59utt2_concatenated.npy
# Loaded dia1115utt7_concatenated.npy
# Loaded dia1037utt5_concatenated.npy
# Loaded dia98utt6_concatenated.npy
# Loaded dia1214utt7_concatenated.npy
# Loaded dia255utt11_concatenated.npy
# Loaded dia1102utt11_concatenated.npy
# Loaded dia1363utt7_concatenated.npy
# Loaded dia383utt12_concatenated.npy
# Loaded dia1330utt11_concatenated.npy
# Loaded dia1280utt1_concatenated.npy
# Loaded dia923utt2_concatenated.npy
# Loaded dia564utt6_concatenated.npy
# Loaded dia963utt8_concatenated.npy
# Loaded dia81utt8_concatenated.npy
# Loaded dia708utt12_concatenated.npy
# Loaded dia747utt4_concatenated.npy
# Loaded dia162utt8_concatenated.npy
# Loaded dia55utt4_concatenated.npy
# Loaded dia506utt16_concatenated.npy
# Loaded dia15utt17_concatenated.npy
# Loaded dia854utt2_concatenated.npy
# Loaded dia403utt11_concatenated.npy
# Loaded dia1119utt1_concatenated.npy
# Loaded dia413utt6_concatenated.npy
# Loaded dia814utt8_concatenated.npy
# Loaded dia1068utt2_concatenated.npy
# Loaded dia925utt1_concatenated.npy
# Loaded dia562utt5_concatenated.npy
# Loaded dia270utt3_concatenated.npy
# Loaded dia741utt7_concatenated.npy
# Loaded dia393utt5_concatenated.npy
# Loaded dia979utt12_concatenated.npy
# Loaded dia945utt16_concatenated.npy
# Loaded dia490utt18_concatenated.npy
# Loaded dia82utt14_concatenated.npy
# Loaded dia53utt7_concatenated.npy
# Loaded dia347utt9_concatenated.npy
# Loaded dia307utt3_concatenated.npy
# Loaded dia852utt1_concatenated.npy
# Loaded dia1031utt6_concatenated.npy
# Loaded dia1271utt11_concatenated.npy
# Loaded dia229utt7_concatenated.npy
# Loaded dia8utt6_concatenated.npy
# Loaded dia1090utt15_concatenated.npy
# Loaded dia1212utt4_concatenated.npy
# Loaded dia1146utt6_concatenated.npy
# Loaded dia318utt10_concatenated.npy
# Loaded dia928utt2_concatenated.npy
# Loaded dia1186utt7_concatenated.npy
# Loaded dia1206utt9_concatenated.npy
# Loaded dia1246utt3_concatenated.npy
# Loaded dia129utt2_concatenated.npy
# Loaded dia169utt8_concatenated.npy
# Loaded dia1112utt1_concatenated.npy
# Loaded dia418utt6_concatenated.npy
# Loaded dia798utt8_concatenated.npy
# Loaded dia1344utt13_concatenated.npy
# Loaded dia1340utt19_concatenated.npy
# Loaded dia224utt4_concatenated.npy
# Loaded dia93utt6_concatenated.npy
# Loaded dia387utt8_concatenated.npy
# Loaded dia679utt17_concatenated.npy
# Loaded dia1368utt7_concatenated.npy
# Loaded dia806utt6_concatenated.npy
# Loaded dia441utt2_concatenated.npy
# Loaded dia781utt6_concatenated.npy
# Loaded dia977utt5_concatenated.npy
# Loaded dia530utt1_concatenated.npy
# Loaded dia95utt5_concatenated.npy
# Loaded dia713utt3_concatenated.npy
# Loaded dia1219utt4_concatenated.npy
# Loaded dia3utt6_concatenated.npy
# Loaded dia894utt3_concatenated.npy
# Loaded dia25utt12_concatenated.npy
# Loaded dia664utt3_concatenated.npy
# Loaded dia624utt9_concatenated.npy
# Loaded dia41utt9_concatenated.npy
# Loaded dia176utt5_concatenated.npy
# Loaded dia738utt17_concatenated.npy
# Loaded dia787utt5_concatenated.npy
# Loaded dia447utt1_concatenated.npy
# Loaded dia355utt7_concatenated.npy
# Loaded dia1063utt2_concatenated.npy
# Loaded dia398utt5_concatenated.npy
# Loaded dia360utt13_concatenated.npy
# Loaded dia1114utt2_concatenated.npy
# Loaded dia1154utt8_concatenated.npy
# Loaded dia206utt10_concatenated.npy
# Loaded dia99utt3_concatenated.npy
# Loaded dia1215utt2_concatenated.npy
# Loaded dia303utt17_concatenated.npy
# Loaded dia1255utt8_concatenated.npy
# Loaded dia898utt5_concatenated.npy
# Loaded dia1363utt10_concatenated.npy
# Loaded dia1362utt2_concatenated.npy
# Loaded dia359utt1_concatenated.npy
# Loaded dia1281utt4_concatenated.npy
# Loaded dia565utt3_concatenated.npy
# Loaded dia525utt9_concatenated.npy
# Loaded dia277utt5_concatenated.npy
# Loaded dia746utt1_concatenated.npy
# Loaded dia486utt5_concatenated.npy
# Loaded dia483utt14_concatenated.npy
# Loaded dia394utt3_concatenated.npy
# Loaded dia450utt10_concatenated.npy
# Loaded dia952utt10_concatenated.npy
# Loaded dia123utt7_concatenated.npy
# Loaded dia54utt1_concatenated.npy
# Loaded dia788utt17_concatenated.npy
# Loaded dia631utt1_concatenated.npy
# Loaded dia300utt5_concatenated.npy
# Loaded dia412utt3_concatenated.npy
# Loaded dia1118utt4_concatenated.npy
# Loaded dia1069utt7_concatenated.npy
# Loaded dia924utt4_concatenated.npy
# Loaded dia271utt6_concatenated.npy
# Loaded dia480utt6_concatenated.npy
# Loaded dia887utt8_concatenated.npy
# Loaded dia700utt8_concatenated.npy
# Loaded dia740utt2_concatenated.npy
# Loaded dia125utt4_concatenated.npy
# Loaded dia626utt17_concatenated.npy
# Loaded dia677utt8_concatenated.npy
# Loaded dia12utt8_concatenated.npy
# Loaded dia637utt2_concatenated.npy
# Loaded dia723utt10_concatenated.npy
# Loaded dia853utt4_concatenated.npy
# Loaded dia1030utt3_concatenated.npy
# Loaded dia268utt8_concatenated.npy
# Loaded dia499utt8_concatenated.npy
# Loaded dia9utt3_concatenated.npy
# Loaded dia1213utt1_concatenated.npy
# Loaded dia719utt6_concatenated.npy
# Loaded dia149utt14_concatenated.npy
# Loaded dia291utt13_concatenated.npy
# Loaded dia1364utt1_concatenated.npy
# Loaded dia347utt10_concatenated.npy
# Loaded dia1107utt9_concatenated.npy
# Loaded dia1147utt3_concatenated.npy
# Loaded dia1287utt7_concatenated.npy
# Loaded dia1336utt11_concatenated.npy
# Loaded dia125utt20_concatenated.npy
# Loaded dia338utt4_concatenated.npy
# Loaded dia385utt12_concatenated.npy
# Loaded dia1083utt9_concatenated.npy
# Loaded dia1104utt11_concatenated.npy
# Loaded dia253utt11_concatenated.npy
# Loaded dia1001utt16_concatenated.npy
# Loaded dia1057utt5_concatenated.npy
# Loaded dia874utt8_concatenated.npy
# Loaded dia907utt11_concatenated.npy
# Loaded dia834utt2_concatenated.npy
# Loaded dia1179utt1_concatenated.npy
# Loaded dia538utt18_concatenated.npy
# Loaded dia35utt4_concatenated.npy
# Loaded dia802utt16_concatenated.npy
# Loaded dia650utt4_concatenated.npy
# Loaded dia282utt6_concatenated.npy
# Loaded dia102utt8_concatenated.npy
# Loaded dia142utt2_concatenated.npy
# Loaded dia637utt11_concatenated.npy
# Loaded dia727utt4_concatenated.npy
# Loaded dia903utt8_concatenated.npy
# Loaded dia504utt6_concatenated.npy
# Loaded dia684utt8_concatenated.npy
# Loaded dia832utt1_concatenated.npy
# Loaded dia367utt3_concatenated.npy
# Loaded dia656utt7_concatenated.npy
# Loaded dia33utt7_concatenated.npy
# Loaded dia596utt3_concatenated.npy
# Loaded dia144utt1_concatenated.npy
# Loaded dia84utt14_concatenated.npy
# Loaded dia284utt5_concatenated.npy
# Loaded dia721utt7_concatenated.npy
# Loaded dia544utt11_concatenated.npy
# Loaded dia1048utt8_concatenated.npy
# Loaded dia1008utt2_concatenated.npy
# Loaded dia945utt1_concatenated.npy
# Loaded dia1126utt6_concatenated.npy
# Loaded dia1305utt4_concatenated.npy
# Loaded dia1372utt16_concatenated.npy
# Loaded dia738utt9_concatenated.npy
# Loaded dia1272utt4_concatenated.npy
# Loaded dia778utt3_concatenated.npy
# Loaded dia120utt11_concatenated.npy
# Loaded dia189utt3_concatenated.npy
# Loaded dia249utt7_concatenated.npy
# Loaded dia1193utt12_concatenated.npy
# Loaded dia439utt9_concatenated.npy
# Loaded dia1173utt4_concatenated.npy
# Loaded dia479utt3_concatenated.npy
# Loaded dia288utt3_concatenated.npy
# Loaded dia1090utt2_concatenated.npy
# Loaded dia1227utt6_concatenated.npy
# Loaded dia949utt7_concatenated.npy
# Loaded dia1004utt4_concatenated.npy
# Loaded dia248utt16_concatenated.npy
# Loaded dia332utt1_concatenated.npy
# Loaded dia420utt7_concatenated.npy
# Loaded dia827utt9_concatenated.npy
# Loaded dia825utt15_concatenated.npy
# Loaded dia819utt11_concatenated.npy
# Loaded dia151utt9_concatenated.npy
# Loaded dia1349utt8_concatenated.npy
# Loaded dia66utt5_concatenated.npy
# Loaded dia422utt12_concatenated.npy
# Loaded dia984utt5_concatenated.npy
# Loaded dia774utt5_concatenated.npy
# Loaded dia8utt16_concatenated.npy
# Loaded dia697utt3_concatenated.npy
# Loaded dia910utt3_concatenated.npy
# Loaded dia614utt18_concatenated.npy
# Loaded dia185utt5_concatenated.npy
# Loaded dia245utt1_concatenated.npy
# Loaded dia334utt2_concatenated.npy
# Loaded dia426utt4_concatenated.npy
# Loaded dia982utt6_concatenated.npy
# Loaded dia427utt23_concatenated.npy
# Loaded dia772utt6_concatenated.npy
# Loaded dia1278utt1_concatenated.npy
# Loaded dia551utt4_concatenated.npy
# Loaded dia466utt15_concatenated.npy
# Loaded dia243utt2_concatenated.npy
# Loaded dia70utt13_concatenated.npy
# Loaded dia183utt6_concatenated.npy
# Loaded dia1175utt7_concatenated.npy
# Loaded dia1062utt12_concatenated.npy
# Loaded dia1283utt16_concatenated.npy
# Loaded dia1096utt1_concatenated.npy
# Loaded dia39utt2_concatenated.npy
# Loaded dia1356utt5_concatenated.npy
# Loaded dia1221utt5_concatenated.npy
# Loaded dia1188utt15_concatenated.npy
# Loaded dia1369utt11_concatenated.npy
# Loaded dia1355utt15_concatenated.npy
# Loaded dia493utt17_concatenated.npy
# Loaded dia606utt8_concatenated.npy
# Loaded dia63utt8_concatenated.npy
# Loaded dia646utt2_concatenated.npy
# Loaded dia23utt2_concatenated.npy
# Loaded dia377utt6_concatenated.npy
# Loaded dia596utt10_concatenated.npy
# Loaded dia822utt4_concatenated.npy
# Loaded dia955utt4_concatenated.npy
# Loaded dia180utt8_concatenated.npy
# Loaded dia771utt8_concatenated.npy
# Loaded dia731utt2_concatenated.npy
# Loaded dia946utt19_concatenated.npy
# Loaded dia1078utt10_concatenated.npy
# Loaded dia998utt6_concatenated.npy
# Loaded dia1315utt1_concatenated.npy
# Loaded dia1176utt9_concatenated.npy
# Loaded dia1001utt9_concatenated.npy
# Loaded dia259utt2_concatenated.npy
# Loaded dia199utt6_concatenated.npy
# Loaded dia1276utt14_concatenated.npy
# Loaded dia768utt6_concatenated.npy
# Loaded dia1232utt13_concatenated.npy
# Loaded dia165utt13_concatenated.npy
# Loaded dia328utt1_concatenated.npy
# Loaded dia1004utt19_concatenated.npy
# Loaded dia1264utt2_concatenated.npy
# Loaded dia1224utt8_concatenated.npy
# Loaded dia1139utt10_concatenated.npy
# Loaded dia252utt14_concatenated.npy
# Loaded dia292utt3_concatenated.npy
# Loaded dia25utt1_concatenated.npy
# Loaded dia803utt13_concatenated.npy
# Loaded dia640utt1_concatenated.npy
# Loaded dia580utt5_concatenated.npy
# Loaded dia371utt5_concatenated.npy
# Loaded dia463utt3_concatenated.npy
# Loaded dia906utt14_concatenated.npy
# Loaded dia1169utt4_concatenated.npy
# Loaded dia438utt10_concatenated.npy
# Loaded dia514utt3_concatenated.npy
# Loaded dia953utt7_concatenated.npy
# Loaded dia206utt5_concatenated.npy
# Loaded dia737utt1_concatenated.npy
# Loaded dia80utt20_concatenated.npy
# Loaded dia70utt3_concatenated.npy
# Loaded dia655utt9_concatenated.npy
# Loaded dia30utt9_concatenated.npy
# Loaded dia669utt14_concatenated.npy
# Loaded dia992utt3_concatenated.npy
# Loaded dia655utt10_concatenated.npy
# Loaded dia871utt5_concatenated.npy
# Loaded dia436utt1_concatenated.npy
# Loaded dia324utt7_concatenated.npy
# Loaded dia193utt3_concatenated.npy
# Loaded dia467utt10_concatenated.npy
# Loaded dia965utt10_concatenated.npy
# Loaded dia253utt7_concatenated.npy
# Loaded dia681utt5_concatenated.npy
# Loaded dia906utt5_concatenated.npy
# Loaded dia541utt1_concatenated.npy
# Loaded dia860utt17_concatenated.npy
# Loaded dia562utt17_concatenated.npy
# Loaded dia30utt20_concatenated.npy
# Loaded dia686utt14_concatenated.npy
# Loaded dia762utt3_concatenated.npy
# Loaded dia1268utt4_concatenated.npy
# Loaded dia1166utt10_concatenated.npy
# Loaded dia1282utt13_concatenated.npy
# Loaded dia1165utt2_concatenated.npy
# Loaded dia828utt1_concatenated.npy
# Loaded dia1125utt8_concatenated.npy
# Loaded dia147utt21_concatenated.npy
# Loaded dia518utt5_concatenated.npy
# Loaded dia1269utt19_concatenated.npy
# Loaded dia1189utt10_concatenated.npy
# Loaded dia1080utt7_concatenated.npy
# Loaded dia1310utt17_concatenated.npy
# Loaded dia1328utt19_concatenated.npy
# Loaded dia1340utt3_concatenated.npy
# Loaded dia158utt2_concatenated.npy
# Loaded dia142utt10_concatenated.npy
# Loaded dia1163utt1_concatenated.npy
# Loaded dia469utt6_concatenated.npy
# Loaded dia249utt13_concatenated.npy
# Loaded dia1014utt1_concatenated.npy
# Loaded dia370utt10_concatenated.npy
# Loaded dia1027utt10_concatenated.npy
# Loaded dia35utt11_concatenated.npy
# Loaded dia1319utt7_concatenated.npy
# Loaded dia877utt6_concatenated.npy
# Loaded dia470utt8_concatenated.npy
# Loaded dia430utt2_concatenated.npy
# Loaded dia322utt4_concatenated.npy
# Loaded dia255utt4_concatenated.npy
# Loaded dia611utt17_concatenated.npy
# Loaded dia900utt6_concatenated.npy
# Loaded dia687utt6_concatenated.npy
# Loaded dia483utt8_concatenated.npy
# Loaded dia884utt6_concatenated.npy
# Loaded dia703utt6_concatenated.npy
# Loaded dia930utt11_concatenated.npy
# Loaded dia432utt11_concatenated.npy
# Loaded dia1209utt1_concatenated.npy
# Loaded dia18utt13_concatenated.npy
# Loaded dia520utt4_concatenated.npy
# Loaded dia272utt8_concatenated.npy
# Loaded dia232utt2_concatenated.npy
# Loaded dia305utt8_concatenated.npy
# Loaded dia345utt2_concatenated.npy
# Loaded dia739utt12_concatenated.npy
# Loaded dia674utt6_concatenated.npy
# Loaded dia1250utt5_concatenated.npy
# Loaded dia1073utt7_concatenated.npy
# Loaded dia264utt11_concatenated.npy
# Loaded dia258utt15_concatenated.npy
# Loaded dia1104utt7_concatenated.npy
# Loaded dia849utt4_concatenated.npy
# Loaded dia180utt12_concatenated.npy
# ...
# Loaded dia348utt2_concatenated.npy
# Loaded dia836utt11_concatenated.npy
# Loaded dia889utt6_concatenated.npy
# Loaded dia239utt1_concatenated.npy
# Loaded dia1311utt1_concatenated.npy
# Loaded dia134utt7_concatenated.npy
# Loaded dia1172utt9_concatenated.npy
# Loaded dia445utt9_concatenated.npy
# Loaded dia572utt3_concatenated.npy
# Loaded dia858utt7_concatenated.npy
# Loaded dia1128utt3_concatenated.npy
# Loaded dia801utt3_concatenated.npy
# Loaded dia1171utt7_concatenated.npy
# Loaded dia137utt9_concatenated.npy
# Loaded dia1225utt5_concatenated.npy
# Loaded dia531utt7_concatenated.npy
# Loaded dia936utt9_concatenated.npy
# Loaded dia239utt13_concatenated.npy
# Loaded dia1294utt19_concatenated.npy
# Loaded dia241utt10_concatenated.npy
# Loaded dia1223utt6_concatenated.npy
# Loaded dia225utt2_concatenated.npy
# Loaded dia718utt19_concatenated.npy
# Loaded dia448utt10_concatenated.npy
# Loaded dia415utt6_concatenated.npy
# Loaded dia1122utt6_concatenated.npy
# Loaded dia124utt2_concatenated.npy
# Loaded dia636utt4_concatenated.npy
# Loaded dia1055utt6_concatenated.npy
# Loaded dia341utt9_concatenated.npy
# Loaded dia122utt1_concatenated.npy
# Loaded dia363utt14_concatenated.npy
# Loaded dia630utt7_concatenated.npy
# Loaded dia276utt3_concatenated.npy
# Loaded dia358utt7_concatenated.npy
# Loaded dia932utt13_concatenated.npy
# Loaded dia779utt5_concatenated.npy
# Loaded dia421utt15_concatenated.npy
# Loaded dia720utt1_concatenated.npy
# Loaded dia1360utt1_concatenated.npy
# Loaded dia145utt7_concatenated.npy
# Loaded dia1143utt3_concatenated.npy
# Loaded dia1331utt23_concatenated.npy
# Loaded dia591utt6_concatenated.npy
# Loaded dia461utt18_concatenated.npy
# Loaded dia862utt15_concatenated.npy
# Loaded dia988utt12_concatenated.npy
# Loaded dia634utt16_concatenated.npy
# Loaded dia406utt16_concatenated.npy
# Loaded dia879utt8_concatenated.npy
# Loaded dia550utt2_concatenated.npy
# Loaded dia1060utt11_concatenated.npy
# Loaded dia52utt5_concatenated.npy
# Loaded dia421utt1_concatenated.npy
# Loaded dia879utt12_concatenated.npy
# Loaded dia993utt15_concatenated.npy
# Loaded dia749utt12_concatenated.npy
# Loaded dia598utt13_concatenated.npy
# Loaded dia682utt8_concatenated.npy
# Loaded dia943utt1_concatenated.npy
# Loaded dia473utt5_concatenated.npy
# Loaded dia508utt3_concatenated.npy
# Loaded dia667utt17_concatenated.npy
# Loaded dia838utt7_concatenated.npy
# Loaded dia691utt3_concatenated.npy
# Loaded dia1245utt5_concatenated.npy
# Loaded dia1185utt1_concatenated.npy
# Loaded dia134utt10_concatenated.npy
# Loaded dia821utt9_concatenated.npy
# Loaded dia1060utt4_concatenated.npy
# Loaded dia1245utt17_concatenated.npy
# Loaded dia603utt6_concatenated.npy
# Loaded dia583utt8_concatenated.npy
# Loaded dia148utt4_concatenated.npy
# Loaded dia859utt2_concatenated.npy
# Loaded dia800utt6_concatenated.npy
# Loaded dia407utt8_concatenated.npy
# Loaded dia662utt3_concatenated.npy
# Loaded dia536utt1_concatenated.npy
# Loaded dia971utt5_concatenated.npy
# Loaded dia228utt1_concatenated.npy
# Loaded dia414utt3_concatenated.npy
# Loaded dia392utt3_concatenated.npy
# Loaded dia67utt7_concatenated.npy
# Loaded dia668utt6_concatenated.npy
# Loaded dia858utt11_concatenated.npy
# Loaded dia343utt2_concatenated.npy
# Loaded dia526utt4_concatenated.npy
# Loaded dia1011utt4_concatenated.npy
# Loaded dia234utt2_concatenated.npy
# Loaded dia705utt6_concatenated.npy
# Loaded dia891utt17_concatenated.npy
# Loaded dia540utt13_concatenated.npy
# Loaded dia1160utt7_concatenated.npy
# Loaded dia927utt9_concatenated.npy
# Loaded dia133utt1_concatenated.npy
# Loaded dia47utt10_concatenated.npy
# Loaded dia310utt3_concatenated.npy
# Loaded dia932utt1_concatenated.npy
# Loaded dia384utt5_concatenated.npy
# Loaded dia1261utt7_concatenated.npy
# Loaded dia859utt14_concatenated.npy
# Loaded dia821utt17_concatenated.npy
# Loaded dia135utt2_concatenated.npy
# Loaded dia750utt4_concatenated.npy
# Loaded dia261utt16_concatenated.npy
# Loaded dia1294utt4_concatenated.npy
# Loaded dia909utt12_concatenated.npy
# Loaded dia1199utt2_concatenated.npy
# Loaded dia473utt11_concatenated.npy
# Loaded dia793utt18_concatenated.npy
# Loaded dia225utt11_concatenated.npy
# Loaded dia512utt3_concatenated.npy
# Loaded dia294utt3_concatenated.npy
# Loaded dia586utt5_concatenated.npy
# Loaded dia1371utt1_concatenated.npy
# Loaded dia724utt9_concatenated.npy
# Loaded dia764utt3_concatenated.npy
# Loaded dia547utt1_concatenated.npy
# Loaded dia101utt5_concatenated.npy
# Loaded dia817utt12_concatenated.npy
# Loaded dia959utt1_concatenated.npy
# Loaded dia88utt4_concatenated.npy
# Loaded dia298utt5_concatenated.npy
# Loaded dia1298utt2_concatenated.npy
# Loaded dia1195utt4_concatenated.npy
# Loaded dia473utt12_concatenated.npy
# Loaded dia49utt3_concatenated.npy
# Loaded dia586utt6_concatenated.npy
# Loaded dia1371utt2_concatenated.npy
# Loaded dia1331utt8_concatenated.npy
# Loaded dia225utt12_concatenated.npy
# Loaded dia1294utt7_concatenated.npy
# Loaded dia261utt15_concatenated.npy
# Loaded dia16utt4_concatenated.npy
# Loaded dia1199utt1_concatenated.npy
# Loaded dia909utt11_concatenated.npy
# Loaded dia1298utt1_concatenated.npy
# Loaded dia586utt18_concatenated.npy
# Loaded dia1195utt7_concatenated.npy
# Loaded dia101utt6_concatenated.npy
# Loaded dia547utt2_concatenated.npy
# Loaded dia298utt6_concatenated.npy
# Loaded dia88utt7_concatenated.npy
# Loaded dia959utt2_concatenated.npy
# Loaded dia817utt11_concatenated.npy
# Loaded dia62utt9_concatenated.npy
# Loaded dia1160utt4_concatenated.npy
# Loaded dia705utt5_concatenated.npy
# Loaded dia234utt1_concatenated.npy
# Loaded dia816utt3_concatenated.npy
# Loaded dia343utt1_concatenated.npy
# Loaded dia540utt10_concatenated.npy
# Loaded dia448utt9_concatenated.npy
# Loaded dia891utt14_concatenated.npy
# Loaded dia749utt9_concatenated.npy
# Loaded dia821utt14_concatenated.npy
# Loaded dia750utt7_concatenated.npy
# Loaded dia261utt3_concatenated.npy
# Loaded dia135utt1_concatenated.npy
# Loaded dia1261utt4_concatenated.npy
# Loaded dia384utt6_concatenated.npy
# Loaded dia932utt2_concatenated.npy
# Loaded dia133utt2_concatenated.npy
# Loaded dia47utt13_concatenated.npy
# Loaded dia859utt17_concatenated.npy
# Loaded dia971utt6_concatenated.npy
# Loaded dia536utt2_concatenated.npy
# Loaded dia353utt4_concatenated.npy
# Loaded dia859utt1_concatenated.npy
# Loaded dia58utt20_concatenated.npy
# Loaded dia800utt5_concatenated.npy
# Loaded dia67utt4_concatenated.npy
# Loaded dia668utt5_concatenated.npy
# Loaded dia228utt2_concatenated.npy
# Loaded dia473utt6_concatenated.npy
# Loaded dia1223utt21_concatenated.npy
# Loaded dia943utt2_concatenated.npy
# Loaded dia604utt10_concatenated.npy
# Loaded dia988utt3_concatenated.npy
# Loaded dia598utt10_concatenated.npy
# Loaded dia779utt14_concatenated.npy
# Loaded dia327utt9_concatenated.npy
# Loaded dia210utt3_concatenated.npy
# Loaded dia867utt3_concatenated.npy
# Loaded dia603utt5_concatenated.npy
# Loaded dia1245utt14_concatenated.npy
# Loaded dia1060utt7_concatenated.npy
# Loaded dia148utt7_concatenated.npy
# Loaded dia838utt4_concatenated.npy
# Loaded dia455utt14_concatenated.npy
# Loaded dia667utt14_concatenated.npy
# Loaded dia1245utt6_concatenated.npy
# Loaded dia1185utt2_concatenated.npy
# Loaded dia591utt5_concatenated.npy
# Loaded dia988utt11_concatenated.npy
# Loaded dia862utt16_concatenated.npy
# Loaded dia779utt6_concatenated.npy
# Loaded dia58utt3_concatenated.npy
# Loaded dia1331utt20_concatenated.npy
# Loaded dia833utt4_concatenated.npy
# Loaded dia145utt4_concatenated.npy
# Loaded dia1320utt8_concatenated.npy
# Loaded dia1360utt2_concatenated.npy
# Loaded dia421utt2_concatenated.npy
# Loaded dia461utt8_concatenated.npy
# Loaded dia67utt15_concatenated.npy
# Loaded dia749utt11_concatenated.npy
# Loaded dia993utt16_concatenated.npy
# Loaded dia879utt11_concatenated.npy
# Loaded dia406utt15_concatenated.npy
# Loaded dia634utt15_concatenated.npy
# Loaded dia1256utt18_concatenated.npy
# Loaded dia1333utt3_concatenated.npy
# Loaded dia604utt3_concatenated.npy
# Loaded dia733utt9_concatenated.npy
# Loaded dia1064utt18_concatenated.npy
# Loaded dia52utt6_concatenated.npy
# Loaded dia550utt1_concatenated.npy
# Loaded dia225utt1_concatenated.npy
# Loaded dia1223utt5_concatenated.npy
# Loaded dia241utt13_concatenated.npy
# Loaded dia807utt3_concatenated.npy
# Loaded dia1059utt3_concatenated.npy
# Loaded dia858utt4_concatenated.npy
# Loaded dia531utt4_concatenated.npy
# Loaded dia239utt10_concatenated.npy
# Loaded dia1225utt6_concatenated.npy
# Loaded dia314utt8_concatenated.npy
# Loaded dia1171utt4_concatenated.npy
# Loaded dia630utt4_concatenated.npy
# Loaded dia122utt2_concatenated.npy
# Loaded dia363utt17_concatenated.npy
# Loaded dia793utt8_concatenated.npy
# Loaded dia932utt10_concatenated.npy
# Loaded dia358utt4_concatenated.npy
# Loaded dia718utt3_concatenated.npy
# Loaded dia758utt9_concatenated.npy
# Loaded dia790utt14_concatenated.npy
# Loaded dia448utt13_concatenated.npy
# Loaded dia20utt8_concatenated.npy
# Loaded dia1055utt5_concatenated.npy
# Loaded dia327utt10_concatenated.npy
# Loaded dia481utt3_concatenated.npy
# Loaded dia636utt7_concatenated.npy
# Loaded dia124utt1_concatenated.npy
# Loaded dia1122utt5_concatenated.npy
# Loaded dia415utt5_concatenated.npy
# Loaded dia584utt12_concatenated.npy
# Loaded dia279utt23_concatenated.npy
# Loaded dia885utt3_concatenated.npy
# Loaded dia702utt3_concatenated.npy
# Loaded dia1010utt2_concatenated.npy
# Loaded dia790utt6_concatenated.npy
# Loaded dia817utt6_concatenated.npy
# Loaded dia342utt4_concatenated.npy
# Loaded dia939utt2_concatenated.npy
# Loaded dia789utt8_concatenated.npy
# Loaded dia643utt18_concatenated.npy
# Loaded dia279utt8_concatenated.npy
# Loaded dia239utt2_concatenated.npy
# Loaded dia896utt8_concatenated.npy
# Loaded dia134utt4_concatenated.npy
# Loaded dia1311utt2_concatenated.npy
# Loaded dia844utt7_concatenated.npy
# Loaded dia889utt5_concatenated.npy
# Loaded dia836utt12_concatenated.npy
# Loaded dia348utt1_concatenated.npy
# Loaded dia519utt10_concatenated.npy
# Loaded dia1293utt1_concatenated.npy
# Loaded dia464utt5_concatenated.npy
# Loaded dia1143utt13_concatenated.npy
# Loaded dia241utt9_concatenated.npy
# Loaded dia1046utt14_concatenated.npy
# Loaded dia800utt17_concatenated.npy
# Loaded dia407utt10_concatenated.npy
# Loaded dia993utt6_concatenated.npy
# Loaded dia365utt8_concatenated.npy
# Loaded dia540utt4_concatenated.npy
# Loaded dia1194utt2_concatenated.npy
# Loaded dia836utt9_concatenated.npy
# Loaded dia431utt7_concatenated.npy
# Loaded dia901utt3_concatenated.npy
# Loaded dia89utt10_concatenated.npy
# Loaded dia299utt3_concatenated.npy
# Loaded dia89utt2_concatenated.npy
# Loaded dia228utt3_concatenated.npy
# Loaded dia392utt1_concatenated.npy
# Loaded dia414utt1_concatenated.npy
# Loaded dia67utt5_concatenated.npy
# Loaded dia1012utt8_concatenated.npy
# Loaded dia668utt4_concatenated.npy
# Loaded dia800utt4_concatenated.npy
# Loaded dia536utt3_concatenated.npy
# Loaded dia971utt7_concatenated.npy
# Loaded dia353utt5_concatenated.npy
# Loaded dia662utt1_concatenated.npy
# Loaded dia455utt15_concatenated.npy
# Loaded dia838utt5_concatenated.npy
# Loaded dia667utt15_concatenated.npy
# Loaded dia508utt1_concatenated.npy
# Loaded dia691utt1_concatenated.npy
# Loaded dia1185utt3_concatenated.npy
# Loaded dia1245utt7_concatenated.npy
# Loaded dia603utt4_concatenated.npy
# Loaded dia111utt2_concatenated.npy
# Loaded dia867utt2_concatenated.npy
# Loaded dia1060utt6_concatenated.npy
# Loaded dia1245utt15_concatenated.npy
# Loaded dia148utt6_concatenated.npy
# Loaded dia988utt2_concatenated.npy
# Loaded dia779utt15_concatenated.npy
# Loaded dia598utt11_concatenated.npy
# Loaded dia327utt8_concatenated.npy
# Loaded dia502utt4_concatenated.npy
# Loaded dia210utt2_concatenated.npy
# Loaded dia473utt7_concatenated.npy
# Loaded dia943utt3_concatenated.npy
# Loaded dia1223utt20_concatenated.npy
# Loaded dia101utt7_concatenated.npy
# Loaded dia764utt1_concatenated.npy
# Loaded dia547utt3_concatenated.npy
# Loaded dia195utt1_concatenated.npy
# Loaded dia298utt7_concatenated.npy
# Loaded dia88utt6_concatenated.npy
# Loaded dia817utt10_concatenated.npy
# Loaded dia959utt3_concatenated.npy
# Loaded dia1195utt6_concatenated.npy
# Loaded dia1294utt6_concatenated.npy
# Loaded dia261utt14_concatenated.npy
# Loaded dia16utt5_concatenated.npy
# Loaded dia1023utt2_concatenated.npy
# Loaded dia909utt10_concatenated.npy
# Loaded dia473utt13_concatenated.npy
# Loaded dia49utt2_concatenated.npy
# Loaded dia1331utt9_concatenated.npy
# Loaded dia1371utt3_concatenated.npy
# Loaded dia586utt7_concatenated.npy
# Loaded dia294utt1_concatenated.npy
# Loaded dia225utt13_concatenated.npy
# Loaded dia512utt1_concatenated.npy
# Loaded dia932utt3_concatenated.npy
# Loaded dia1261utt5_concatenated.npy
# Loaded dia384utt7_concatenated.npy
# Loaded dia47utt12_concatenated.npy
# Loaded dia133utt3_concatenated.npy
# Loaded dia310utt1_concatenated.npy
# Loaded dia859utt16_concatenated.npy
# Loaded dia749utt8_concatenated.npy
# Loaded dia821utt15_concatenated.npy
# Loaded dia261utt2_concatenated.npy
# Loaded dia750utt6_concatenated.npy
# Loaded dia526utt6_concatenated.npy
# Loaded dia705utt4_concatenated.npy
# Loaded dia816utt2_concatenated.npy
# Loaded dia540utt11_concatenated.npy
# Loaded dia448utt8_concatenated.npy
# Loaded dia891utt15_concatenated.npy
# Loaded dia62utt8_concatenated.npy
# Loaded dia166utt1_concatenated.npy
# Loaded dia1160utt5_concatenated.npy
# Loaded dia1360utt14_concatenated.npy
# Loaded dia844utt6_concatenated.npy
# Loaded dia889utt4_concatenated.npy
# Loaded dia239utt3_concatenated.npy
# Loaded dia279utt9_concatenated.npy
# Loaded dia643utt19_concatenated.npy
# Loaded dia572utt1_concatenated.npy
# Loaded dia896utt9_concatenated.npy
# Loaded dia134utt5_concatenated.npy
# Loaded dia1311utt3_concatenated.npy
# Loaded dia1010utt3_concatenated.npy
# Loaded dia883utt1_concatenated.npy
# Loaded dia817utt7_concatenated.npy
# Loaded dia790utt7_concatenated.npy
# Loaded dia342utt5_concatenated.npy
# Loaded dia939utt3_concatenated.npy
# Loaded dia789utt9_concatenated.npy
# Loaded dia584utt13_concatenated.npy
# Loaded dia279utt22_concatenated.npy
# Loaded dia702utt2_concatenated.npy
# Loaded dia885utt2_concatenated.npy
# Loaded dia836utt8_concatenated.npy
# Loaded dia431utt6_concatenated.npy
# Loaded dia901utt2_concatenated.npy
# Loaded dia89utt11_concatenated.npy
# Loaded dia299utt2_concatenated.npy
# Loaded dia89utt3_concatenated.npy
# Loaded dia407utt11_concatenated.npy
# Loaded dia800utt16_concatenated.npy
# Loaded dia519utt1_concatenated.npy
# Loaded dia365utt9_concatenated.npy
# Loaded dia993utt7_concatenated.npy
# Loaded dia1194utt3_concatenated.npy
# Loaded dia540utt5_concatenated.npy
# Loaded dia519utt11_concatenated.npy
# Loaded dia464utt4_concatenated.npy
# Loaded dia1143utt12_concatenated.npy
# Loaded dia241utt8_concatenated.npy
# Loaded dia406utt14_concatenated.npy
# Loaded dia634utt14_concatenated.npy
# Loaded dia604utt2_concatenated.npy
# Loaded dia1333utt2_concatenated.npy
# Loaded dia1256utt19_concatenated.npy
# Loaded dia1064utt19_concatenated.npy
# Loaded dia733utt8_concatenated.npy
# Loaded dia461utt9_concatenated.npy
# Loaded dia421utt3_concatenated.npy
# Loaded dia67utt14_concatenated.npy
# Loaded dia749utt10_concatenated.npy
# Loaded dia993utt17_concatenated.npy
# Loaded dia879utt10_concatenated.npy
# Loaded dia58utt2_concatenated.npy
# Loaded dia779utt7_concatenated.npy
# Loaded dia145utt5_concatenated.npy
# Loaded dia1360utt3_concatenated.npy
# Loaded dia1320utt9_concatenated.npy
# Loaded dia1331utt21_concatenated.npy
# Loaded dia1143utt1_concatenated.npy
# Loaded dia591utt4_concatenated.npy
# Loaded dia988utt10_concatenated.npy
# Loaded dia758utt8_concatenated.npy
# Loaded dia718utt2_concatenated.npy
# Loaded dia448utt12_concatenated.npy
# Loaded dia481utt2_concatenated.npy
# Loaded dia20utt9_concatenated.npy
# Loaded dia327utt11_concatenated.npy
# Loaded dia1055utt4_concatenated.npy
# Loaded dia415utt4_concatenated.npy
# Loaded dia1122utt4_concatenated.npy
# Loaded dia636utt6_concatenated.npy
# Loaded dia276utt1_concatenated.npy
# Loaded dia793utt9_concatenated.npy
# Loaded dia630utt5_concatenated.npy
# Loaded dia122utt3_concatenated.npy
# Loaded dia363utt16_concatenated.npy
# Loaded dia932utt11_concatenated.npy
# Loaded dia358utt5_concatenated.npy
# Loaded dia858utt5_concatenated.npy
# Loaded dia1128utt1_concatenated.npy
# Loaded dia1225utt7_concatenated.npy
# Loaded dia239utt11_concatenated.npy
# Loaded dia531utt5_concatenated.npy
# Loaded dia314utt9_concatenated.npy
# Loaded dia801utt1_concatenated.npy
# Loaded dia1171utt5_concatenated.npy
# Loaded dia1223utt4_concatenated.npy
# Loaded dia807utt2_concatenated.npy
# Loaded dia241utt12_concatenated.npy
# Loaded dia1059utt2_concatenated.npy
# Loaded 11053 train embeddings
# Loaded 2566 test embeddings

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder


emotions_csv_path = '/project/msoleyma_1026/ecp-cause-pair/script_mlp/assets/video_emotion_combined.csv'
emotions_df = pd.read_csv(emotions_csv_path)
emotion_dict = {row['video_name'].split('.')[0]: row['emotion'] for _, row in emotions_df.iterrows()}

def map_embeddings_to_emotions(file_names, emotion_dict):
    emotions = []
    for file_name in file_names:
        # Extract the video name without the file extension
        video_name = file_name.split('_concatenated')[0]
        # Map the video name to its corresponding emotion
        emotion = emotion_dict.get(video_name, 'Unknown')
        emotions.append(emotion)
    return emotions

# Function to load all .npy files from a directory and return embeddings with their file names
def load_embeddings_and_names(directory):
    embeddings = []
    names = []
    for filename in os.listdir(directory):
        if filename.endswith('.npy'):
            file_path = os.path.join(directory, filename)
            embedding = np.load(file_path)
            embeddings.append(embedding)
            names.append(filename.split('_concatenated.npy')[0])
            print(f'Loaded {filename}')
    return embeddings, names

# Load the embeddings and their file names
train_embeddings, train_files = load_embeddings_and_names(train_dir)
test_embeddings, test_files = load_embeddings_and_names(test_dir)

# map the file names to emotions
Y_train = map_embeddings_to_emotions(train_files, emotion_dict)
Y_test = map_embeddings_to_emotions(test_files, emotion_dict)
# Out:
# Loaded dia116utt4_concatenated.npy
# Loaded dia61utt2_concatenated.npy
# Loaded dia644utt8_concatenated.npy
# Loaded dia21utt8_concatenated.npy
# Loaded dia983utt2_concatenated.npy
# Loaded dia607utt15_concatenated.npy
# Loaded dia860utt4_concatenated.npy
# Loaded dia690utt4_concatenated.npy
# Loaded dia530utt12_concatenated.npy
# Loaded dia917utt4_concatenated.npy
# Loaded dia182utt2_concatenated.npy
# Loaded dia409utt11_concatenated.npy
# Loaded dia773utt2_concatenated.npy
# Loaded dia1279utt5_concatenated.npy
# Loaded dia1031utt12_concatenated.npy
# Loaded dia38utt6_concatenated.npy
# Loaded dia1097utt5_concatenated.npy
# Loaded dia1108utt11_concatenated.npy
# Loaded dia1134utt9_concatenated.npy
# Loaded dia1203utt12_concatenated.npy
# Loaded dia1003utt3_concatenated.npy
# Loaded dia168utt16_concatenated.npy
# Loaded dia509utt4_concatenated.npy
# Loaded dia1220utt1_concatenated.npy
# Loaded dia389utt12_concatenated.npy
# Loaded dia149utt3_concatenated.npy
# Loaded dia1091utt6_concatenated.npy
# Loaded dia1351utt2_concatenated.npy
# Loaded dia478utt7_concatenated.npy
# Loaded dia948utt3_concatenated.npy
# Loaded dia1049utt11_concatenated.npy
# Loaded dia227utt12_concatenated.npy
# Loaded dia1226utt2_concatenated.npy
# Loaded dia1170utt12_concatenated.npy
# Loaded dia1088utt8_concatenated.npy
# Loaded dia985utt1_concatenated.npy
# Loaded dia602utt1_concatenated.npy
# Loaded dia1308utt6_concatenated.npy
# Loaded dia471utt12_concatenated.npy
# Loaded dia795utt11_concatenated.npy
# Loaded dia911utt7_concatenated.npy
# Loaded dia556utt3_concatenated.npy
# Loaded dia244utt5_concatenated.npy
# Loaded dia184utt1_concatenated.npy
# Loaded dia775utt1_concatenated.npy
# Loaded dia597utt7_concatenated.npy
# Loaded dia617utt9_concatenated.npy
# Loaded dia72utt9_concatenated.npy
# Loaded dia32utt3_concatenated.npy
# Loaded dia285utt1_concatenated.npy
# Loaded dia618utt18_concatenated.npy
# Loaded dia474utt1_concatenated.npy
# Loaded dia503utt1_concatenated.npy
# Loaded dia1009utt6_concatenated.npy
# Loaded dia928utt18_concatenated.npy
# Loaded dia453utt20_concatenated.npy
# Loaded dia989utt7_concatenated.npy
# Loaded dia1167utt8_concatenated.npy
# Loaded dia1127utt2_concatenated.npy
# Loaded dia1016utt11_concatenated.npy
# Loaded dia248utt3_concatenated.npy
# Loaded dia1319utt18_concatenated.npy
# Loaded dia1050utt2_concatenated.npy
# Loaded dia1224utt11_concatenated.npy
# Loaded dia1302utt3_concatenated.npy
# Loaded dia608utt4_concatenated.npy
# Loaded dia1081utt12_concatenated.npy
# Loaded dia1121utt1_concatenated.npy
# Loaded dia1260utt16_concatenated.npy
# Loaded dia1056utt1_concatenated.npy
# Loaded dia339utt12_concatenated.npy
# Loaded dia1275utt3_concatenated.npy
# Loaded dia305utt16_concatenated.npy
# Loaded dia456utt11_concatenated.npy
# Loaded dia283utt2_concatenated.npy
# Loaded dia472utt2_concatenated.npy
# Loaded dia432utt8_concatenated.npy
# Loaded dia1178utt5_concatenated.npy
# Loaded dia360utt4_concatenated.npy
# Loaded dia505utt2_concatenated.npy
# Loaded dia93utt13_concatenated.npy
# Loaded dia741utt6_concatenated.npy
# Loaded dia945utt17_concatenated.npy
# Loaded dia979utt13_concatenated.npy
# Loaded dia393utt4_concatenated.npy
# Loaded dia562utt4_concatenated.npy
# Loaded dia1068utt3_concatenated.npy
# Loaded dia270utt2_concatenated.npy
# Loaded dia307utt2_concatenated.npy
# Loaded dia347utt8_concatenated.npy
# Loaded dia82utt15_concatenated.npy
# Loaded dia53utt6_concatenated.npy
# Loaded dia1212utt5_concatenated.npy
# Loaded dia1090utt14_concatenated.npy
# Loaded dia8utt7_concatenated.npy
# Loaded dia1031utt7_concatenated.npy
# Loaded dia229utt6_concatenated.npy
# Loaded dia1271utt10_concatenated.npy
# Loaded dia1146utt7_concatenated.npy
# Loaded dia899utt1_concatenated.npy
# Loaded dia1214utt6_concatenated.npy
# Loaded dia1102utt10_concatenated.npy
# Loaded dia255utt10_concatenated.npy
# Loaded dia98utt7_concatenated.npy
# Loaded dia1037utt4_concatenated.npy
# Loaded dia1140utt4_concatenated.npy
# Loaded dia1330utt10_concatenated.npy
# Loaded dia1363utt6_concatenated.npy
# Loaded dia669utt1_concatenated.npy
# Loaded dia487utt1_concatenated.npy
# Loaded dia747utt5_concatenated.npy
# Loaded dia81utt9_concatenated.npy
# Loaded dia564utt7_concatenated.npy
# Loaded dia963utt9_concatenated.npy
# Loaded dia923utt3_concatenated.npy
# Loaded dia708utt13_concatenated.npy
# Loaded dia301utt1_concatenated.npy
# Loaded dia413utt7_concatenated.npy
# Loaded dia814utt9_concatenated.npy
# Loaded dia403utt10_concatenated.npy
# Loaded dia15utt16_concatenated.npy
# Loaded dia162utt9_concatenated.npy
# Loaded dia55utt5_concatenated.npy
# Loaded dia863utt19_concatenated.npy
# Loaded dia2utt2_concatenated.npy
# Loaded dia895utt7_concatenated.npy
# Loaded dia712utt7_concatenated.npy
# Loaded dia76utt12_concatenated.npy
# Loaded dia263utt9_concatenated.npy
# Loaded dia223utt3_concatenated.npy
# Loaded dia94utt1_concatenated.npy
# Loaded dia976utt1_concatenated.npy
# Loaded dia446utt5_concatenated.npy
# Loaded dia757utt13_concatenated.npy
# Loaded dia786utt1_concatenated.npy
# Loaded dia354utt3_concatenated.npy
# Loaded dia99utt12_concatenated.npy
# Loaded dia652utt14_concatenated.npy
# Loaded dia177utt1_concatenated.npy
# Loaded dia399utt1_concatenated.npy
# Loaded dia1241utt4_concatenated.npy
# Loaded dia1062utt6_concatenated.npy
# Loaded dia568utt1_concatenated.npy
# Loaded dia1115utt6_concatenated.npy
# Loaded dia236utt14_concatenated.npy
# Loaded dia59utt3_concatenated.npy
# Loaded dia1336utt4_concatenated.npy
# Loaded dia19utt9_concatenated.npy
# Loaded dia1247utt7_concatenated.npy
# Loaded dia1121utt19_concatenated.npy
# Loaded dia272utt13_concatenated.npy
# Loaded dia929utt6_concatenated.npy
# Loaded dia459utt8_concatenated.npy
# Loaded dia1113utt5_concatenated.npy
# Loaded dia419utt2_concatenated.npy
# Loaded dia1330utt7_concatenated.npy
# Loaded dia398utt14_concatenated.npy
# Loaded dia128utt6_concatenated.npy
# Loaded dia714utt4_concatenated.npy
# Loaded dia4utt1_concatenated.npy
# Loaded dia893utt4_concatenated.npy
# Loaded dia970utt2_concatenated.npy
# Loaded dia930utt8_concatenated.npy
# Loaded dia537utt6_concatenated.npy
# Loaded dia92utt2_concatenated.npy
# Loaded dia780utt2_concatenated.npy
# Loaded dia521utt14_concatenated.npy
# Loaded dia847utt8_concatenated.npy
# Loaded dia440utt6_concatenated.npy
# Loaded dia663utt4_concatenated.npy
# Loaded dia926utt13_concatenated.npy
# Loaded dia1369utt3_concatenated.npy
# Loaded dia171utt2_concatenated.npy
# Loaded dia131utt8_concatenated.npy
# Loaded dia1006utt12_concatenated.npy
# Loaded dia1027utt1_concatenated.npy
# Loaded dia1103utt15_concatenated.npy
# Loaded dia268utt11_concatenated.npy
# Loaded dia1204utt3_concatenated.npy
# Loaded dia1244utt9_concatenated.npy
# Loaded dia1230utt18_concatenated.npy
# Loaded dia1373utt3_concatenated.npy
# Loaded dia679utt4_concatenated.npy
# Loaded dia287utt11_concatenated.npy
# Loaded dia1290utt5_concatenated.npy
# Loaded dia382utt16_concatenated.npy
# Loaded dia266utt4_concatenated.npy
# Loaded dia709utt16_concatenated.npy
# Loaded dia735utt12_concatenated.npy
# Loaded dia574utt2_concatenated.npy
# Loaded dia385utt2_concatenated.npy
# Loaded dia497utt4_concatenated.npy
# Loaded dia839utt16_concatenated.npy
# Loaded dia132utt6_concatenated.npy
# Loaded dia14utt13_concatenated.npy
# Loaded dia403utt2_concatenated.npy
# Loaded dia1109utt5_concatenated.npy
# Loaded dia311utt4_concatenated.npy
# Loaded dia260utt7_concatenated.npy
# Loaded dia1078utt6_concatenated.npy
# Loaded dia935utt5_concatenated.npy
# Loaded dia383utt1_concatenated.npy
# Loaded dia446utt12_concatenated.npy
# Loaded dia491utt7_concatenated.npy
# Loaded dia711utt9_concatenated.npy
# Loaded dia751utt3_concatenated.npy
# Loaded dia666utt9_concatenated.npy
# Loaded dia626utt3_concatenated.npy
# Loaded dia771utt15_concatenated.npy
# Loaded dia997utt16_concatenated.npy
# Loaded dia83utt10_concatenated.npy
# Loaded dia405utt1_concatenated.npy
# Loaded dia842utt5_concatenated.npy
# Loaded dia317utt7_concatenated.npy
# Loaded dia127utt15_concatenated.npy
# Loaded dia1270utt15_concatenated.npy
# Loaded dia1021utt2_concatenated.npy
# Loaded dia708utt7_concatenated.npy
# Loaded dia329utt11_concatenated.npy
# Loaded dia1296utt6_concatenated.npy
# Loaded dia979utt9_concatenated.npy
# Loaded dia1197utt6_concatenated.npy
# Loaded dia1217utt8_concatenated.npy
# Loaded dia1257utt2_concatenated.npy
# Loaded dia232utt20_concatenated.npy
# Loaded dia376utt11_concatenated.npy
# Loaded dia138utt3_concatenated.npy
# Loaded dia1316utt16_concatenated.npy
# Loaded dia409utt7_concatenated.npy
# Loaded dia144utt11_concatenated.npy
# Loaded dia82utt7_concatenated.npy
# Loaded dia527utt3_concatenated.npy
# Loaded dia235utt5_concatenated.npy
# Loaded dia704utt1_concatenated.npy
# Loaded dia396utt9_concatenated.npy
# Loaded dia673utt1_concatenated.npy
# Loaded dia33utt10_concatenated.npy
# Loaded dia520utt11_concatenated.npy
# Loaded dia450utt3_concatenated.npy
# Loaded dia822utt11_concatenated.npy
# Loaded dia966utt4_concatenated.npy
# Loaded dia84utt4_concatenated.npy
# Loaded dia785utt12_concatenated.npy
# Loaded dia233utt6_concatenated.npy
# Loaded dia1208utt5_concatenated.npy
# Loaded dia167utt4_concatenated.npy
# Loaded dia675utt2_concatenated.npy
# Loaded dia10utt2_concatenated.npy
# Loaded dia344utt6_concatenated.npy
# Loaded dia796utt4_concatenated.npy
# Loaded dia811utt4_concatenated.npy
# Loaded dia1072utt3_concatenated.npy
# Loaded dia1032utt9_concatenated.npy
# Loaded dia1251utt1_concatenated.npy
# Loaded dia389utt4_concatenated.npy
# Loaded dia1326utt1_concatenated.npy
# Loaded dia1105utt3_concatenated.npy
# Loaded dia1145utt9_concatenated.npy
# Loaded dia1162utt5_concatenated.npy
# Loaded dia468utt2_concatenated.npy
# Loaded dia1081utt3_concatenated.npy
# Loaded dia1048utt14_concatenated.npy
# Loaded dia1015utt5_concatenated.npy
# Loaded dia323utt10_concatenated.npy
# Loaded dia876utt2_concatenated.npy
# Loaded dia77utt4_concatenated.npy
# Loaded dia612utt4_concatenated.npy
# Loaded dia995utt4_concatenated.npy
# Loaded dia100utt2_concatenated.npy
# Loaded dia877utt10_concatenated.npy
# Loaded dia140utt8_concatenated.npy
# Loaded dia575utt10_concatenated.npy
# Loaded dia549utt14_concatenated.npy
# Loaded dia765utt4_concatenated.npy
# Loaded dia194utt4_concatenated.npy
# Loaded dia747utt10_concatenated.npy
# Loaded dia686utt2_concatenated.npy
# Loaded dia546utt6_concatenated.npy
# Loaded dia941utt8_concatenated.npy
# Loaded dia870utt1_concatenated.npy
# Loaded dia437utt5_concatenated.npy
# Loaded dia606utt10_concatenated.npy
# Loaded dia325utt3_concatenated.npy
# Loaded dia594utt9_concatenated.npy
# Loaded dia614utt7_concatenated.npy
# Loaded dia71utt7_concatenated.npy
# Loaded dia106utt1_concatenated.npy
# Loaded dia763utt7_concatenated.npy
# Loaded dia434utt10_concatenated.npy
# Loaded dia408utt14_concatenated.npy
# Loaded dia252utt3_concatenated.npy
# Loaded dia907utt1_concatenated.npy
# Loaded dia680utt1_concatenated.npy
# Loaded dia186utt13_concatenated.npy
# Loaded dia1164utt6_concatenated.npy
# Loaded dia829utt5_concatenated.npy
# Loaded dia1109utt14_concatenated.npy
# Loaded dia28utt3_concatenated.npy
# Loaded dia1347utt4_concatenated.npy
# Loaded dia388utt17_concatenated.npy
# Loaded dia1230utt4_concatenated.npy
# Loaded dia1013utt6_concatenated.npy
# Loaded dia136utt13_concatenated.npy
# Loaded dia329utt5_concatenated.npy
# Loaded dia1131utt4_concatenated.npy
# Loaded dia1312utt6_concatenated.npy
# Loaded dia618utt1_concatenated.npy
# Loaded dia1265utt6_concatenated.npy
# Loaded dia1057utt19_concatenated.npy
# Loaded dia370utt1_concatenated.npy
# Loaded dia865utt9_concatenated.npy
# Loaded dia825utt3_concatenated.npy
# Loaded dia41utt12_concatenated.npy
# Loaded dia45utt18_concatenated.npy
# Loaded dia153utt3_concatenated.npy
# Loaded dia581utt1_concatenated.npy
# Loaded dia641utt5_concatenated.npy
# Loaded dia736utt5_concatenated.npy
# Loaded dia92utt16_concatenated.npy
# Loaded dia515utt7_concatenated.npy
# Loaded dia952utt3_concatenated.npy
# Loaded dia659utt10_concatenated.npy
# Loaded dia695utt9_concatenated.npy
# Loaded dia207utt1_concatenated.npy
# Loaded dia376utt2_concatenated.npy
# Loaded dia336utt8_concatenated.npy
# Loaded dia621utt13_concatenated.npy
# Loaded dia647utt6_concatenated.npy
# Loaded dia587utt2_concatenated.npy
# Loaded dia828utt10_concatenated.npy
# Loaded dia730utt6_concatenated.npy
# Loaded dia814utt14_concatenated.npy
# Loaded dia513utt4_concatenated.npy
# Loaded dia201utt2_concatenated.npy
# Loaded dia1137utt7_concatenated.npy
# Loaded dia1314utt5_concatenated.npy
# Loaded dia999utt2_concatenated.npy
# Loaded dia729utt8_concatenated.npy
# Loaded dia1219utt10_concatenated.npy
# Loaded dia769utt2_concatenated.npy
# Loaded dia1324utt19_concatenated.npy
# Loaded dia1040utt7_concatenated.npy
# Loaded dia198utt2_concatenated.npy
# Loaded dia258utt6_concatenated.npy
# Loaded dia393utt10_concatenated.npy
# Loaded dia469utt7_concatenated.npy
# Loaded dia142utt11_concatenated.npy
# Loaded dia1340utt2_concatenated.npy
# Loaded dia1328utt18_concatenated.npy
# Loaded dia1080utt6_concatenated.npy
# Loaded dia1310utt16_concatenated.npy
# Loaded dia158utt3_concatenated.npy
# Loaded dia1027utt11_concatenated.npy
# Loaded dia370utt11_concatenated.npy
# Loaded dia1277utt8_concatenated.npy
# Loaded dia249utt12_concatenated.npy
# Loaded dia877utt7_concatenated.npy
# Loaded dia470utt9_concatenated.npy
# Loaded dia1319utt6_concatenated.npy
# Loaded dia76utt1_concatenated.npy
# Loaded dia613utt1_concatenated.npy
# Loaded dia35utt10_concatenated.npy
# Loaded dia994utt1_concatenated.npy
# Loaded dia611utt16_concatenated.npy
# Loaded dia255utt5_concatenated.npy
# Loaded dia871utt4_concatenated.npy
# Loaded dia324utt6_concatenated.npy
# Loaded dia992utt2_concatenated.npy
# Loaded dia655utt11_concatenated.npy
# Loaded dia655utt8_concatenated.npy
# Loaded dia669utt15_concatenated.npy
# Loaded dia30utt8_concatenated.npy
# Loaded dia70utt2_concatenated.npy
# Loaded dia107utt4_concatenated.npy
# Loaded dia562utt16_concatenated.npy
# Loaded dia860utt16_concatenated.npy
# Loaded dia1268utt5_concatenated.npy
# Loaded dia762utt2_concatenated.npy
# Loaded dia686utt15_concatenated.npy
# Loaded dia30utt21_concatenated.npy
# Loaded dia253utt6_concatenated.npy
# Loaded dia965utt11_concatenated.npy
# Loaded dia467utt11_concatenated.npy
# Loaded dia193utt2_concatenated.npy
# Loaded dia906utt4_concatenated.npy
# Loaded dia681utt4_concatenated.npy
# Loaded dia1165utt3_concatenated.npy
# Loaded dia29utt6_concatenated.npy
# Loaded dia1282utt12_concatenated.npy
# Loaded dia1269utt18_concatenated.npy
# Loaded dia1231utt1_concatenated.npy
# Loaded dia1189utt11_concatenated.npy
# Loaded dia518utt4_concatenated.npy
# Loaded dia147utt20_concatenated.npy
# Loaded dia1130utt1_concatenated.npy
# Loaded dia165utt12_concatenated.npy
# Loaded dia1232utt12_concatenated.npy
# Loaded dia619utt4_concatenated.npy
# Loaded dia1224utt9_concatenated.npy
# Loaded dia1264utt3_concatenated.npy
# Loaded dia252utt15_concatenated.npy
# Loaded dia1139utt11_concatenated.npy
# Loaded dia1047utt1_concatenated.npy
# Loaded dia1004utt18_concatenated.npy
# Loaded dia371utt4_concatenated.npy
# Loaded dia438utt11_concatenated.npy
# Loaded dia1169utt5_concatenated.npy
# Loaded dia906utt15_concatenated.npy
# Loaded dia463utt2_concatenated.npy
# Loaded dia292utt2_concatenated.npy
# Loaded dia580utt4_concatenated.npy
# Loaded dia803utt12_concatenated.npy
# Loaded dia80utt21_concatenated.npy
# Loaded dia554utt8_concatenated.npy
# Loaded dia953utt6_concatenated.npy
# Loaded dia514utt2_concatenated.npy
# Loaded dia206utt4_concatenated.npy
# Loaded dia377utt7_concatenated.npy
# Loaded dia596utt11_concatenated.npy
# Loaded dia822utt5_concatenated.npy
# Loaded dia465utt1_concatenated.npy
# Loaded dia493utt16_concatenated.npy
# Loaded dia646utt3_concatenated.npy
# Loaded dia23utt3_concatenated.npy
# Loaded dia606utt9_concatenated.npy
# Loaded dia63utt9_concatenated.npy
# Loaded dia731utt3_concatenated.npy
# Loaded dia771utt9_concatenated.npy
# Loaded dia946utt18_concatenated.npy
# Loaded dia955utt5_concatenated.npy
# Loaded dia180utt9_concatenated.npy
# Loaded dia1176utt8_concatenated.npy
# Loaded dia1078utt11_concatenated.npy
# Loaded dia998utt7_concatenated.npy
# Loaded dia768utt7_concatenated.npy
# Loaded dia1041utt2_concatenated.npy
# Loaded dia1001utt8_concatenated.npy
# Loaded dia1276utt15_concatenated.npy
# Loaded dia199utt7_concatenated.npy
# Loaded dia259utt3_concatenated.npy
# Loaded dia1026utt4_concatenated.npy
# Loaded dia207utt14_concatenated.npy
# Loaded dia888utt1_concatenated.npy
# Loaded dia1069utt17_concatenated.npy
# Loaded dia678utt1_concatenated.npy
# Loaded dia1372utt6_concatenated.npy
# Loaded dia1183utt10_concatenated.npy
# Loaded dia130utt13_concatenated.npy
# Loaded dia267utt1_concatenated.npy
# Loaded dia575utt7_concatenated.npy
# Loaded dia90utt9_concatenated.npy
# Loaded dia482utt10_concatenated.npy
# Loaded dia756utt5_concatenated.npy
# Loaded dia496utt1_concatenated.npy
# Loaded dia44utt5_concatenated.npy
# Loaded dia621utt5_concatenated.npy
# Loaded dia856utt13_concatenated.npy
# Loaded dia429utt17_concatenated.npy
# Loaded dia1039utt9_concatenated.npy
# Loaded dia573utt4_concatenated.npy
# Loaded dia382utt4_concatenated.npy
# Loaded dia490utt2_concatenated.npy
# Loaded dia812utt14_concatenated.npy
# Loaded dia510utt14_concatenated.npy
# Loaded dia627utt6_concatenated.npy
# Loaded dia42utt6_concatenated.npy
# Loaded dia404utt4_concatenated.npy
# Loaded dia356utt8_concatenated.npy
# Loaded dia316utt2_concatenated.npy
# Loaded dia238utt6_concatenated.npy
# Loaded dia709utt2_concatenated.npy
# Loaded dia1203utt5_concatenated.npy
# Loaded dia243utt13_concatenated.npy
# Loaded dia1114utt13_concatenated.npy
# Loaded dia1157utt7_concatenated.npy
# Loaded dia325utt10_concatenated.npy
# Loaded dia938utt6_concatenated.npy
# Loaded dia1075utt5_concatenated.npy
# Loaded dia1196utt3_concatenated.npy
# Loaded dia1177utt17_concatenated.npy
# Loaded dia139utt6_concatenated.npy
# Loaded dia408utt2_concatenated.npy
# Loaded dia1102utt5_concatenated.npy
# Loaded dia83utt2_concatenated.npy
# Loaded dia741utt10_concatenated.npy
# Loaded dia961utt2_concatenated.npy
# Loaded dia644utt17_concatenated.npy
# Loaded dia882utt4_concatenated.npy
# Loaded dia678utt13_concatenated.npy
# Loaded dia120utt8_concatenated.npy
# Loaded dia573utt10_concatenated.npy
# Loaded dia160utt2_concatenated.npy
# Loaded dia871utt10_concatenated.npy
# Loaded dia17utt4_concatenated.npy
# Loaded dia697utt13_concatenated.npy
# Loaded dia948utt13_concatenated.npy
# Loaded dia856utt8_concatenated.npy
# Loaded dia451utt6_concatenated.npy
# Loaded dia792utt14_concatenated.npy
# Loaded dia791utt2_concatenated.npy
# Loaded dia520utt5_concatenated.npy
# Loaded dia967utt1_concatenated.npy
# Loaded dia85utt1_concatenated.npy
# Loaded dia232utt3_concatenated.npy
# Loaded dia272utt9_concatenated.npy
# Loaded dia432utt10_concatenated.npy
# Loaded dia18utt12_concatenated.npy
# Loaded dia930utt10_concatenated.npy
# Loaded dia703utt7_concatenated.npy
# Loaded dia483utt9_concatenated.npy
# Loaded dia884utt7_concatenated.npy
# Loaded dia739utt13_concatenated.npy
# Loaded dia305utt9_concatenated.npy
# Loaded dia797utt1_concatenated.npy
# Loaded dia810utt1_concatenated.npy
# Loaded dia579utt1_concatenated.npy
# Loaded dia1073utt6_concatenated.npy
# Loaded dia1250utt4_concatenated.npy
# Loaded dia388utt1_concatenated.npy
# Loaded dia1327utt4_concatenated.npy
# Loaded dia48utt3_concatenated.npy
# Loaded dia258utt14_concatenated.npy
# Loaded dia264utt10_concatenated.npy
# Loaded dia184utt19_concatenated.npy
# Loaded dia1104utt6_concatenated.npy
# Loaded dia849utt5_concatenated.npy
# Loaded dia740utt3_concatenated.npy
# Loaded dia700utt9_concatenated.npy
# Loaded dia887utt9_concatenated.npy
# Loaded dia1069utt6_concatenated.npy
# Loaded dia924utt5_concatenated.npy
# Loaded dia563utt1_concatenated.npy
# Loaded dia271utt7_concatenated.npy
# Loaded dia723utt11_concatenated.npy
# Loaded dia853utt5_concatenated.npy
# Loaded dia626utt16_concatenated.npy
# Loaded dia125utt5_concatenated.npy
# Loaded dia637utt3_concatenated.npy
# Loaded dia677utt9_concatenated.npy
# Loaded dia12utt9_concatenated.npy
# Loaded dia719utt7_concatenated.npy
# Loaded dia149utt15_concatenated.npy
# Loaded dia9utt2_concatenated.npy
# Loaded dia499utt9_concatenated.npy
# Loaded dia291utt12_concatenated.npy
# Loaded dia1030utt2_concatenated.npy
# Loaded dia268utt9_concatenated.npy
# Loaded dia347utt11_concatenated.npy
# Loaded dia1287utt6_concatenated.npy
# Loaded dia1147utt2_concatenated.npy
# Loaded dia1107utt8_concatenated.npy
# Loaded dia898utt4_concatenated.npy
# Loaded dia1255utt9_concatenated.npy
# Loaded dia303utt16_concatenated.npy
# Loaded dia1215utt3_concatenated.npy
# Loaded dia99utt2_concatenated.npy
# Loaded dia1036utt1_concatenated.npy
# Loaded dia206utt11_concatenated.npy
# Loaded dia131utt16_concatenated.npy
# Loaded dia1141utt1_concatenated.npy
# Loaded dia1281utt5_concatenated.npy
# Loaded dia1363utt11_concatenated.npy
# Loaded dia1362utt3_concatenated.npy
# Loaded dia486utt4_concatenated.npy
# Loaded dia394utt2_concatenated.npy
# Loaded dia483utt15_concatenated.npy
# Loaded dia922utt6_concatenated.npy
# Loaded dia525utt8_concatenated.npy
# Loaded dia565utt2_concatenated.npy
# Loaded dia884utt12_concatenated.npy
# Loaded dia277utt4_concatenated.npy
# Loaded dia857utt16_concatenated.npy
# Loaded dia300utt4_concatenated.npy
# Loaded dia1118utt5_concatenated.npy
# Loaded dia412utt2_concatenated.npy
# Loaded dia123utt6_concatenated.npy
# Loaded dia952utt11_concatenated.npy
# Loaded dia450utt11_concatenated.npy
# Loaded dia788utt16_concatenated.npy
# Loaded dia894utt2_concatenated.npy
# Loaded dia25utt13_concatenated.npy
# Loaded dia3utt7_concatenated.npy
# Loaded dia1219utt5_concatenated.npy
# Loaded dia713utt2_concatenated.npy
# Loaded dia95utt4_concatenated.npy
# Loaded dia977utt4_concatenated.npy
# Loaded dia787utt4_concatenated.npy
# Loaded dia355utt6_concatenated.npy
# Loaded dia624utt8_concatenated.npy
# Loaded dia41utt8_concatenated.npy
# Loaded dia664utt2_concatenated.npy
# Loaded dia738utt16_concatenated.npy
# Loaded dia176utt4_concatenated.npy
# Loaded dia398utt4_concatenated.npy
# Loaded dia1240utt1_concatenated.npy
# Loaded dia1063utt3_concatenated.npy
# Loaded dia1154utt9_concatenated.npy
# Loaded dia1114utt3_concatenated.npy
# Loaded dia1337utt1_concatenated.npy
# Loaded dia360utt12_concatenated.npy
# Loaded dia1246utt2_concatenated.npy
# Loaded dia1206utt8_concatenated.npy
# Loaded dia1186utt6_concatenated.npy
# Loaded dia928utt3_concatenated.npy
# Loaded dia318utt11_concatenated.npy
# Loaded dia418utt7_concatenated.npy
# Loaded dia1340utt18_concatenated.npy
# Loaded dia1344utt12_concatenated.npy
# Loaded dia169utt9_concatenated.npy
# Loaded dia129utt3_concatenated.npy
# Loaded dia387utt9_concatenated.npy
# Loaded dia679utt16_concatenated.npy
# Loaded dia715utt1_concatenated.npy
# Loaded dia892utt1_concatenated.npy
# Loaded dia224utt5_concatenated.npy
# Loaded dia93utt7_concatenated.npy
# Loaded dia781utt7_concatenated.npy
# Loaded dia441utt3_concatenated.npy
# Loaded dia806utt7_concatenated.npy
# Loaded dia1368utt6_concatenated.npy
# Loaded dia117utt1_concatenated.npy
# Loaded dia334utt3_concatenated.npy
# Loaded dia426utt5_concatenated.npy
# Loaded dia861utt1_concatenated.npy
# Loaded dia551utt5_concatenated.npy
# Loaded dia916utt1_concatenated.npy
# Loaded dia183utt7_concatenated.npy
# Loaded dia70utt12_concatenated.npy
# Loaded dia243utt3_concatenated.npy
# Loaded dia466utt14_concatenated.npy
# Loaded dia427utt22_concatenated.npy
# Loaded dia772utt7_concatenated.npy
# Loaded dia1283utt17_concatenated.npy
# Loaded dia1356utt4_concatenated.npy
# Loaded dia39utt3_concatenated.npy
# Loaded dia1175utt6_concatenated.npy
# Loaded dia1062utt13_concatenated.npy
# Loaded dia1355utt14_concatenated.npy
# Loaded dia1369utt10_concatenated.npy
# Loaded dia1188utt14_concatenated.npy
# Loaded dia1221utt4_concatenated.npy
# Loaded dia288utt2_concatenated.npy
# Loaded dia1090utt3_concatenated.npy
# Loaded dia1214utt14_concatenated.npy
# Loaded dia479utt2_concatenated.npy
# Loaded dia439utt8_concatenated.npy
# Loaded dia1173utt5_concatenated.npy
# Loaded dia949utt6_concatenated.npy
# Loaded dia1004utt5_concatenated.npy
# Loaded dia248utt17_concatenated.npy
# Loaded dia151utt8_concatenated.npy
# Loaded dia984utt4_concatenated.npy
# Loaded dia422utt13_concatenated.npy
# Loaded dia66utt4_concatenated.npy
# Loaded dia1349utt9_concatenated.npy
# Loaded dia819utt10_concatenated.npy
# Loaded dia420utt6_concatenated.npy
# Loaded dia827utt8_concatenated.npy
# Loaded dia825utt14_concatenated.npy
# Loaded dia910utt2_concatenated.npy
# Loaded dia697utt2_concatenated.npy
# Loaded dia185utt4_concatenated.npy
# Loaded dia774utt4_concatenated.npy
# Loaded dia8utt17_concatenated.npy
# Loaded dia729utt10_concatenated.npy
# Loaded dia596utt2_concatenated.npy
# Loaded dia656utt6_concatenated.npy
# Loaded dia33utt6_concatenated.npy
# Loaded dia84utt15_concatenated.npy
# Loaded dia284utt4_concatenated.npy
# Loaded dia367utt2_concatenated.npy
# Loaded dia544utt10_concatenated.npy
# Loaded dia1008utt3_concatenated.npy
# Loaded dia1048utt9_concatenated.npy
# Loaded dia721utt6_concatenated.npy
# Loaded dia1305utt5_concatenated.npy
# Loaded dia249utt6_concatenated.npy
# Loaded dia120utt10_concatenated.npy
# Loaded dia189utt2_concatenated.npy
# Loaded dia1372utt17_concatenated.npy
# Loaded dia778utt2_concatenated.npy
# Loaded dia738utt8_concatenated.npy
# Loaded dia1272utt5_concatenated.npy
# Loaded dia609utt1_concatenated.npy
# Loaded dia1083utt8_concatenated.npy
# Loaded dia1120utt4_concatenated.npy
# Loaded dia1336utt10_concatenated.npy
# Loaded dia385utt13_concatenated.npy
# Loaded dia338utt5_concatenated.npy
# Loaded dia1001utt17_concatenated.npy
# Loaded dia1057utt4_concatenated.npy
# Loaded dia253utt10_concatenated.npy
# Loaded dia1104utt10_concatenated.npy
# Loaded dia35utt5_concatenated.npy
# Loaded dia650utt5_concatenated.npy
# Loaded dia538utt19_concatenated.npy
# Loaded dia590utt1_concatenated.npy
# Loaded dia142utt3_concatenated.npy
# Loaded dia282utt7_concatenated.npy
# Loaded dia834utt3_concatenated.npy
# Loaded dia907utt10_concatenated.npy
# Loaded dia874utt9_concatenated.npy
# Loaded dia361utt1_concatenated.npy
# Loaded dia216utt1_concatenated.npy
# Loaded dia684utt9_concatenated.npy
# Loaded dia903utt9_concatenated.npy
# Loaded dia504utt7_concatenated.npy
# Loaded dia637utt10_concatenated.npy
# Loaded dia727utt5_concatenated.npy
# Loaded dia1208utt4_concatenated.npy
# Loaded dia84utt5_concatenated.npy
# Loaded dia785utt13_concatenated.npy
# Loaded dia521utt1_concatenated.npy
# Loaded dia966utt5_concatenated.npy
# Loaded dia233utt7_concatenated.npy
# Loaded dia344utt7_concatenated.npy
# Loaded dia456utt1_concatenated.npy
# Loaded dia811utt5_concatenated.npy
# Loaded dia796utt5_concatenated.npy
# Loaded dia167utt5_concatenated.npy
# Loaded dia675utt3_concatenated.npy
# Loaded dia10utt3_concatenated.npy
# Loaded dia1191utt4_concatenated.npy
# Loaded dia389utt5_concatenated.npy
# Loaded dia1032utt8_concatenated.npy
# Loaded dia1072utt2_concatenated.npy
# Loaded dia1145utt8_concatenated.npy
# Loaded dia1105utt2_concatenated.npy
# Loaded dia848utt1_concatenated.npy
# Loaded dia1257utt3_concatenated.npy
# Loaded dia232utt21_concatenated.npy
# Loaded dia1197utt7_concatenated.npy
# Loaded dia376utt10_concatenated.npy
# Loaded dia979utt8_concatenated.npy
# Loaded dia1074utt1_concatenated.npy
# Loaded dia144utt10_concatenated.npy
# Loaded dia409utt6_concatenated.npy
# Loaded dia1103utt1_concatenated.npy
# Loaded dia138utt2_concatenated.npy
# Loaded dia396utt8_concatenated.npy
# Loaded dia527utt2_concatenated.npy
# Loaded dia82utt6_concatenated.npy
# Loaded dia235utt4_concatenated.npy
# Loaded dia450utt2_concatenated.npy
# Loaded dia822utt10_concatenated.npy
# Loaded dia520utt10_concatenated.npy
# Loaded dia33utt11_concatenated.npy
# Loaded dia751utt2_concatenated.npy
# Loaded dia711utt8_concatenated.npy
# Loaded dia491utt6_concatenated.npy
# Loaded dia260utt6_concatenated.npy
# Loaded dia1078utt7_concatenated.npy
# Loaded dia935utt4_concatenated.npy
# Loaded dia842utt4_concatenated.npy
# Loaded dia317utt6_concatenated.npy
# Loaded dia771utt14_concatenated.npy
# Loaded dia626utt2_concatenated.npy
# Loaded dia666utt8_concatenated.npy
# Loaded dia83utt11_concatenated.npy
# Loaded dia997utt17_concatenated.npy
# Loaded dia708utt6_concatenated.npy
# Loaded dia1270utt14_concatenated.npy
# Loaded dia127utt14_concatenated.npy
# Loaded dia1296utt7_concatenated.npy
# Loaded dia329utt10_concatenated.npy
# Loaded dia268utt10_concatenated.npy
# Loaded dia1103utt14_concatenated.npy
# Loaded dia1244utt8_concatenated.npy
# Loaded dia1204utt2_concatenated.npy
# Loaded dia1290utt4_concatenated.npy
# Loaded dia382utt17_concatenated.npy
# Loaded dia679utt5_concatenated.npy
# Loaded dia1373utt2_concatenated.npy
# Loaded dia1230utt19_concatenated.npy
# Loaded dia287utt10_concatenated.npy
# Loaded dia385utt3_concatenated.npy
# Loaded dia86utt20_concatenated.npy
# Loaded dia757utt1_concatenated.npy
# Loaded dia735utt13_concatenated.npy
# Loaded dia266utt5_concatenated.npy
# Loaded dia574utt3_concatenated.npy
# Loaded dia1109utt4_concatenated.npy
# Loaded dia403utt3_concatenated.npy
# Loaded dia14utt12_concatenated.npy
# Loaded dia311utt5_concatenated.npy
# Loaded dia45utt1_concatenated.npy
# Loaded dia620utt1_concatenated.npy
# Loaded dia839utt17_concatenated.npy
# Loaded dia132utt7_concatenated.npy
# Loaded dia621utt12_concatenated.npy
# Loaded dia155utt1_concatenated.npy
# Loaded dia587utt3_concatenated.npy
# Loaded dia647utt7_concatenated.npy
# Loaded dia336utt9_concatenated.npy
# Loaded dia376utt3_concatenated.npy
# Loaded dia823utt1_concatenated.npy
# Loaded dia413utt12_concatenated.npy
# Loaded dia954utt1_concatenated.npy
# Loaded dia513utt5_concatenated.npy
# Loaded dia201utt3_concatenated.npy
# Loaded dia730utt7_concatenated.npy
# Loaded dia828utt11_concatenated.npy
# Loaded dia999utt3_concatenated.npy
# Loaded dia1314utt4_concatenated.npy
# Loaded dia1137utt6_concatenated.npy
# Loaded dia1040utt6_concatenated.npy
# Loaded dia1324utt18_concatenated.npy
# Loaded dia393utt11_concatenated.npy
# Loaded dia258utt7_concatenated.npy
# Loaded dia198utt3_concatenated.npy
# Loaded dia769utt3_concatenated.npy
# Loaded dia729utt9_concatenated.npy
# Loaded dia1219utt11_concatenated.npy
# Loaded dia329utt4_concatenated.npy
# Loaded dia136utt12_concatenated.npy
# Loaded dia1131utt5_concatenated.npy
# Loaded dia1057utt18_concatenated.npy
# Loaded dia1265utt7_concatenated.npy
# Loaded dia1053utt12_concatenated.npy
# Loaded dia153utt2_concatenated.npy
# Loaded dia113utt8_concatenated.npy
# Loaded dia41utt13_concatenated.npy
# Loaded dia641utt4_concatenated.npy
# Loaded dia825utt2_concatenated.npy
# Loaded dia1168utt1_concatenated.npy
# Loaded dia865utt8_concatenated.npy
# Loaded dia695utt8_concatenated.npy
# Loaded dia952utt2_concatenated.npy
# Loaded dia659utt11_concatenated.npy
# Loaded dia515utt6_concatenated.npy
# Loaded dia736utt4_concatenated.npy
# Loaded dia92utt17_concatenated.npy
# Loaded dia614utt6_concatenated.npy
# Loaded dia71utt6_concatenated.npy
# Loaded dia594utt8_concatenated.npy
# Loaded dia437utt4_concatenated.npy
# Loaded dia325utt2_concatenated.npy
# Loaded dia606utt11_concatenated.npy
# Loaded dia252utt2_concatenated.npy
# Loaded dia1269utt1_concatenated.npy
# Loaded dia763utt6_concatenated.npy
# Loaded dia1347utt5_concatenated.npy
# Loaded dia28utt2_concatenated.npy
# Loaded dia1087utt1_concatenated.npy
# Loaded dia1164utt7_concatenated.npy
# Loaded dia829utt4_concatenated.npy
# Loaded dia186utt12_concatenated.npy
# Loaded dia1109utt15_concatenated.npy
# Loaded dia388utt16_concatenated.npy
# Loaded dia1230utt5_concatenated.npy
# Loaded dia1081utt2_concatenated.npy
# Loaded dia468utt3_concatenated.npy
# Loaded dia1162utt4_concatenated.npy
# Loaded dia323utt11_concatenated.npy
# Loaded dia1015utt4_concatenated.npy
# Loaded dia995utt5_concatenated.npy
# Loaded dia77utt5_concatenated.npy
# Loaded dia612utt5_concatenated.npy
# Loaded dia549utt15_concatenated.npy
# Loaded dia140utt9_concatenated.npy
# Loaded dia575utt11_concatenated.npy
# Loaded dia100utt3_concatenated.npy
# Loaded dia877utt11_concatenated.npy
# Loaded dia876utt3_concatenated.npy
# Loaded dia66utt10_concatenated.npy
# Loaded dia323utt1_concatenated.npy
# Loaded dia254utt1_concatenated.npy
# Loaded dia194utt5_concatenated.npy
# Loaded dia546utt7_concatenated.npy
# Loaded dia941utt9_concatenated.npy
# Loaded dia686utt3_concatenated.npy
# Loaded dia747utt11_concatenated.npy
# Loaded dia765utt5_concatenated.npy
# Loaded dia1260utt17_concatenated.npy
# Loaded dia339utt1_concatenated.npy
# Loaded dia608utt5_concatenated.npy
# Loaded dia1081utt13_concatenated.npy
# Loaded dia1302utt2_concatenated.npy
# Loaded dia1359utt14_concatenated.npy
# Loaded dia1275utt2_concatenated.npy
# Loaded dia339utt13_concatenated.npy
# Loaded dia432utt9_concatenated.npy
# Loaded dia1178utt4_concatenated.npy
# Loaded dia472utt3_concatenated.npy
# Loaded dia360utt5_concatenated.npy
# Loaded dia34utt1_concatenated.npy
# Loaded dia651utt1_concatenated.npy
# Loaded dia283utt3_concatenated.npy
# Loaded dia954utt10_concatenated.npy
# Loaded dia456utt10_concatenated.npy
# Loaded dia485utt14_concatenated.npy
# Loaded dia93utt12_concatenated.npy
# Loaded dia726utt1_concatenated.npy
# Loaded dia505utt3_concatenated.npy
# Loaded dia32utt2_concatenated.npy
# Loaded dia617utt8_concatenated.npy
# Loaded dia72utt8_concatenated.npy
# Loaded dia597utt6_concatenated.npy
# Loaded dia618utt19_concatenated.npy
# Loaded dia453utt21_concatenated.npy
# Loaded dia928utt19_concatenated.npy
# Loaded dia1009utt7_concatenated.npy
# Loaded dia1127utt3_concatenated.npy
# Loaded dia1167utt9_concatenated.npy
# Loaded dia1016utt10_concatenated.npy
# Loaded dia1304utt1_concatenated.npy
# Loaded dia989utt6_concatenated.npy
# Loaded dia1224utt10_concatenated.npy
# Loaded dia1273utt1_concatenated.npy
# Loaded dia248utt2_concatenated.npy
# Loaded dia1050utt3_concatenated.npy
# Loaded dia478utt6_concatenated.npy
# Loaded dia149utt2_concatenated.npy
# Loaded dia1351utt3_concatenated.npy
# Loaded dia1091utt7_concatenated.npy
# Loaded dia1170utt13_concatenated.npy
# Loaded dia1226utt3_concatenated.npy
# Loaded dia227utt13_concatenated.npy
# Loaded dia1049utt10_concatenated.npy
# Loaded dia948utt2_concatenated.npy
# Loaded dia1005utt1_concatenated.npy
# Loaded dia333utt4_concatenated.npy
# Loaded dia471utt13_concatenated.npy
# Loaded dia795utt10_concatenated.npy
# Loaded dia1308utt7_concatenated.npy
# Loaded dia1088utt9_concatenated.npy
# Loaded dia556utt2_concatenated.npy
# Loaded dia911utt6_concatenated.npy
# Loaded dia244utt4_concatenated.npy
# Loaded dia607utt14_concatenated.npy
# Loaded dia427utt1_concatenated.npy
# Loaded dia860utt5_concatenated.npy
# Loaded dia116utt5_concatenated.npy
# Loaded dia983utt3_concatenated.npy
# Loaded dia644utt9_concatenated.npy
# Loaded dia21utt9_concatenated.npy
# Loaded dia61utt3_concatenated.npy
# Loaded dia1279utt4_concatenated.npy
# Loaded dia773utt3_concatenated.npy
# Loaded dia409utt10_concatenated.npy
# Loaded dia917utt5_concatenated.npy
# Loaded dia690utt5_concatenated.npy
# Loaded dia182utt3_concatenated.npy
# Loaded dia1108utt10_concatenated.npy
# Loaded dia1134utt8_concatenated.npy
# Loaded dia839utt1_concatenated.npy
# Loaded dia1031utt13_concatenated.npy
# Loaded dia1097utt4_concatenated.npy
# Loaded dia389utt13_concatenated.npy
# Loaded dia1043utt8_concatenated.npy
# Loaded dia168utt17_concatenated.npy
# Loaded dia509utt5_concatenated.npy
# Loaded dia1003utt2_concatenated.npy
# Loaded dia1203utt13_concatenated.npy
# Loaded dia1121utt18_concatenated.npy
# Loaded dia272utt12_concatenated.npy
# Loaded dia929utt7_concatenated.npy
# Loaded dia1247utt6_concatenated.npy
# Loaded dia1330utt6_concatenated.npy
# Loaded dia128utt7_concatenated.npy
# Loaded dia398utt15_concatenated.npy
# Loaded dia419utt3_concatenated.npy
# Loaded dia459utt9_concatenated.npy
# Loaded dia1113utt4_concatenated.npy
# Loaded dia92utt3_concatenated.npy
# Loaded dia930utt9_concatenated.npy
# Loaded dia537utt7_concatenated.npy
# Loaded dia970utt3_concatenated.npy
# Loaded dia893utt5_concatenated.npy
# Loaded dia714utt5_concatenated.npy
# Loaded dia1369utt2_concatenated.npy
# Loaded dia926utt12_concatenated.npy
# Loaded dia131utt9_concatenated.npy
# Loaded dia171utt3_concatenated.npy
# Loaded dia847utt9_concatenated.npy
# Loaded dia440utt7_concatenated.npy
# Loaded dia521utt15_concatenated.npy
# Loaded dia780utt3_concatenated.npy
# Loaded dia352utt1_concatenated.npy
# Loaded dia223utt2_concatenated.npy
# Loaded dia263utt8_concatenated.npy
# Loaded dia76utt13_concatenated.npy
# Loaded dia863utt18_concatenated.npy
# Loaded dia1218utt1_concatenated.npy
# Loaded dia712utt6_concatenated.npy
# Loaded dia895utt6_concatenated.npy
# Loaded dia2utt3_concatenated.npy
# Loaded dia652utt15_concatenated.npy
# Loaded dia665utt6_concatenated.npy
# Loaded dia757utt12_concatenated.npy
# Loaded dia446utt4_concatenated.npy
# Loaded dia354utt2_concatenated.npy
# Loaded dia99utt13_concatenated.npy
# Loaded dia1062utt7_concatenated.npy
# Loaded dia1241utt5_concatenated.npy
# Loaded dia19utt8_concatenated.npy
# Loaded dia1336utt5_concatenated.npy
# Loaded dia236utt15_concatenated.npy
# Loaded dia59utt2_concatenated.npy
# Loaded dia1115utt7_concatenated.npy
# Loaded dia1037utt5_concatenated.npy
# Loaded dia98utt6_concatenated.npy
# Loaded dia1214utt7_concatenated.npy
# Loaded dia255utt11_concatenated.npy
# Loaded dia1102utt11_concatenated.npy
# Loaded dia1363utt7_concatenated.npy
# Loaded dia383utt12_concatenated.npy
# Loaded dia1330utt11_concatenated.npy
# Loaded dia1280utt1_concatenated.npy
# Loaded dia923utt2_concatenated.npy
# Loaded dia564utt6_concatenated.npy
# Loaded dia963utt8_concatenated.npy
# Loaded dia81utt8_concatenated.npy
# Loaded dia708utt12_concatenated.npy
# Loaded dia747utt4_concatenated.npy
# Loaded dia162utt8_concatenated.npy
# Loaded dia55utt4_concatenated.npy
# Loaded dia506utt16_concatenated.npy
# Loaded dia15utt17_concatenated.npy
# Loaded dia854utt2_concatenated.npy
# Loaded dia403utt11_concatenated.npy
# Loaded dia1119utt1_concatenated.npy
# Loaded dia413utt6_concatenated.npy
# Loaded dia814utt8_concatenated.npy
# Loaded dia1068utt2_concatenated.npy
# Loaded dia925utt1_concatenated.npy
# Loaded dia562utt5_concatenated.npy
# Loaded dia270utt3_concatenated.npy
# Loaded dia741utt7_concatenated.npy
# Loaded dia393utt5_concatenated.npy
# Loaded dia979utt12_concatenated.npy
# Loaded dia945utt16_concatenated.npy
# Loaded dia490utt18_concatenated.npy
# Loaded dia82utt14_concatenated.npy
# Loaded dia53utt7_concatenated.npy
# Loaded dia347utt9_concatenated.npy
# Loaded dia307utt3_concatenated.npy
# Loaded dia852utt1_concatenated.npy
# Loaded dia1031utt6_concatenated.npy
# Loaded dia1271utt11_concatenated.npy
# Loaded dia229utt7_concatenated.npy
# Loaded dia8utt6_concatenated.npy
# Loaded dia1090utt15_concatenated.npy
# Loaded dia1212utt4_concatenated.npy
# Loaded dia1146utt6_concatenated.npy
# Loaded dia318utt10_concatenated.npy
# Loaded dia928utt2_concatenated.npy
# Loaded dia1186utt7_concatenated.npy
# Loaded dia1206utt9_concatenated.npy
# Loaded dia1246utt3_concatenated.npy
# Loaded dia129utt2_concatenated.npy
# Loaded dia169utt8_concatenated.npy
# Loaded dia1112utt1_concatenated.npy
# Loaded dia418utt6_concatenated.npy
# Loaded dia798utt8_concatenated.npy
# Loaded dia1344utt13_concatenated.npy
# Loaded dia1340utt19_concatenated.npy
# Loaded dia224utt4_concatenated.npy
# Loaded dia93utt6_concatenated.npy
# Loaded dia387utt8_concatenated.npy
# Loaded dia679utt17_concatenated.npy
# Loaded dia1368utt7_concatenated.npy
# Loaded dia806utt6_concatenated.npy
# Loaded dia441utt2_concatenated.npy
# Loaded dia781utt6_concatenated.npy
# Loaded dia977utt5_concatenated.npy
# Loaded dia530utt1_concatenated.npy
# Loaded dia95utt5_concatenated.npy
# Loaded dia713utt3_concatenated.npy
# Loaded dia1219utt4_concatenated.npy
# Loaded dia3utt6_concatenated.npy
# Loaded dia894utt3_concatenated.npy
# Loaded dia25utt12_concatenated.npy
# Loaded dia664utt3_concatenated.npy
# Loaded dia624utt9_concatenated.npy
# Loaded dia41utt9_concatenated.npy
# Loaded dia176utt5_concatenated.npy
# Loaded dia738utt17_concatenated.npy
# Loaded dia787utt5_concatenated.npy
# Loaded dia447utt1_concatenated.npy
# Loaded dia355utt7_concatenated.npy
# Loaded dia1063utt2_concatenated.npy
# Loaded dia398utt5_concatenated.npy
# Loaded dia360utt13_concatenated.npy
# Loaded dia1114utt2_concatenated.npy
# Loaded dia1154utt8_concatenated.npy
# Loaded dia206utt10_concatenated.npy
# Loaded dia99utt3_concatenated.npy
# Loaded dia1215utt2_concatenated.npy
# Loaded dia303utt17_concatenated.npy
# Loaded dia1255utt8_concatenated.npy
# Loaded dia898utt5_concatenated.npy
# Loaded dia1363utt10_concatenated.npy
# Loaded dia1362utt2_concatenated.npy
# Loaded dia359utt1_concatenated.npy
# Loaded dia1281utt4_concatenated.npy
# Loaded dia565utt3_concatenated.npy
# Loaded dia525utt9_concatenated.npy
# Loaded dia277utt5_concatenated.npy
# Loaded dia746utt1_concatenated.npy
# Loaded dia486utt5_concatenated.npy
# Loaded dia483utt14_concatenated.npy
# Loaded dia394utt3_concatenated.npy
# Loaded dia450utt10_concatenated.npy
# Loaded dia952utt10_concatenated.npy
# Loaded dia123utt7_concatenated.npy
# Loaded dia54utt1_concatenated.npy
# Loaded dia788utt17_concatenated.npy
# Loaded dia631utt1_concatenated.npy
# Loaded dia300utt5_concatenated.npy
# Loaded dia412utt3_concatenated.npy
# Loaded dia1118utt4_concatenated.npy
# Loaded dia1069utt7_concatenated.npy
# Loaded dia924utt4_concatenated.npy
# Loaded dia271utt6_concatenated.npy
# Loaded dia480utt6_concatenated.npy
# Loaded dia887utt8_concatenated.npy
# Loaded dia700utt8_concatenated.npy
# Loaded dia740utt2_concatenated.npy
# Loaded dia125utt4_concatenated.npy
# Loaded dia626utt17_concatenated.npy
# Loaded dia677utt8_concatenated.npy
# Loaded dia12utt8_concatenated.npy
# Loaded dia637utt2_concatenated.npy
# Loaded dia723utt10_concatenated.npy
# Loaded dia853utt4_concatenated.npy
# Loaded dia1030utt3_concatenated.npy
# Loaded dia268utt8_concatenated.npy
# Loaded dia499utt8_concatenated.npy
# Loaded dia9utt3_concatenated.npy
# Loaded dia1213utt1_concatenated.npy
# Loaded dia719utt6_concatenated.npy
# Loaded dia149utt14_concatenated.npy
# Loaded dia291utt13_concatenated.npy
# Loaded dia1364utt1_concatenated.npy
# Loaded dia347utt10_concatenated.npy
# Loaded dia1107utt9_concatenated.npy
# Loaded dia1147utt3_concatenated.npy
# Loaded dia1287utt7_concatenated.npy
# Loaded dia1336utt11_concatenated.npy
# Loaded dia125utt20_concatenated.npy
# Loaded dia338utt4_concatenated.npy
# Loaded dia385utt12_concatenated.npy
# Loaded dia1083utt9_concatenated.npy
# Loaded dia1104utt11_concatenated.npy
# Loaded dia253utt11_concatenated.npy
# Loaded dia1001utt16_concatenated.npy
# Loaded dia1057utt5_concatenated.npy
# Loaded dia874utt8_concatenated.npy
# Loaded dia907utt11_concatenated.npy
# Loaded dia834utt2_concatenated.npy
# Loaded dia1179utt1_concatenated.npy
# Loaded dia538utt18_concatenated.npy
# Loaded dia35utt4_concatenated.npy
# Loaded dia802utt16_concatenated.npy
# Loaded dia650utt4_concatenated.npy
# Loaded dia282utt6_concatenated.npy
# Loaded dia102utt8_concatenated.npy
# Loaded dia142utt2_concatenated.npy
# Loaded dia637utt11_concatenated.npy
# Loaded dia727utt4_concatenated.npy
# Loaded dia903utt8_concatenated.npy
# Loaded dia504utt6_concatenated.npy
# Loaded dia684utt8_concatenated.npy
# Loaded dia832utt1_concatenated.npy
# Loaded dia367utt3_concatenated.npy
# Loaded dia656utt7_concatenated.npy
# Loaded dia33utt7_concatenated.npy
# Loaded dia596utt3_concatenated.npy
# Loaded dia144utt1_concatenated.npy
# Loaded dia84utt14_concatenated.npy
# Loaded dia284utt5_concatenated.npy
# Loaded dia721utt7_concatenated.npy
# Loaded dia544utt11_concatenated.npy
# Loaded dia1048utt8_concatenated.npy
# Loaded dia1008utt2_concatenated.npy
# Loaded dia945utt1_concatenated.npy
# Loaded dia1126utt6_concatenated.npy
# Loaded dia1305utt4_concatenated.npy
# Loaded dia1372utt16_concatenated.npy
# Loaded dia738utt9_concatenated.npy
# Loaded dia1272utt4_concatenated.npy
# Loaded dia778utt3_concatenated.npy
# Loaded dia120utt11_concatenated.npy
# Loaded dia189utt3_concatenated.npy
# Loaded dia249utt7_concatenated.npy
# Loaded dia1193utt12_concatenated.npy
# Loaded dia439utt9_concatenated.npy
# Loaded dia1173utt4_concatenated.npy
# Loaded dia479utt3_concatenated.npy
# Loaded dia288utt3_concatenated.npy
# Loaded dia1090utt2_concatenated.npy
# Loaded dia1227utt6_concatenated.npy
# Loaded dia949utt7_concatenated.npy
# Loaded dia1004utt4_concatenated.npy
# Loaded dia248utt16_concatenated.npy
# Loaded dia332utt1_concatenated.npy
# Loaded dia420utt7_concatenated.npy
# Loaded dia827utt9_concatenated.npy
# Loaded dia825utt15_concatenated.npy
# Loaded dia819utt11_concatenated.npy
# Loaded dia151utt9_concatenated.npy
# Loaded dia1349utt8_concatenated.npy
# Loaded dia66utt5_concatenated.npy
# Loaded dia422utt12_concatenated.npy
# Loaded dia984utt5_concatenated.npy
# Loaded dia774utt5_concatenated.npy
# Loaded dia8utt16_concatenated.npy
# Loaded dia697utt3_concatenated.npy
# Loaded dia910utt3_concatenated.npy
# Loaded dia614utt18_concatenated.npy
# Loaded dia185utt5_concatenated.npy
# Loaded dia245utt1_concatenated.npy
# Loaded dia334utt2_concatenated.npy
# Loaded dia426utt4_concatenated.npy
# Loaded dia982utt6_concatenated.npy
# Loaded dia427utt23_concatenated.npy
# Loaded dia772utt6_concatenated.npy
# Loaded dia1278utt1_concatenated.npy
# Loaded dia551utt4_concatenated.npy
# Loaded dia466utt15_concatenated.npy
# Loaded dia243utt2_concatenated.npy
# Loaded dia70utt13_concatenated.npy
# Loaded dia183utt6_concatenated.npy
# Loaded dia1175utt7_concatenated.npy
# Loaded dia1062utt12_concatenated.npy
# Loaded dia1283utt16_concatenated.npy
# Loaded dia1096utt1_concatenated.npy
# Loaded dia39utt2_concatenated.npy
# Loaded dia1356utt5_concatenated.npy
# Loaded dia1221utt5_concatenated.npy
# Loaded dia1188utt15_concatenated.npy
# Loaded dia1369utt11_concatenated.npy
# Loaded dia1355utt15_concatenated.npy
# Loaded dia493utt17_concatenated.npy
# Loaded dia606utt8_concatenated.npy
# Loaded dia63utt8_concatenated.npy
# Loaded dia646utt2_concatenated.npy
# Loaded dia23utt2_concatenated.npy
# Loaded dia377utt6_concatenated.npy
# Loaded dia596utt10_concatenated.npy
# Loaded dia822utt4_concatenated.npy
# Loaded dia955utt4_concatenated.npy
# Loaded dia180utt8_concatenated.npy
# Loaded dia771utt8_concatenated.npy
# Loaded dia731utt2_concatenated.npy
# Loaded dia946utt19_concatenated.npy
# Loaded dia1078utt10_concatenated.npy
# Loaded dia998utt6_concatenated.npy
# Loaded dia1315utt1_concatenated.npy
# Loaded dia1176utt9_concatenated.npy
# Loaded dia1001utt9_concatenated.npy
# Loaded dia259utt2_concatenated.npy
# Loaded dia199utt6_concatenated.npy
# Loaded dia1276utt14_concatenated.npy
# Loaded dia768utt6_concatenated.npy
# Loaded dia1232utt13_concatenated.npy
# Loaded dia165utt13_concatenated.npy
# Loaded dia328utt1_concatenated.npy
# Loaded dia1004utt19_concatenated.npy
# Loaded dia1264utt2_concatenated.npy
# Loaded dia1224utt8_concatenated.npy
# Loaded dia1139utt10_concatenated.npy
# Loaded dia252utt14_concatenated.npy
# Loaded dia292utt3_concatenated.npy
# Loaded dia25utt1_concatenated.npy
# Loaded dia803utt13_concatenated.npy
# Loaded dia640utt1_concatenated.npy
# Loaded dia580utt5_concatenated.npy
# Loaded dia371utt5_concatenated.npy
# Loaded dia463utt3_concatenated.npy
# Loaded dia906utt14_concatenated.npy
# Loaded dia1169utt4_concatenated.npy
# Loaded dia438utt10_concatenated.npy
# Loaded dia514utt3_concatenated.npy
# Loaded dia953utt7_concatenated.npy
# Loaded dia206utt5_concatenated.npy
# Loaded dia737utt1_concatenated.npy
# Loaded dia80utt20_concatenated.npy
# Loaded dia70utt3_concatenated.npy
# Loaded dia655utt9_concatenated.npy
# Loaded dia30utt9_concatenated.npy
# Loaded dia669utt14_concatenated.npy
# Loaded dia992utt3_concatenated.npy
# Loaded dia655utt10_concatenated.npy
# Loaded dia871utt5_concatenated.npy
# Loaded dia436utt1_concatenated.npy
# Loaded dia324utt7_concatenated.npy
# Loaded dia193utt3_concatenated.npy
# Loaded dia467utt10_concatenated.npy
# Loaded dia965utt10_concatenated.npy
# Loaded dia253utt7_concatenated.npy
# Loaded dia681utt5_concatenated.npy
# Loaded dia906utt5_concatenated.npy
# Loaded dia541utt1_concatenated.npy
# Loaded dia860utt17_concatenated.npy
# Loaded dia562utt17_concatenated.npy
# Loaded dia30utt20_concatenated.npy
# Loaded dia686utt14_concatenated.npy
# Loaded dia762utt3_concatenated.npy
# Loaded dia1268utt4_concatenated.npy
# Loaded dia1166utt10_concatenated.npy
# Loaded dia1282utt13_concatenated.npy
# Loaded dia1165utt2_concatenated.npy
# Loaded dia828utt1_concatenated.npy
# Loaded dia1125utt8_concatenated.npy
# Loaded dia147utt21_concatenated.npy
# Loaded dia518utt5_concatenated.npy
# Loaded dia1269utt19_concatenated.npy
# Loaded dia1189utt10_concatenated.npy
# Loaded dia1080utt7_concatenated.npy
# Loaded dia1310utt17_concatenated.npy
# Loaded dia1328utt19_concatenated.npy
# Loaded dia1340utt3_concatenated.npy
# Loaded dia158utt2_concatenated.npy
# Loaded dia142utt10_concatenated.npy
# Loaded dia1163utt1_concatenated.npy
# Loaded dia469utt6_concatenated.npy
# Loaded dia249utt13_concatenated.npy
# Loaded dia1014utt1_concatenated.npy
# Loaded dia370utt10_concatenated.npy
# Loaded dia1027utt10_concatenated.npy
# Loaded dia35utt11_concatenated.npy
# Loaded dia1319utt7_concatenated.npy
# Loaded dia877utt6_concatenated.npy
# Loaded dia470utt8_concatenated.npy
# Loaded dia430utt2_concatenated.npy
# Loaded dia322utt4_concatenated.npy
# Loaded dia255utt4_concatenated.npy
# Loaded dia611utt17_concatenated.npy
# Loaded dia900utt6_concatenated.npy
# Loaded dia687utt6_concatenated.npy
# Loaded dia483utt8_concatenated.npy
# Loaded dia884utt6_concatenated.npy
# Loaded dia703utt6_concatenated.npy
# Loaded dia930utt11_concatenated.npy
# Loaded dia432utt11_concatenated.npy
# Loaded dia1209utt1_concatenated.npy
# Loaded dia18utt13_concatenated.npy
# Loaded dia520utt4_concatenated.npy
# Loaded dia272utt8_concatenated.npy
# Loaded dia232utt2_concatenated.npy
# Loaded dia305utt8_concatenated.npy
# Loaded dia345utt2_concatenated.npy
# Loaded dia739utt12_concatenated.npy
# Loaded dia674utt6_concatenated.npy
# Loaded dia1250utt5_concatenated.npy
# Loaded dia1073utt7_concatenated.npy
# Loaded dia264utt11_concatenated.npy
# Loaded dia258utt15_concatenated.npy
# Loaded dia1104utt7_concatenated.npy
# Loaded dia849utt4_concatenated.npy
# Loaded dia180utt12_concatenated.npy
# ...
# Loaded dia844utt4_concatenated.npy
# Loaded dia348utt2_concatenated.npy
# Loaded dia836utt11_concatenated.npy
# Loaded dia889utt6_concatenated.npy
# Loaded dia239utt1_concatenated.npy
# Loaded dia1311utt1_concatenated.npy
# Loaded dia134utt7_concatenated.npy
# Loaded dia1172utt9_concatenated.npy
# Loaded dia445utt9_concatenated.npy
# Loaded dia572utt3_concatenated.npy
# Loaded dia858utt7_concatenated.npy
# Loaded dia1128utt3_concatenated.npy
# Loaded dia801utt3_concatenated.npy
# Loaded dia1171utt7_concatenated.npy
# Loaded dia137utt9_concatenated.npy
# Loaded dia1225utt5_concatenated.npy
# Loaded dia531utt7_concatenated.npy
# Loaded dia936utt9_concatenated.npy
# Loaded dia239utt13_concatenated.npy
# Loaded dia1294utt19_concatenated.npy
# Loaded dia241utt10_concatenated.npy
# Loaded dia1223utt6_concatenated.npy
# Loaded dia225utt2_concatenated.npy
# Loaded dia718utt19_concatenated.npy
# Loaded dia448utt10_concatenated.npy
# Loaded dia415utt6_concatenated.npy
# Loaded dia1122utt6_concatenated.npy
# Loaded dia124utt2_concatenated.npy
# Loaded dia636utt4_concatenated.npy
# Loaded dia1055utt6_concatenated.npy
# Loaded dia341utt9_concatenated.npy
# Loaded dia122utt1_concatenated.npy
# Loaded dia363utt14_concatenated.npy
# Loaded dia630utt7_concatenated.npy
# Loaded dia276utt3_concatenated.npy
# Loaded dia358utt7_concatenated.npy
# Loaded dia932utt13_concatenated.npy
# Loaded dia779utt5_concatenated.npy
# Loaded dia421utt15_concatenated.npy
# Loaded dia720utt1_concatenated.npy
# Loaded dia1360utt1_concatenated.npy
# Loaded dia145utt7_concatenated.npy
# Loaded dia1143utt3_concatenated.npy
# Loaded dia1331utt23_concatenated.npy
# Loaded dia591utt6_concatenated.npy
# Loaded dia461utt18_concatenated.npy
# Loaded dia862utt15_concatenated.npy
# Loaded dia988utt12_concatenated.npy
# Loaded dia634utt16_concatenated.npy
# Loaded dia406utt16_concatenated.npy
# Loaded dia879utt8_concatenated.npy
# Loaded dia550utt2_concatenated.npy
# Loaded dia1060utt11_concatenated.npy
# Loaded dia52utt5_concatenated.npy
# Loaded dia421utt1_concatenated.npy
# Loaded dia879utt12_concatenated.npy
# Loaded dia993utt15_concatenated.npy
# Loaded dia749utt12_concatenated.npy
# Loaded dia598utt13_concatenated.npy
# Loaded dia682utt8_concatenated.npy
# Loaded dia943utt1_concatenated.npy
# Loaded dia473utt5_concatenated.npy
# Loaded dia508utt3_concatenated.npy
# Loaded dia667utt17_concatenated.npy
# Loaded dia838utt7_concatenated.npy
# Loaded dia691utt3_concatenated.npy
# Loaded dia1245utt5_concatenated.npy
# Loaded dia1185utt1_concatenated.npy
# Loaded dia134utt10_concatenated.npy
# Loaded dia821utt9_concatenated.npy
# Loaded dia1060utt4_concatenated.npy
# Loaded dia1245utt17_concatenated.npy
# Loaded dia603utt6_concatenated.npy
# Loaded dia583utt8_concatenated.npy
# Loaded dia148utt4_concatenated.npy
# Loaded dia859utt2_concatenated.npy
# Loaded dia800utt6_concatenated.npy
# Loaded dia407utt8_concatenated.npy
# Loaded dia662utt3_concatenated.npy
# Loaded dia536utt1_concatenated.npy
# Loaded dia971utt5_concatenated.npy
# Loaded dia228utt1_concatenated.npy
# Loaded dia414utt3_concatenated.npy
# Loaded dia392utt3_concatenated.npy
# Loaded dia67utt7_concatenated.npy
# Loaded dia668utt6_concatenated.npy
# Loaded dia858utt11_concatenated.npy
# Loaded dia343utt2_concatenated.npy
# Loaded dia526utt4_concatenated.npy
# Loaded dia1011utt4_concatenated.npy
# Loaded dia234utt2_concatenated.npy
# Loaded dia705utt6_concatenated.npy
# Loaded dia891utt17_concatenated.npy
# Loaded dia540utt13_concatenated.npy
# Loaded dia1160utt7_concatenated.npy
# Loaded dia927utt9_concatenated.npy
# Loaded dia133utt1_concatenated.npy
# Loaded dia47utt10_concatenated.npy
# Loaded dia310utt3_concatenated.npy
# Loaded dia932utt1_concatenated.npy
# Loaded dia384utt5_concatenated.npy
# Loaded dia1261utt7_concatenated.npy
# Loaded dia859utt14_concatenated.npy
# Loaded dia821utt17_concatenated.npy
# Loaded dia135utt2_concatenated.npy
# Loaded dia750utt4_concatenated.npy
# Loaded dia261utt16_concatenated.npy
# Loaded dia1294utt4_concatenated.npy
# Loaded dia909utt12_concatenated.npy
# Loaded dia1199utt2_concatenated.npy
# Loaded dia473utt11_concatenated.npy
# Loaded dia793utt18_concatenated.npy
# Loaded dia225utt11_concatenated.npy
# Loaded dia512utt3_concatenated.npy
# Loaded dia294utt3_concatenated.npy
# Loaded dia586utt5_concatenated.npy
# Loaded dia1371utt1_concatenated.npy
# Loaded dia724utt9_concatenated.npy
# Loaded dia764utt3_concatenated.npy
# Loaded dia547utt1_concatenated.npy
# Loaded dia101utt5_concatenated.npy
# Loaded dia817utt12_concatenated.npy
# Loaded dia959utt1_concatenated.npy
# Loaded dia88utt4_concatenated.npy
# Loaded dia298utt5_concatenated.npy
# Loaded dia1298utt2_concatenated.npy
# Loaded dia1195utt4_concatenated.npy
# Loaded dia473utt12_concatenated.npy
# Loaded dia49utt3_concatenated.npy
# Loaded dia586utt6_concatenated.npy
# Loaded dia1371utt2_concatenated.npy
# Loaded dia1331utt8_concatenated.npy
# Loaded dia225utt12_concatenated.npy
# Loaded dia1294utt7_concatenated.npy
# Loaded dia261utt15_concatenated.npy
# Loaded dia16utt4_concatenated.npy
# Loaded dia1199utt1_concatenated.npy
# Loaded dia909utt11_concatenated.npy
# Loaded dia1298utt1_concatenated.npy
# Loaded dia586utt18_concatenated.npy
# Loaded dia1195utt7_concatenated.npy
# Loaded dia101utt6_concatenated.npy
# Loaded dia547utt2_concatenated.npy
# Loaded dia298utt6_concatenated.npy
# Loaded dia88utt7_concatenated.npy
# Loaded dia959utt2_concatenated.npy
# Loaded dia817utt11_concatenated.npy
# Loaded dia62utt9_concatenated.npy
# Loaded dia1160utt4_concatenated.npy
# Loaded dia705utt5_concatenated.npy
# Loaded dia234utt1_concatenated.npy
# Loaded dia816utt3_concatenated.npy
# Loaded dia343utt1_concatenated.npy
# Loaded dia540utt10_concatenated.npy
# Loaded dia448utt9_concatenated.npy
# Loaded dia891utt14_concatenated.npy
# Loaded dia749utt9_concatenated.npy
# Loaded dia821utt14_concatenated.npy
# Loaded dia750utt7_concatenated.npy
# Loaded dia261utt3_concatenated.npy
# Loaded dia135utt1_concatenated.npy
# Loaded dia1261utt4_concatenated.npy
# Loaded dia384utt6_concatenated.npy
# Loaded dia932utt2_concatenated.npy
# Loaded dia133utt2_concatenated.npy
# Loaded dia47utt13_concatenated.npy
# Loaded dia859utt17_concatenated.npy
# Loaded dia971utt6_concatenated.npy
# Loaded dia536utt2_concatenated.npy
# Loaded dia353utt4_concatenated.npy
# Loaded dia859utt1_concatenated.npy
# Loaded dia58utt20_concatenated.npy
# Loaded dia800utt5_concatenated.npy
# Loaded dia67utt4_concatenated.npy
# Loaded dia668utt5_concatenated.npy
# Loaded dia228utt2_concatenated.npy
# Loaded dia473utt6_concatenated.npy
# Loaded dia1223utt21_concatenated.npy
# Loaded dia943utt2_concatenated.npy
# Loaded dia604utt10_concatenated.npy
# Loaded dia988utt3_concatenated.npy
# Loaded dia598utt10_concatenated.npy
# Loaded dia779utt14_concatenated.npy
# Loaded dia327utt9_concatenated.npy
# Loaded dia210utt3_concatenated.npy
# Loaded dia867utt3_concatenated.npy
# Loaded dia603utt5_concatenated.npy
# Loaded dia1245utt14_concatenated.npy
# Loaded dia1060utt7_concatenated.npy
# Loaded dia148utt7_concatenated.npy
# Loaded dia838utt4_concatenated.npy
# Loaded dia455utt14_concatenated.npy
# Loaded dia667utt14_concatenated.npy
# Loaded dia1245utt6_concatenated.npy
# Loaded dia1185utt2_concatenated.npy
# Loaded dia591utt5_concatenated.npy
# Loaded dia988utt11_concatenated.npy
# Loaded dia862utt16_concatenated.npy
# Loaded dia779utt6_concatenated.npy
# Loaded dia58utt3_concatenated.npy
# Loaded dia1331utt20_concatenated.npy
# Loaded dia833utt4_concatenated.npy
# Loaded dia145utt4_concatenated.npy
# Loaded dia1320utt8_concatenated.npy
# Loaded dia1360utt2_concatenated.npy
# Loaded dia421utt2_concatenated.npy
# Loaded dia461utt8_concatenated.npy
# Loaded dia67utt15_concatenated.npy
# Loaded dia749utt11_concatenated.npy
# Loaded dia993utt16_concatenated.npy
# Loaded dia879utt11_concatenated.npy
# Loaded dia406utt15_concatenated.npy
# Loaded dia634utt15_concatenated.npy
# Loaded dia1256utt18_concatenated.npy
# Loaded dia1333utt3_concatenated.npy
# Loaded dia604utt3_concatenated.npy
# Loaded dia733utt9_concatenated.npy
# Loaded dia1064utt18_concatenated.npy
# Loaded dia52utt6_concatenated.npy
# Loaded dia550utt1_concatenated.npy
# Loaded dia225utt1_concatenated.npy
# Loaded dia1223utt5_concatenated.npy
# Loaded dia241utt13_concatenated.npy
# Loaded dia807utt3_concatenated.npy
# Loaded dia1059utt3_concatenated.npy
# Loaded dia858utt4_concatenated.npy
# Loaded dia531utt4_concatenated.npy
# Loaded dia239utt10_concatenated.npy
# Loaded dia1225utt6_concatenated.npy
# Loaded dia314utt8_concatenated.npy
# Loaded dia1171utt4_concatenated.npy
# Loaded dia630utt4_concatenated.npy
# Loaded dia122utt2_concatenated.npy
# Loaded dia363utt17_concatenated.npy
# Loaded dia793utt8_concatenated.npy
# Loaded dia932utt10_concatenated.npy
# Loaded dia358utt4_concatenated.npy
# Loaded dia718utt3_concatenated.npy
# Loaded dia758utt9_concatenated.npy
# Loaded dia790utt14_concatenated.npy
# Loaded dia448utt13_concatenated.npy
# Loaded dia20utt8_concatenated.npy
# Loaded dia1055utt5_concatenated.npy
# Loaded dia327utt10_concatenated.npy
# Loaded dia481utt3_concatenated.npy
# Loaded dia636utt7_concatenated.npy
# Loaded dia124utt1_concatenated.npy
# Loaded dia1122utt5_concatenated.npy
# Loaded dia415utt5_concatenated.npy
# Loaded dia584utt12_concatenated.npy
# Loaded dia279utt23_concatenated.npy
# Loaded dia885utt3_concatenated.npy
# Loaded dia702utt3_concatenated.npy
# Loaded dia1010utt2_concatenated.npy
# Loaded dia790utt6_concatenated.npy
# Loaded dia817utt6_concatenated.npy
# Loaded dia342utt4_concatenated.npy
# Loaded dia939utt2_concatenated.npy
# Loaded dia789utt8_concatenated.npy
# Loaded dia643utt18_concatenated.npy
# Loaded dia279utt8_concatenated.npy
# Loaded dia239utt2_concatenated.npy
# Loaded dia896utt8_concatenated.npy
# Loaded dia134utt4_concatenated.npy
# Loaded dia1311utt2_concatenated.npy
# Loaded dia844utt7_concatenated.npy
# Loaded dia889utt5_concatenated.npy
# Loaded dia836utt12_concatenated.npy
# Loaded dia348utt1_concatenated.npy
# Loaded dia519utt10_concatenated.npy
# Loaded dia1293utt1_concatenated.npy
# Loaded dia464utt5_concatenated.npy
# Loaded dia1143utt13_concatenated.npy
# Loaded dia241utt9_concatenated.npy
# Loaded dia1046utt14_concatenated.npy
# Loaded dia800utt17_concatenated.npy
# Loaded dia407utt10_concatenated.npy
# Loaded dia993utt6_concatenated.npy
# Loaded dia365utt8_concatenated.npy
# Loaded dia540utt4_concatenated.npy
# Loaded dia1194utt2_concatenated.npy
# Loaded dia836utt9_concatenated.npy
# Loaded dia431utt7_concatenated.npy
# Loaded dia901utt3_concatenated.npy
# Loaded dia89utt10_concatenated.npy
# Loaded dia299utt3_concatenated.npy
# Loaded dia89utt2_concatenated.npy
# Loaded dia228utt3_concatenated.npy
# Loaded dia392utt1_concatenated.npy
# Loaded dia414utt1_concatenated.npy
# Loaded dia67utt5_concatenated.npy
# Loaded dia1012utt8_concatenated.npy
# Loaded dia668utt4_concatenated.npy
# Loaded dia800utt4_concatenated.npy
# Loaded dia536utt3_concatenated.npy
# Loaded dia971utt7_concatenated.npy
# Loaded dia353utt5_concatenated.npy
# Loaded dia662utt1_concatenated.npy
# Loaded dia455utt15_concatenated.npy
# Loaded dia838utt5_concatenated.npy
# Loaded dia667utt15_concatenated.npy
# Loaded dia508utt1_concatenated.npy
# Loaded dia691utt1_concatenated.npy
# Loaded dia1185utt3_concatenated.npy
# Loaded dia1245utt7_concatenated.npy
# Loaded dia603utt4_concatenated.npy
# Loaded dia111utt2_concatenated.npy
# Loaded dia867utt2_concatenated.npy
# Loaded dia1060utt6_concatenated.npy
# Loaded dia1245utt15_concatenated.npy
# Loaded dia148utt6_concatenated.npy
# Loaded dia988utt2_concatenated.npy
# Loaded dia779utt15_concatenated.npy
# Loaded dia598utt11_concatenated.npy
# Loaded dia327utt8_concatenated.npy
# Loaded dia502utt4_concatenated.npy
# Loaded dia210utt2_concatenated.npy
# Loaded dia473utt7_concatenated.npy
# Loaded dia943utt3_concatenated.npy
# Loaded dia1223utt20_concatenated.npy
# Loaded dia101utt7_concatenated.npy
# Loaded dia764utt1_concatenated.npy
# Loaded dia547utt3_concatenated.npy
# Loaded dia195utt1_concatenated.npy
# Loaded dia298utt7_concatenated.npy
# Loaded dia88utt6_concatenated.npy
# Loaded dia817utt10_concatenated.npy
# Loaded dia959utt3_concatenated.npy
# Loaded dia1195utt6_concatenated.npy
# Loaded dia1294utt6_concatenated.npy
# Loaded dia261utt14_concatenated.npy
# Loaded dia16utt5_concatenated.npy
# Loaded dia1023utt2_concatenated.npy
# Loaded dia909utt10_concatenated.npy
# Loaded dia473utt13_concatenated.npy
# Loaded dia49utt2_concatenated.npy
# Loaded dia1331utt9_concatenated.npy
# Loaded dia1371utt3_concatenated.npy
# Loaded dia586utt7_concatenated.npy
# Loaded dia294utt1_concatenated.npy
# Loaded dia225utt13_concatenated.npy
# Loaded dia512utt1_concatenated.npy
# Loaded dia932utt3_concatenated.npy
# Loaded dia1261utt5_concatenated.npy
# Loaded dia384utt7_concatenated.npy
# Loaded dia47utt12_concatenated.npy
# Loaded dia133utt3_concatenated.npy
# Loaded dia310utt1_concatenated.npy
# Loaded dia859utt16_concatenated.npy
# Loaded dia749utt8_concatenated.npy
# Loaded dia821utt15_concatenated.npy
# Loaded dia261utt2_concatenated.npy
# Loaded dia750utt6_concatenated.npy
# Loaded dia526utt6_concatenated.npy
# Loaded dia705utt4_concatenated.npy
# Loaded dia816utt2_concatenated.npy
# Loaded dia540utt11_concatenated.npy
# Loaded dia448utt8_concatenated.npy
# Loaded dia891utt15_concatenated.npy
# Loaded dia62utt8_concatenated.npy
# Loaded dia166utt1_concatenated.npy
# Loaded dia1160utt5_concatenated.npy
# Loaded dia1360utt14_concatenated.npy
# Loaded dia844utt6_concatenated.npy
# Loaded dia889utt4_concatenated.npy
# Loaded dia239utt3_concatenated.npy
# Loaded dia279utt9_concatenated.npy
# Loaded dia643utt19_concatenated.npy
# Loaded dia572utt1_concatenated.npy
# Loaded dia896utt9_concatenated.npy
# Loaded dia134utt5_concatenated.npy
# Loaded dia1311utt3_concatenated.npy
# Loaded dia1010utt3_concatenated.npy
# Loaded dia883utt1_concatenated.npy
# Loaded dia817utt7_concatenated.npy
# Loaded dia790utt7_concatenated.npy
# Loaded dia342utt5_concatenated.npy
# Loaded dia939utt3_concatenated.npy
# Loaded dia789utt9_concatenated.npy
# Loaded dia584utt13_concatenated.npy
# Loaded dia279utt22_concatenated.npy
# Loaded dia702utt2_concatenated.npy
# Loaded dia885utt2_concatenated.npy
# Loaded dia836utt8_concatenated.npy
# Loaded dia431utt6_concatenated.npy
# Loaded dia901utt2_concatenated.npy
# Loaded dia89utt11_concatenated.npy
# Loaded dia299utt2_concatenated.npy
# Loaded dia89utt3_concatenated.npy
# Loaded dia407utt11_concatenated.npy
# Loaded dia800utt16_concatenated.npy
# Loaded dia519utt1_concatenated.npy
# Loaded dia365utt9_concatenated.npy
# Loaded dia993utt7_concatenated.npy
# Loaded dia1194utt3_concatenated.npy
# Loaded dia540utt5_concatenated.npy
# Loaded dia519utt11_concatenated.npy
# Loaded dia464utt4_concatenated.npy
# Loaded dia1143utt12_concatenated.npy
# Loaded dia241utt8_concatenated.npy
# Loaded dia406utt14_concatenated.npy
# Loaded dia634utt14_concatenated.npy
# Loaded dia604utt2_concatenated.npy
# Loaded dia1333utt2_concatenated.npy
# Loaded dia1256utt19_concatenated.npy
# Loaded dia1064utt19_concatenated.npy
# Loaded dia733utt8_concatenated.npy
# Loaded dia461utt9_concatenated.npy
# Loaded dia421utt3_concatenated.npy
# Loaded dia67utt14_concatenated.npy
# Loaded dia749utt10_concatenated.npy
# Loaded dia993utt17_concatenated.npy
# Loaded dia879utt10_concatenated.npy
# Loaded dia58utt2_concatenated.npy
# Loaded dia779utt7_concatenated.npy
# Loaded dia145utt5_concatenated.npy
# Loaded dia1360utt3_concatenated.npy
# Loaded dia1320utt9_concatenated.npy
# Loaded dia1331utt21_concatenated.npy
# Loaded dia1143utt1_concatenated.npy
# Loaded dia591utt4_concatenated.npy
# Loaded dia988utt10_concatenated.npy
# Loaded dia758utt8_concatenated.npy
# Loaded dia718utt2_concatenated.npy
# Loaded dia448utt12_concatenated.npy
# Loaded dia481utt2_concatenated.npy
# Loaded dia20utt9_concatenated.npy
# Loaded dia327utt11_concatenated.npy
# Loaded dia1055utt4_concatenated.npy
# Loaded dia415utt4_concatenated.npy
# Loaded dia1122utt4_concatenated.npy
# Loaded dia636utt6_concatenated.npy
# Loaded dia276utt1_concatenated.npy
# Loaded dia793utt9_concatenated.npy
# Loaded dia630utt5_concatenated.npy
# Loaded dia122utt3_concatenated.npy
# Loaded dia363utt16_concatenated.npy
# Loaded dia932utt11_concatenated.npy
# Loaded dia358utt5_concatenated.npy
# Loaded dia858utt5_concatenated.npy
# Loaded dia1128utt1_concatenated.npy
# Loaded dia1225utt7_concatenated.npy
# Loaded dia239utt11_concatenated.npy
# Loaded dia531utt5_concatenated.npy
# Loaded dia314utt9_concatenated.npy
# Loaded dia801utt1_concatenated.npy
# Loaded dia1171utt5_concatenated.npy
# Loaded dia1223utt4_concatenated.npy
# Loaded dia807utt2_concatenated.npy
# Loaded dia241utt12_concatenated.npy
# Loaded dia1059utt2_concatenated.npy

# %%
Y_test
# Out:
# ['neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'joy',
#  'surprise',
#  'joy',
#  'sadness',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'anger',
#  'neutral',
#  'fear',
#  'joy',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'joy',
#  'neutral',
#  'disgust',
#  'neutral',
#  'surprise',
#  'surprise',
#  'sadness',
#  'neutral',
#  'neutral',
#  'sadness',
#  'joy',
#  'anger',
#  'surprise',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'joy',
#  'anger',
#  'joy',
#  'joy',
#  'neutral',
#  'surprise',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'surprise',
#  'joy',
#  'joy',
#  'surprise',
#  'joy',
#  'neutral',
#  'joy',
#  'joy',
#  'anger',
#  'neutral',
#  'joy',
#  'joy',
#  'surprise',
#  'sadness',
#  'anger',
#  'anger',
#  'joy',
#  'joy',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'anger',
#  'neutral',
#  'anger',
#  'surprise',
#  'joy',
#  'surprise',
#  'anger',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'anger',
#  'sadness',
#  'anger',
#  'surprise',
#  'sadness',
#  'neutral',
#  'fear',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'surprise',
#  'neutral',
#  'neutral',
#  'surprise',
#  'anger',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'anger',
#  'surprise',
#  'neutral',
#  'anger',
#  'sadness',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'disgust',
#  'neutral',
#  'joy',
#  'joy',
#  'joy',
#  'joy',
#  'sadness',
#  'neutral',
#  'fear',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'surprise',
#  'joy',
#  'anger',
#  'surprise',
#  'surprise',
#  'neutral',
#  'surprise',
#  'joy',
#  'surprise',
#  'joy',
#  'neutral',
#  'joy',
#  'anger',
#  'surprise',
#  'surprise',
#  'neutral',
#  'disgust',
#  'neutral',
#  'anger',
#  'sadness',
#  'neutral',
#  'anger',
#  'sadness',
#  'neutral',
#  'neutral',
#  'surprise',
#  'sadness',
#  'neutral',
#  'neutral',
#  'disgust',
#  'surprise',
#  'joy',
#  'fear',
#  'sadness',
#  'neutral',
#  'anger',
#  'surprise',
#  'surprise',
#  'neutral',
#  'joy',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'sadness',
#  'surprise',
#  'neutral',
#  'anger',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'joy',
#  'anger',
#  'anger',
#  'neutral',
#  'joy',
#  'disgust',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'joy',
#  'anger',
#  'neutral',
#  'fear',
#  'neutral',
#  'fear',
#  'anger',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'anger',
#  'fear',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'anger',
#  'surprise',
#  'neutral',
#  'anger',
#  'sadness',
#  'disgust',
#  'sadness',
#  'surprise',
#  'neutral',
#  'surprise',
#  'sadness',
#  'joy',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'sadness',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'sadness',
#  'sadness',
#  'joy',
#  'surprise',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'surprise',
#  'anger',
#  'surprise',
#  'surprise',
#  'neutral',
#  'joy',
#  'surprise',
#  'anger',
#  'joy',
#  'surprise',
#  'sadness',
#  'neutral',
#  'neutral',
#  'joy',
#  'surprise',
#  'joy',
#  'fear',
#  'anger',
#  'surprise',
#  'surprise',
#  'neutral',
#  'anger',
#  'joy',
#  'neutral',
#  'surprise',
#  'joy',
#  'neutral',
#  'neutral',
#  'surprise',
#  'sadness',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'surprise',
#  'neutral',
#  'surprise',
#  'joy',
#  'anger',
#  'joy',
#  'anger',
#  'neutral',
#  'surprise',
#  'sadness',
#  'neutral',
#  'surprise',
#  'joy',
#  'surprise',
#  'neutral',
#  'neutral',
#  'joy',
#  'surprise',
#  'joy',
#  'neutral',
#  'sadness',
#  'neutral',
#  'surprise',
#  'anger',
#  'anger',
#  'anger',
#  'surprise',
#  'neutral',
#  'disgust',
#  'neutral',
#  'fear',
#  'sadness',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'disgust',
#  'surprise',
#  'sadness',
#  'sadness',
#  'neutral',
#  'sadness',
#  'joy',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'joy',
#  'disgust',
#  'neutral',
#  'joy',
#  'disgust',
#  'neutral',
#  'surprise',
#  'joy',
#  'surprise',
#  'anger',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'disgust',
#  'joy',
#  'sadness',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'disgust',
#  'joy',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'sadness',
#  'anger',
#  'neutral',
#  'sadness',
#  'joy',
#  'fear',
#  'anger',
#  'sadness',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'joy',
#  'sadness',
#  'joy',
#  'sadness',
#  'neutral',
#  'anger',
#  'neutral',
#  'surprise',
#  'fear',
#  'surprise',
#  'joy',
#  'fear',
#  'joy',
#  'joy',
#  'neutral',
#  'joy',
#  'neutral',
#  'sadness',
#  'sadness',
#  'neutral',
#  'surprise',
#  'neutral',
#  'joy',
#  'sadness',
#  'joy',
#  'joy',
#  'joy',
#  'neutral',
#  'disgust',
#  'disgust',
#  'disgust',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'surprise',
#  'anger',
#  'neutral',
#  'surprise',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'sadness',
#  'surprise',
#  'neutral',
#  'neutral',
#  'disgust',
#  'neutral',
#  'anger',
#  'neutral',
#  'surprise',
#  'joy',
#  'anger',
#  'neutral',
#  'surprise',
#  'joy',
#  'anger',
#  'neutral',
#  'fear',
#  'neutral',
#  'sadness',
#  'neutral',
#  'joy',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'anger',
#  'sadness',
#  'disgust',
#  'neutral',
#  'surprise',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'sadness',
#  'neutral',
#  'anger',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'sadness',
#  'sadness',
#  'neutral',
#  'neutral',
#  'surprise',
#  'joy',
#  'neutral',
#  'joy',
#  'neutral',
#  'sadness',
#  'neutral',
#  'sadness',
#  'neutral',
#  'joy',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'joy',
#  'surprise',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'joy',
#  'anger',
#  'neutral',
#  'joy',
#  'neutral',
#  'surprise',
#  'joy',
#  'disgust',
#  'disgust',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'sadness',
#  'fear',
#  'surprise',
#  'joy',
#  'neutral',
#  'sadness',
#  'joy',
#  'joy',
#  'neutral',
#  'joy',
#  'neutral',
#  'sadness',
#  'anger',
#  'neutral',
#  'neutral',
#  'surprise',
#  'sadness',
#  'joy',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'surprise',
#  'joy',
#  'sadness',
#  'neutral',
#  'neutral',
#  'anger',
#  'surprise',
#  'sadness',
#  'disgust',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'sadness',
#  'surprise',
#  'neutral',
#  'anger',
#  'joy',
#  'neutral',
#  'neutral',
#  'surprise',
#  'joy',
#  'neutral',
#  'joy',
#  'surprise',
#  'neutral',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'surprise',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'fear',
#  'anger',
#  'sadness',
#  'surprise',
#  'neutral',
#  'anger',
#  'neutral',
#  'sadness',
#  'surprise',
#  'joy',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'sadness',
#  'joy',
#  'anger',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'joy',
#  'neutral',
#  'surprise',
#  'neutral',
#  'joy',
#  'joy',
#  'disgust',
#  'neutral',
#  'neutral',
#  'anger',
#  'surprise',
#  'joy',
#  'neutral',
#  'joy',
#  'anger',
#  'neutral',
#  'neutral',
#  'sadness',
#  'sadness',
#  'neutral',
#  'sadness',
#  'joy',
#  'neutral',
#  'sadness',
#  'sadness',
#  'neutral',
#  'disgust',
#  'anger',
#  'neutral',
#  'surprise',
#  'sadness',
#  'anger',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'anger',
#  'anger',
#  'sadness',
#  'sadness',
#  'neutral',
#  'anger',
#  'anger',
#  'neutral',
#  'disgust',
#  'neutral',
#  'surprise',
#  'sadness',
#  'neutral',
#  'anger',
#  'joy',
#  'joy',
#  'fear',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'surprise',
#  'surprise',
#  'neutral',
#  'neutral',
#  'anger',
#  'anger',
#  'neutral',
#  'sadness',
#  'joy',
#  'sadness',
#  'fear',
#  'joy',
#  'surprise',
#  'surprise',
#  'disgust',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'anger',
#  'joy',
#  'neutral',
#  'sadness',
#  'anger',
#  'joy',
#  'anger',
#  'neutral',
#  'anger',
#  'anger',
#  'neutral',
#  'joy',
#  'joy',
#  'disgust',
#  'sadness',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'sadness',
#  'joy',
#  'anger',
#  'disgust',
#  'anger',
#  'anger',
#  'fear',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'surprise',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'surprise',
#  'joy',
#  'sadness',
#  'anger',
#  'anger',
#  'surprise',
#  'sadness',
#  'surprise',
#  'surprise',
#  'joy',
#  'neutral',
#  'sadness',
#  'surprise',
#  'anger',
#  'neutral',
#  'joy',
#  'sadness',
#  'joy',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'joy',
#  'joy',
#  'joy',
#  'anger',
#  'anger',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'joy',
#  'sadness',
#  'joy',
#  'neutral',
#  'joy',
#  'neutral',
#  'joy',
#  'sadness',
#  'neutral',
#  'anger',
#  'neutral',
#  'sadness',
#  'surprise',
#  'surprise',
#  'anger',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'joy',
#  'surprise',
#  'neutral',
#  'neutral',
#  'neutral',
#  'sadness',
#  'anger',
#  'neutral',
#  'sadness',
#  'anger',
#  'joy',
#  'neutral',
#  'joy',
#  'neutral',
#  'surprise',
#  'anger',
#  'anger',
#  'surprise',
#  'disgust',
#  'joy',
#  'surprise',
#  'anger',
#  'joy',
#  'surprise',
#  'neutral',
#  'sadness',
#  'neutral',
#  'joy',
#  'neutral',
#  'anger',
#  'anger',
#  'joy',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'surprise',
#  'joy',
#  'anger',
#  'anger',
#  'joy',
#  'sadness',
#  'neutral',
#  'anger',
#  'joy',
#  'joy',
#  'neutral',
#  'neutral',
#  'sadness',
#  'neutral',
#  'neutral',
#  'neutral',
#  'surprise',
#  'neutral',
#  'neutral',
#  'fear',
#  'joy',
#  'neutral',
#  'neutral',
#  'sadness',
#  'sadness',
#  'neutral',
#  'joy',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'disgust',
#  'neutral',
#  'joy',
#  'joy',
#  'sadness',
#  'surprise',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'surprise',
#  'disgust',
#  'neutral',
#  'sadness',
#  'anger',
#  'sadness',
#  'surprise',
#  'anger',
#  'neutral',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'surprise',
#  'neutral',
#  'joy',
#  'neutral',
#  'neutral',
#  'anger',
#  'surprise',
#  'neutral',
#  'neutral',
#  'surprise',
#  'anger',
#  'joy',
#  'anger',
#  'joy',
#  'joy',
#  'surprise',
#  'anger',
#  'surprise',
#  'joy',
#  'neutral',
#  'neutral',
#  'anger',
#  'fear',
#  'anger',
#  'neutral',
#  'neutral',
#  'sadness',
#  'surprise',
#  'anger',
#  'joy',
#  'sadness',
#  'joy',
#  'neutral',
#  'neutral',
#  'anger',
#  'neutral',
#  'neutral',
#  'joy',
#  'neutral',
#  'anger',
#  'neutral',
#  'joy',
#  ...]

# %%
# Assigning to the specified variables
X_train_emotion = train_embeddings
Y_train_emotion = Y_train
X_test_emotion = test_embeddings
Y_test_emotion = Y_test

# Printing the arrays and their shapes
print('X_train_emotion:\n', np.array(X_train_emotion))
print('Y_train_emotion:\n', Y_train_emotion)
print('X_test_emotion:\n', np.array(X_test_emotion))
print('Y_test_emotion:\n', Y_test_emotion)

print('Shape of X_train_emotion:', np.array(X_train_emotion).shape)
#print('Shape of Y_train_emotion:', Y_train_emotion.shape)
print('Shape of X_test_emotion:', np.array(X_test_emotion).shape)
#print('Shape of Y_test_emotion:', Y_test_emotion.shape)
# Out:
# X_train_emotion:
#  [[[ 0.00610315 -0.04233586 -0.03267109 ... -0.24763183 -0.17301214
#     0.14470007]]
#
#  [[-0.06302285 -0.06895685 -0.01511406 ... -0.0931774  -0.17221317
#     0.03556742]]
#
#  [[-0.01879422  0.00930429 -0.01108927 ... -0.0219027  -0.20728719
#     0.09586193]]
#
#  ...
#
#  [[-0.03498007 -0.02649954  0.0456823  ... -0.1198136  -0.24607512
#     0.10069121]]
#
#  [[ 0.05089436 -0.05664142 -0.01564185 ... -0.09867117 -0.15780176
#     0.11430164]]
#
#  [[-0.01059369 -0.12625754 -0.02806858 ... -0.11804007 -0.18786113
#     0.11847226]]]
# Y_train_emotion:
#  ['sadness', 'neutral', 'surprise', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'joy', 'joy', 'surprise', 'surprise', 'joy', 'neutral', 'neutral', 'neutral', 'joy', 'neutral', 'disgust', 'anger', 'joy', 'sadness', 'neutral', 'joy', 'neutral', 'anger', 'neutral', 'neutral', 'disgust', 'neutral', 'anger', 'sadness', 'neutral', 'neutral', 'neutral', 'joy', 'neutral', 'neutral', 'joy', 'joy', 'joy', 'joy', 'neutral', 'neutral', 'joy', 'surprise', 'joy', 'joy', 'disgust', 'neutral', 'sadness', 'neutral', 'joy', 'surprise', 'neutral', 'neutral', 'sadness', 'neutral', 'neutral', 'neutral', 'neutral', 'sadness', 'anger', 'joy', 'sadness', 'sadness', 'joy', 'joy', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 
 'joy', 'neutral', 'neutral', 'neutral', 'neutral', 'anger', 'joy', 'anger', 'neutral', 'fear', 'neutral', 'fear', 'anger', 'neutral', 'neutral', 'joy', 'neutral', 'anger', 'neutral', 'neutral', 'anger', 'neutral', 'joy', 'neutral', 'neutral', 'anger', 'fear', 'neutral', 'neutral', 'joy', 'neutral', 'neutral', 'neutral', 'neutral', 'surprise', 'anger', 'surprise', 'neutral', 'anger', 'sadness', 'disgust', 'sadness', 'surprise', 'neutral', 'surprise', 'sadness', 'joy', 'anger', 'neutral', 'neutral', 'neutral', 'joy', 'sadness', 'neutral', 'joy', 'neutral', 'neutral', 'sadness', 'sadness', 'joy', 'surprise', 'neutral', 'joy', 'neutral', 'neutral', 'surprise', 'anger', 'surprise', 'surprise', 'neutral', 'joy', 'surprise', 'anger', 'joy', 'surprise', 'sadness', 'neutral', 'neutral', 'joy', 'surprise', 'joy', 'fear', 'anger', 'surprise', 'surprise', 'neutral', 'anger', 'joy', 'neutral', 'surprise', 'joy', 'neutral', 'neutral', 'surprise', 'sadness', 'neutral', 'neutral', 'sadness', 'neutral', 'neutral', 'neutral', 'sadness', 'neutral', 'surprise', 'neutral', 'surprise', 'joy', 'anger', 'joy', 'anger', 'neutral', 'surprise', 'sadness', 'neutral', 'surprise', 'joy', 'surprise', 'neutral', 'neutral', 'joy', 'surprise', 'joy', 'neutral', 'sadness', 'neutral', 'surprise', 'anger', 'anger', 'anger', 'surprise', 'neutral', 'disgust', 'neutral', 'fear', 'sadness', 'joy', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'neutral', 'disgust', 'surprise', 'sadness', 'sadness', 'neutral', 'sadness', 'joy', 'neutral', 'anger', 'neutral', ...
# Shape of X_train_emotion: (11053, 1, 2560)
# Shape of X_test_emotion: (2566, 1, 2560)

# %%
#train and test
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# Ensure that X_train_emotion and X_test_emotion are numpy arrays of the correct shape
# Flatten the arrays if they are not already 2D (necessary for sklearn)
X_train_emotion = np.array(X_train_emotion)
if len(X_train_emotion.shape) > 2:
    X_train_emotion = X_train_emotion.reshape(X_train_emotion.shape[0], -1)
X_test_emotion = np.array(X_test_emotion)
if len(X_test_emotion.shape) > 2:
    X_test_emotion = X_test_emotion.reshape(X_test_emotion.shape[0], -1)

# Initialize the MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(300,100), max_iter=300, activation='relu', solver='adam', learning_rate_init=0.001, random_state=42)

# Fit the classifier on the training data
mlp.fit(X_train_emotion, Y_train_emotion)

# Predict the labels for the test data
Y_pred_test = mlp.predict(X_test_emotion)

# Calculate the accuracy for the test set
test_accuracy = accuracy_score(Y_test_emotion, Y_pred_test)

print(f'Test accuracy: {test_accuracy:.4f}')
# Out:
# Test accuracy: 0.5452

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report, f1_score

# Ensure that X_train_emotion and X_test_emotion are numpy arrays of the correct shape
X_train_emotion = np.array(X_train_emotion)
if len(X_train_emotion.shape) > 2:
    X_train_emotion = X_train_emotion.reshape(X_train_emotion.shape[0], -1)
X_test_emotion = np.array(X_test_emotion)
if len(X_test_emotion.shape) > 2:
    X_test_emotion = X_test_emotion.reshape(X_test_emotion.shape[0], -1)

# Initialize the MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(300, 100), max_iter=300, activation='relu', solver='adam', learning_rate_init=0.001, random_state=42)

# Fit the classifier on the training data
mlp.fit(X_train_emotion, Y_train_emotion)

# Predict the labels for the training data
Y_pred_train = mlp.predict(X_train_emotion)

# Calculate the accuracy for the training set
train_accuracy = accuracy_score(Y_train_emotion, Y_pred_train)
print(f'Train accuracy: {train_accuracy:.4f}')
train_classification_report = classification_report(Y_train_emotion, Y_pred_train)
print("Training Set Classification Report:")
print(train_classification_report)
train_f1_score = f1_score(Y_train_emotion, Y_pred_train, average='weighted')
print(f'Train F1 Score: {train_f1_score:.4f}')



# Predict the labels for the test data
Y_pred_test = mlp.predict(X_test_emotion)

# Calculate the accuracy for the test set
test_accuracy = accuracy_score(Y_test_emotion, Y_pred_test)
print(f'Test accuracy: {test_accuracy:.4f}')
test_classification_report = classification_report(Y_test_emotion, Y_pred_test)
print("Test Set Classification Report:")
print(test_classification_report)
test_f1_score = f1_score(Y_test_emotion, Y_pred_test, average='weighted')
print(f'Test F1 Score: {test_f1_score:.4f}')
# Out:
# Train accuracy: 0.9999
# Training Set Classification Report:
#               precision    recall  f1-score   support
#
#        anger       1.00      1.00      1.00      1282
#      disgust       1.00      1.00      1.00       335
#         fear       1.00      1.00      1.00       317
#          joy       1.00      1.00      1.00      1872
#      neutral       1.00      1.00      1.00      4808
#      sadness       1.00      1.00      1.00       906
#     surprise       1.00      1.00      1.00      1533
#
#     accuracy                           1.00     11053
#    macro avg       1.00      1.00      1.00     11053
# weighted avg       1.00      1.00      1.00     11053
#
# Train F1 Score: 0.9999
# Test accuracy: 0.5452
# Test Set Classification Report:
#               precision    recall  f1-score   support
#
#        anger       0.44      0.36      0.40       333
#      disgust       0.09      0.09      0.09        79
#         fear       0.15      0.16      0.16        56
#          joy       0.50      0.48      0.49       429
#      neutral       0.67      0.74      0.70      1121
#      sadness       0.38      0.32      0.34       241
#     surprise       0.50      0.51      0.51       307
#
#     accuracy                           0.55      2566
#    macro avg       0.39      0.38      0.38      2566
# weighted avg       0.53      0.55      0.54      2566
#
# Test F1 Score: 0.5383

# %%
# Print all the file names for the training data
print("Training file names:")
for file_name in train_files:
    print(file_name)
# Out:
# Training file names:
# dia116utt4
# dia61utt2
# dia644utt8
# dia21utt8
# dia983utt2
# dia607utt15
# dia860utt4
# dia690utt4
# dia530utt12
# dia917utt4
# dia182utt2
# dia409utt11
# dia773utt2
# dia1279utt5
# dia1031utt12
# dia38utt6
# dia1097utt5
# dia1108utt11
# dia1134utt9
# dia1203utt12
# dia1003utt3
# dia168utt16
# dia509utt4
# dia1220utt1
# dia389utt12
# dia149utt3
# dia1091utt6
# dia1351utt2
# dia478utt7
# dia948utt3
# dia1049utt11
# dia227utt12
# dia1226utt2
# dia1170utt12
# dia1088utt8
# dia985utt1
# dia602utt1
# dia1308utt6
# dia471utt12
# dia795utt11
# dia911utt7
# dia556utt3
# dia244utt5
# dia184utt1
# dia775utt1
# dia597utt7
# dia617utt9
# dia72utt9
# dia32utt3
# dia285utt1
# dia618utt18
# dia474utt1
# dia503utt1
#  'dia3utt9': 'surprise',
#  'dia4utt1': 'sadness',
#  'dia4utt2': 'sadness',
#  'dia4utt3': 'sadness',
#  'dia5utt1': 'joy',
#  'dia5utt2': 'neutral',
#  'dia5utt3': 'joy',
#  'dia6utt1': 'neutral',
#  'dia6utt2': 'neutral',
#  'dia6utt3': 'surprise',
#  'dia6utt4': 'neutral',
#  'dia6utt5': 'neutral',
#  'dia6utt6': 'sadness',
#  'dia6utt7': 'neutral',
#  'dia6utt8': 'joy',
#  'dia6utt9': 'neutral',
#  'dia6utt10': 'neutral',
#  'dia7utt1': 'sadness',
#  'dia7utt2': 'surprise',
#  'dia7utt3': 'neutral',
#  'dia7utt4': 'surprise',
#  'dia7utt5': 'neutral',
#  'dia7utt6': 'neutral',
#  'dia7utt7': 'neutral',
#  'dia7utt8': 'neutral',
#  'dia7utt9': 'neutral',
#  'dia7utt10': 'neutral',
#  'dia8utt1': 'sadness',
#  'dia8utt2': 'neutral',
#  'dia8utt3': 'neutral',
#  'dia8utt4': 'neutral',
#  'dia8utt5': 'neutral',
#  'dia8utt6': 'neutral',
#  'dia8utt7': 'neutral',
#  'dia8utt8': 'neutral',
#  'dia8utt9': 'neutral',
#  'dia8utt10': 'neutral',
#  'dia8utt11': 'neutral',
#  'dia8utt12': 'joy',
#  'dia8utt13': 'joy',
#  'dia8utt14': 'neutral',
#  'dia8utt15': 'neutral',
#  'dia8utt16': 'joy',
#  'dia8utt17': 'surprise',
#  'dia9utt1': 'surprise',
#  'dia9utt2': 'neutral',
#  'dia9utt3': 'surprise',
#  'dia9utt4': 'neutral',
#  'dia9utt5': 'surprise',
#  'dia9utt6': 'neutral',
#  'dia10utt1': 'neutral',
#  'dia10utt2': 'joy',
#  'dia10utt3': 'joy',
#  'dia10utt4': 'surprise',
#  'dia10utt5': 'neutral',
#  'dia11utt1': 'disgust',
#  'dia11utt2': 'neutral',
#  'dia11utt3': 'neutral',
#  'dia11utt4': 'sadness',
#  'dia11utt5': 'neutral',
#  'dia12utt1': 'neutral',
#  'dia12utt2': 'anger',
#  'dia12utt3': 'neutral',
#  'dia12utt4': 'neutral',
#  'dia12utt5': 'neutral',
#  'dia12utt6': 'joy',
#  'dia12utt7': 'neutral',
#  'dia12utt8': 'neutral',
#  'dia12utt9': 'surprise',
#  'dia13utt1': 'neutral',
#  'dia13utt2': 'neutral',
#  'dia13utt3': 'joy',
#  'dia13utt4': 'surprise',
#  'dia13utt5': 'neutral',
#  'dia13utt6': 'joy',
#  'dia13utt7': 'joy',
#  'dia13utt8': 'joy',
#  'dia13utt9': 'neutral',
#  'dia13utt10': 'surprise',
#  'dia13utt11': 'neutral',
#  'dia13utt12': 'surprise',
#  'dia13utt13': 'joy',
#  'dia13utt14': 'neutral',
#  'dia14utt1': 'neutral',
#  'dia14utt2': 'neutral',
#  'dia14utt3': 'disgust',
#  'dia14utt4': 'anger',
#  'dia14utt5': 'disgust',
#  'dia14utt6': 'anger',
#  'dia14utt7': 'surprise',
#  'dia14utt8': 'anger',
#  'dia14utt9': 'anger',
#  'dia14utt10': 'anger',
#  'dia14utt11': 'anger',
#  'dia14utt12': 'anger',
#  'dia14utt13': 'disgust',
#  'dia14utt14': 'anger',
#  'dia14utt15': 'anger',
#  'dia14utt16': 'neutral',
#  'dia14utt17': 'neutral',
#  'dia14utt18': 'neutral',
#  'dia14utt19': 'anger',
#  'dia14utt20': 'neutral',
#  'dia14utt21': 'neutral',
#  'dia14utt22': 'neutral',
#  'dia14utt23': 'anger',
#  'dia15utt1': 'disgust',
#  'dia15utt2': 'disgust',
#  'dia15utt3': 'anger',
#  'dia15utt4': 'neutral',
#  'dia15utt5': 'neutral',
#  'dia15utt6': 'surprise',
#  'dia15utt7': 'joy',
#  'dia15utt8': 'surprise',
#  'dia15utt9': 'neutral',
#  'dia15utt10': 'neutral',
#  'dia15utt11': 'neutral',
#  'dia15utt12': 'neutral',
#  'dia15utt13': 'joy',
#  'dia15utt14': 'joy',
#  'dia15utt15': 'joy',
#  'dia15utt16': 'neutral',
#  'dia15utt17': 'neutral',
#  'dia17utt1': 'sadness',
#  'dia17utt2': 'sadness',
#  'dia17utt3': 'neutral',
#  'dia17utt4': 'neutral',
#  'dia17utt5': 'neutral',
#  'dia17utt6': 'neutral',
#  'dia17utt7': 'neutral',
#  'dia17utt8': 'neutral',
#  'dia17utt9': 'sadness',
#  'dia17utt10': 'sadness',
#  'dia19utt1': 'surprise',
#  'dia19utt2': 'neutral',
#  'dia19utt3': 'joy',
#  'dia19utt4': 'surprise',
#  'dia19utt5': 'neutral',
#  'dia19utt6': 'surprise',
#  'dia19utt7': 'anger',
#  'dia19utt8': 'neutral',
#  'dia19utt9': 'disgust',
#  'dia19utt10': 'neutral',
#  'dia19utt11': 'disgust',
#  'dia19utt12': 'neutral',
#  'dia19utt13': 'joy',
#  'dia21utt1': 'joy',
#  'dia21utt2': 'joy',
#  'dia21utt3': 'neutral',
#  'dia21utt4': 'neutral',
#  'dia21utt5': 'neutral',
#  'dia21utt6': 'surprise',
#  'dia21utt7': 'neutral',
#  'dia21utt8': 'neutral',
#  'dia21utt9': 'surprise',
#  'dia21utt10': 'neutral',
#  'dia21utt11': 'neutral',
#  'dia21utt12': 'joy',
#  'dia22utt1': 'neutral',
#  'dia22utt2': 'joy',
#  'dia22utt3': 'neutral',
#  'dia22utt4': 'neutral',
#  'dia24utt1': 'neutral',
#  'dia24utt2': 'neutral',
#  'dia24utt3': 'neutral',
#  'dia25utt1': 'sadness',
#  'dia25utt2': 'sadness',
#  'dia25utt3': 'neutral',
#  'dia25utt4': 'joy',
#  'dia25utt5': 'neutral',
#  'dia25utt6': 'neutral',
#  'dia25utt7': 'neutral',
#  'dia25utt8': 'sadness',
#  'dia25utt9': 'neutral',
#  'dia25utt10': 'sadness',
#  'dia25utt11': 'sadness',
#  'dia25utt12': 'surprise',
#  'dia25utt13': 'anger',
#  'dia25utt14': 'surprise',
#  'dia25utt15': 'neutral',
#  'dia25utt16': 'joy',
#  'dia25utt17': 'neutral',
#  'dia25utt18': 'neutral',
#  'dia25utt19': 'surprise',
#  'dia25utt20': 'sadness',
#  'dia25utt21': 'surprise',
#  'dia25utt22': 'neutral',
#  'dia25utt23': 'neutral',
#  'dia25utt24': 'joy',
#  'dia25utt25': 'joy',
#  'dia25utt26': 'sadness',
#  'dia27utt1': 'neutral',
#  'dia27utt2': 'neutral',
#  'dia27utt3': 'neutral',
#  'dia27utt4': 'sadness',
#  'dia27utt5': 'anger',
#  'dia27utt6': 'neutral',
#  'dia27utt7': 'neutral',
#  'dia27utt8': 'surprise',
#  'dia27utt9': 'neutral',
#  'dia29utt1': 'surprise',
#  'dia29utt2': 'surprise',
#  'dia29utt3': 'joy',
#  'dia29utt4': 'joy',
#  'dia29utt5': 'joy',
#  'dia29utt6': 'joy',
#  'dia30utt1': 'surprise',
#  'dia30utt2': 'joy',
#  'dia30utt3': 'surprise',
#  'dia30utt4': 'disgust',
#  'dia30utt5': 'neutral',
#  'dia30utt6': 'joy',
#  'dia30utt7': 'joy',
#  'dia30utt8': 'joy',
#  'dia30utt9': 'disgust',
#  'dia30utt10': 'neutral',
#  'dia30utt11': 'surprise',
#  'dia30utt12': 'neutral',
#  'dia30utt13': 'neutral',
#  'dia30utt14': 'neutral',
#  'dia30utt15': 'anger',
#  'dia30utt16': 'neutral',
#  'dia30utt17': 'neutral',
#  'dia30utt18': 'anger',
#  'dia30utt19': 'anger',
#  'dia30utt20': 'anger',
#  'dia30utt21': 'joy',
#  'dia31utt1': 'neutral',
#  'dia31utt2': 'neutral',
#  'dia31utt3': 'neutral',
#  'dia31utt4': 'neutral',
#  'dia31utt5': 'neutral',
#  'dia31utt6': 'neutral',
#  'dia31utt7': 'neutral',
#  'dia31utt8': 'surprise',
#  'dia31utt9': 'neutral',
#  'dia31utt10': 'neutral',
#  'dia31utt11': 'joy',
#  'dia31utt12': 'neutral',
#  'dia31utt13': 'neutral',
#  'dia31utt14': 'neutral',
#  'dia31utt15': 'neutral',
#  'dia32utt1': 'surprise',
#  'dia32utt2': 'surprise',
#  'dia32utt3': 'disgust',
#  'dia32utt4': 'sadness',
#  'dia32utt5': 'sadness',
#  'dia33utt1': 'neutral',
#  'dia33utt2': 'neutral',
#  'dia33utt3': 'neutral',
#  'dia33utt4': 'joy',
#  'dia33utt5': 'fear',
#  'dia33utt6': 'joy',
#  'dia33utt7': 'surprise',
#  'dia33utt8': 'disgust',
#  'dia33utt9': 'surprise',
#  'dia33utt10': 'sadness',
#  'dia33utt11': 'neutral',
#  'dia33utt12': 'anger',
#  'dia34utt1': 'neutral',
#  'dia34utt2': 'neutral',
#  'dia34utt3': 'surprise',
#  'dia34utt4': 'sadness',
#  'dia34utt5': 'neutral',
#  'dia34utt6': 'anger',
#  'dia35utt1': 'anger',
#  'dia35utt2': 'joy',
#  'dia35utt3': 'disgust',
#  'dia35utt4': 'neutral',
#  'dia35utt5': 'anger',
#  'dia35utt6': 'surprise',
#  'dia35utt7': 'anger',
#  'dia35utt8': 'neutral',
#  'dia35utt9': 'sadness',
#  'dia35utt10': 'neutral',
#  'dia35utt11': 'neutral',
#  'dia35utt12': 'neutral',
#  'dia35utt13': 'neutral',
#  'dia35utt14': 'anger',
#  'dia35utt15': 'anger',
#  'dia35utt16': 'anger',
#  'dia36utt1': 'joy',
#  'dia36utt2': 'neutral',
#  'dia36utt3': 'neutral',
#  'dia36utt4': 'surprise',
#  'dia36utt5': 'surprise',
#  'dia36utt6': 'surprise',
#  'dia36utt7': 'neutral',
#  'dia37utt1': 'neutral',
#  'dia37utt2': 'joy',
#  'dia38utt1': 'joy',
#  'dia38utt2': 'joy',
#  'dia38utt3': 'joy',
#  'dia38utt4': 'joy',
#  'dia38utt5': 'surprise',
#  'dia38utt6': 'neutral',
#  'dia39utt1': 'neutral',
#  'dia39utt2': 'neutral',
#  'dia39utt3': 'neutral',
#  'dia39utt4': 'neutral',
#  'dia39utt5': 'sadness',
#  'dia39utt6': 'fear',
#  'dia39utt7': 'sadness',
#  'dia40utt1': 'joy',
#  'dia40utt2': 'neutral',
#  'dia40utt3': 'neutral',
#  'dia40utt4': 'sadness',
#  'dia40utt5': 'neutral',
#  'dia40utt6': 'fear',
#  'dia40utt7': 'neutral',
#  'dia40utt8': 'fear',
#  'dia40utt9': 'anger',
#  'dia40utt10': 'fear',
#  'dia41utt1': 'joy',
#  'dia41utt2': 'joy',
#  'dia41utt3': 'neutral',
#  'dia41utt4': 'surprise',
#  'dia41utt5': 'surprise',
#  'dia41utt6': 'anger',
#  'dia41utt7': 'neutral',
#  'dia41utt8': 'disgust',
#  'dia41utt9': 'neutral',
#  'dia41utt10': 'disgust',
#  'dia41utt11': 'neutral',
#  'dia41utt12': 'disgust',
#  'dia41utt13': 'neutral',
#  'dia41utt14': 'surprise',
#  'dia41utt15': 'surprise',
#  'dia41utt16': 'disgust',
#  'dia41utt17': 'sadness',
#  'dia41utt18': 'surprise',
#  'dia41utt19': 'neutral',
#  'dia42utt1': 'neutral',
#  'dia42utt2': 'surprise',
#  'dia42utt3': 'surprise',
#  'dia42utt4': 'sadness',
#  'dia42utt5': 'sadness',
#  'dia42utt6': 'surprise',
#  'dia42utt7': 'neutral',
#  'dia42utt8': 'joy',
#  'dia42utt9': 'neutral',
#  'dia42utt10': 'neutral',
#  'dia42utt11': 'neutral',
#  'dia42utt12': 'fear',
#  'dia42utt13': 'neutral',
#  'dia42utt14': 'surprise',
#  'dia42utt15': 'neutral',
#  'dia42utt16': 'neutral',
#  'dia42utt17': 'neutral',
#  'dia44utt1': 'sadness',
#  'dia44utt2': 'neutral',
#  'dia44utt3': 'sadness',
#  'dia44utt4': 'sadness',
#  'dia44utt5': 'joy',
#  'dia44utt6': 'neutral',
#  'dia44utt7': 'neutral',
#  'dia44utt8': 'joy',
#  'dia44utt9': 'joy',
#  'dia44utt10': 'joy',
#  'dia44utt11': 'neutral',
#  'dia44utt12': 'sadness',
#  'dia44utt13': 'neutral',
#  'dia44utt14': 'neutral',
#  'dia44utt15': 'joy',
#  'dia44utt16': 'neutral',
#  'dia45utt1': 'sadness',
#  'dia45utt2': 'disgust',
#  'dia45utt3': 'neutral',
#  'dia45utt4': 'sadness',
#  'dia45utt5': 'neutral',
#  'dia45utt6': 'surprise',
#  'dia45utt7': 'joy',
#  'dia45utt8': 'joy',
#  'dia45utt9': 'surprise',
#  'dia45utt10': 'joy',
#  'dia45utt11': 'fear',
#  'dia45utt12': 'joy',
#  'dia45utt13': 'neutral',
#  'dia45utt14': 'neutral',
#  'dia45utt15': 'neutral',
#  'dia45utt16': 'neutral',
#  'dia45utt17': 'joy',
#  'dia45utt18': 'surprise',
#  'dia48utt1': 'anger',
#  'dia48utt2': 'joy',
#  'dia48utt3': 'neutral',
#  'dia48utt4': 'surprise',
#  'dia50utt1': 'surprise',
#  'dia50utt2': 'neutral',
#  'dia50utt3': 'surprise',
#  'dia50utt4': 'neutral',
#  'dia50utt5': 'neutral',
#  'dia50utt6': 'neutral',
#  'dia50utt7': 'joy',
#  'dia53utt1': 'neutral',
#  'dia53utt2': 'neutral',
#  'dia53utt3': 'surprise',
#  'dia53utt4': 'neutral',
#  'dia53utt5': 'neutral',
#  'dia53utt6': 'surprise',
#  'dia53utt7': 'neutral',
#  'dia53utt8': 'neutral',
#  'dia53utt9': 'neutral',
#  'dia53utt10': 'neutral',
#  'dia53utt11': 'surprise',
#  'dia53utt12': 'neutral',
#  'dia53utt13': 'neutral',
#  'dia53utt14': 'neutral',
#  'dia54utt1': 'neutral',
#  'dia54utt2': 'surprise',
#  'dia54utt3': 'neutral',
#  'dia54utt4': 'surprise',
#  'dia54utt5': 'neutral',
#  'dia54utt6': 'joy',
#  'dia55utt1': 'neutral',
#  'dia55utt2': 'neutral',
#  'dia55utt3': 'neutral',
#  'dia55utt4': 'surprise',
#  'dia55utt5': 'neutral',
#  'dia55utt6': 'neutral',
#  'dia55utt7': 'joy',
#  'dia55utt8': 'surprise',
#  'dia55utt9': 'joy',
#  'dia55utt10': 'neutral',
#  'dia55utt11': 'neutral',
#  'dia55utt12': 'anger',
#  'dia55utt13': 'neutral',
#  'dia55utt14': 'anger',
#  'dia55utt15': 'anger',
#  'dia55utt16': 'anger',
#  'dia55utt17': 'surprise',
#  'dia55utt18': 'surprise',
#  'dia56utt1': 'joy',
#  'dia56utt2': 'neutral',
#  'dia56utt3': 'neutral',
#  'dia56utt4': 'neutral',
#  'dia56utt5': 'surprise',
#  'dia56utt6': 'neutral',
#  'dia56utt7': 'surprise',
#  'dia56utt8': 'surprise',
#  'dia56utt9': 'fear',
#  'dia57utt1': 'neutral',
#  'dia57utt2': 'neutral',
#  'dia57utt3': 'sadness',
#  'dia57utt4': 'disgust',
#  'dia57utt5': 'anger',
#  'dia57utt6': 'neutral',
#  'dia59utt1': 'surprise',
#  'dia59utt2': 'neutral',
#  'dia59utt3': 'neutral',
#  'dia59utt4': 'neutral',
#  'dia59utt5': 'neutral',
#  'dia59utt6': 'fear',
#  'dia59utt7': 'joy',
#  'dia59utt8': 'joy',
#  'dia59utt9': 'neutral',
#  'dia59utt10': 'neutral',
#  'dia60utt1': 'neutral',
#  'dia60utt2': 'joy',
#  'dia60utt3': 'neutral',
#  'dia60utt4': 'neutral',
#  'dia60utt5': 'neutral',
#  'dia61utt1': 'neutral',
#  'dia61utt2': 'neutral',
#  'dia61utt3': 'neutral',
#  'dia61utt4': 'neutral',
#  'dia61utt5': 'neutral',
#  'dia61utt6': 'neutral',
#  'dia61utt7': 'surprise',
#  'dia61utt8': 'surprise',
#  'dia61utt9': 'fear',
#  'dia61utt10': 'anger',
#  'dia61utt11': 'disgust',
#  'dia61utt12': 'disgust',
#  'dia63utt1': 'sadness',
#  'dia63utt2': 'sadness',
#  'dia63utt3': 'sadness',
#  'dia63utt4': 'anger',
#  'dia63utt5': 'surprise',
#  'dia63utt6': 'surprise',
#  'dia63utt7': 'neutral',
#  'dia63utt8': 'neutral',
#  'dia63utt9': 'anger',
#  'dia63utt10': 'neutral',
#  'dia63utt11': 'neutral',
#  'dia63utt12': 'surprise',
#  'dia63utt13': 'neutral',
#  'dia63utt14': 'surprise',
#  'dia63utt15': 'disgust',
#  'dia63utt16': 'joy',
#  'dia63utt17': 'joy',
#  'dia63utt18': 'joy',
#  'dia63utt19': 'neutral',
#  'dia66utt1': 'surprise',
#  'dia66utt2': 'neutral',
#  'dia66utt3': 'surprise',
#  'dia66utt4': 'surprise',
#  'dia66utt5': 'surprise',
#  'dia66utt6': 'neutral',
#  'dia66utt7': 'surprise',
#  'dia66utt8': 'neutral',
#  'dia66utt9': 'neutral',
#  'dia66utt10': 'joy',
#  'dia68utt1': 'neutral',
#  'dia68utt2': 'neutral',
#  'dia68utt3': 'neutral',
#  'dia68utt4': 'surprise',
#  'dia68utt5': 'neutral',
#  'dia69utt1': 'neutral',
#  'dia69utt2': 'joy',
#  'dia69utt3': 'joy',
#  'dia69utt4': 'neutral',
#  'dia69utt5': 'surprise',
#  'dia69utt6': 'anger',
#  'dia69utt7': 'neutral',
#  'dia69utt8': 'sadness',
#  'dia69utt9': 'neutral',
#  'dia69utt10': 'sadness',
#  'dia69utt11': 'surprise',
#  'dia69utt12': 'sadness',
#  'dia70utt1': 'anger',
#  'dia70utt2': 'sadness',
#  'dia70utt3': 'surprise',
#  'dia70utt4': 'sadness',
#  'dia70utt5': 'neutral',
#  'dia70utt6': 'joy',
#  'dia70utt7': 'surprise',
#  'dia70utt8': 'surprise',
#  'dia70utt9': 'neutral',
#  'dia70utt10': 'neutral',
#  'dia70utt11': 'neutral',
#  'dia70utt12': 'neutral',
#  'dia70utt13': 'sadness',
#  'dia70utt14': 'surprise',
#  'dia70utt15': 'neutral',
#  'dia70utt16': 'neutral',
#  'dia70utt17': 'neutral',
#  'dia72utt1': 'joy',
#  'dia72utt2': 'neutral',
#  'dia72utt3': 'joy',
#  'dia72utt4': 'joy',
#  'dia72utt5': 'joy',
#  'dia72utt6': 'joy',
#  'dia72utt7': 'joy',
#  'dia72utt8': 'joy',
#  'dia72utt9': 'joy',
#  'dia72utt10': 'joy',
#  'dia72utt11': 'joy',
#  'dia73utt1': 'neutral',
#  'dia73utt2': 'anger',
#  'dia73utt3': 'neutral',
#  'dia73utt4': 'neutral',
#  'dia73utt5': 'neutral',
#  'dia73utt6': 'neutral',
#  'dia73utt7': 'neutral',
#  'dia73utt8': 'neutral',
#  'dia73utt9': 'joy',
#  'dia73utt10': 'neutral',
#  'dia73utt11': 'neutral',
#  'dia75utt1': 'neutral',
#  'dia75utt2': 'surprise',
#  'dia75utt3': 'neutral',
#  'dia75utt4': 'surprise',
#  'dia75utt5': 'joy',
#  'dia75utt6': 'joy',
#  'dia75utt7': 'neutral',
#  'dia75utt8': 'anger',
#  'dia75utt9': 'neutral',
#  'dia75utt10': 'anger',
#  'dia75utt11': 'joy',
#  'dia75utt12': 'anger',
#  'dia75utt13': 'joy',
#  'dia75utt14': 'joy',
#  'dia75utt15': 'surprise',
#  'dia76utt1': 'sadness',
#  'dia76utt2': 'neutral',
#  'dia76utt3': 'neutral',
#  'dia76utt4': 'disgust',
#  'dia76utt5': 'joy',
#  'dia76utt6': 'neutral',
#  'dia76utt7': 'neutral',
#  'dia76utt8': 'neutral',
#  'dia76utt9': 'joy',
#  'dia76utt10': 'anger',
#  'dia76utt11': 'joy',
#  'dia76utt12': 'joy',
#  'dia76utt13': 'disgust',
#  'dia76utt14': 'joy',
#  'dia77utt1': 'neutral',
#  'dia77utt2': 'neutral',
#  'dia77utt3': 'neutral',
#  'dia77utt4': 'neutral',
#  'dia77utt5': 'neutral',
#  'dia78utt1': 'surprise',
#  'dia78utt2': 'surprise',
#  'dia78utt3': 'surprise',
#  'dia78utt4': 'neutral',
#  'dia78utt5': 'neutral',
#  'dia78utt6': 'neutral',
#  'dia78utt7': 'anger',
#  'dia78utt8': 'neutral',
#  'dia78utt9': 'neutral',
#  'dia78utt10': 'neutral',
#  'dia78utt11': 'surprise',
#  'dia78utt12': 'surprise',
#  'dia78utt13': 'neutral',
#  'dia80utt1': 'anger',
#  'dia80utt2': 'neutral',
#  'dia80utt3': 'anger',
#  'dia80utt4': 'anger',
#  'dia80utt5': 'anger',
#  'dia80utt6': 'surprise',
#  'dia80utt7': 'disgust',
#  'dia80utt8': 'neutral',
#  'dia80utt9': 'neutral',
#  'dia80utt10': 'neutral',
#  'dia80utt11': 'neutral',
#  'dia80utt12': 'neutral',
#  'dia80utt13': 'neutral',
#  'dia80utt14': 'surprise',
#  'dia80utt15': 'neutral',
#  'dia80utt16': 'fear',
#  'dia80utt17': 'neutral',
#  'dia80utt18': 'anger',
#  'dia80utt19': 'anger',
#  'dia80utt20': 'sadness',
#  'dia80utt21': 'sadness',
#  'dia81utt1': 'surprise',
#  'dia81utt2': 'neutral',
#  'dia81utt3': 'surprise',
#  'dia81utt4': 'neutral',
#  'dia81utt5': 'joy',
#  'dia81utt6': 'anger',
#  'dia81utt7': 'joy',
#  'dia81utt8': 'neutral',
#  'dia81utt9': 'neutral',
#  'dia81utt10': 'joy',
#  'dia81utt11': 'anger',
#  'dia81utt12': 'neutral',
#  'dia81utt13': 'sadness',
#  'dia81utt14': 'neutral',
#  'dia81utt15': 'surprise',
#  'dia81utt16': 'neutral',
#  'dia81utt17': 'neutral',
#  'dia81utt18': 'neutral',
#  'dia81utt19': 'neutral',
#  'dia81utt20': 'neutral',
#  'dia81utt21': 'anger',
#  'dia81utt22': 'surprise',
#  'dia81utt23': 'neutral',
#  'dia82utt1': 'neutral',
#  'dia82utt2': 'surprise',
#  'dia82utt3': 'surprise',
#  'dia82utt4': 'surprise',
#  'dia82utt5': 'neutral',
#  'dia82utt6': 'neutral',
#  'dia82utt7': 'surprise',
#  'dia82utt8': 'neutral',
#  'dia82utt9': 'disgust',
#  'dia82utt10': 'surprise',
#  'dia82utt11': 'neutral',
#  'dia82utt12': 'surprise',
#  'dia82utt13': 'surprise',
#  'dia82utt14': 'joy',
#  'dia82utt15': 'neutral',
#  'dia82utt16': 'anger',
#  'dia82utt17': 'neutral',
#  'dia82utt18': 'neutral',
#  'dia82utt19': 'fear',
#  'dia82utt20': 'neutral',
#  'dia83utt1': 'anger',
#  'dia83utt2': 'surprise',
#  'dia83utt3': 'anger',
#  'dia83utt4': 'neutral',
#  'dia83utt5': 'neutral',
#  'dia83utt6': 'neutral',
#  'dia83utt7': 'neutral',
#  'dia83utt8': 'anger',
#  'dia83utt9': 'anger',
#  'dia83utt10': 'sadness',
#  'dia83utt11': 'sadness',
#  'dia84utt1': 'joy',
#  'dia84utt2': 'joy',
#  'dia84utt3': 'neutral',
#  'dia84utt4': 'neutral',
#  'dia84utt5': 'neutral',
#  'dia84utt6': 'neutral',
#  'dia84utt7': 'fear',
#  'dia84utt8': 'surprise',
#  'dia84utt9': 'neutral',
#  'dia84utt10': 'neutral',
#  'dia84utt11': 'surprise',
#  'dia84utt12': 'neutral',
#  'dia84utt13': 'surprise',
#  'dia84utt14': 'neutral',
#  'dia84utt15': 'neutral',
#  'dia84utt16': 'sadness',
#  'dia85utt1': 'neutral',
#  'dia85utt2': 'joy',
#  'dia85utt3': 'joy',
#  'dia85utt4': 'neutral',
#  'dia85utt5': 'joy',
#  'dia85utt6': 'joy',
#  'dia86utt1': 'neutral',
#  'dia86utt2': 'sadness',
#  'dia86utt3': 'neutral',
#  'dia86utt4': 'neutral',
#  'dia86utt5': 'surprise',
#  'dia86utt6': 'neutral',
#  'dia86utt7': 'sadness',
#  'dia86utt8': 'anger',
#  'dia86utt9': 'anger',
#  'dia86utt10': 'sadness',
#  'dia86utt11': 'surprise',
#  'dia86utt12': 'sadness',
#  'dia86utt13': 'sadness',
#  'dia86utt14': 'surprise',
#  'dia86utt15': 'sadness',
#  'dia86utt16': 'disgust',
#  'dia86utt17': 'disgust',
#  'dia86utt18': 'disgust',
#  'dia86utt19': 'disgust',
#  'dia86utt20': 'joy',
#  'dia87utt1': 'sadness',
#  'dia87utt2': 'surprise',
#  'dia87utt3': 'joy',
#  'dia87utt4': 'neutral',
#  'dia87utt5': 'neutral',
#  'dia87utt6': 'sadness',
#  'dia87utt7': 'sadness',
#  'dia87utt8': 'neutral',
#  'dia87utt9': 'sadness',
#  'dia90utt1': 'sadness',
#  'dia90utt2': 'neutral',
#  'dia90utt3': 'surprise',
#  'dia90utt4': 'surprise',
#  'dia90utt5': 'neutral',
#  'dia90utt6': 'neutral',
#  'dia90utt7': 'neutral',
#  'dia90utt8': 'surprise',
#  'dia90utt9': 'neutral',
#  'dia90utt10': 'neutral',
#  'dia90utt11': 'neutral',
#  'dia90utt12': 'neutral',
#  'dia90utt13': 'neutral',
#  'dia90utt14': 'neutral',
#  'dia90utt15': 'disgust',
#  'dia90utt16': 'neutral',
#  'dia90utt17': 'disgust',
#  'dia90utt18': 'surprise',
#  'dia91utt1': 'neutral',
#  'dia91utt2': 'neutral',
#  'dia91utt3': 'neutral',
#  'dia91utt4': 'neutral',
#  'dia91utt5': 'joy',
#  'dia91utt6': 'neutral',
#  'dia91utt7': 'neutral',
#  'dia91utt8': 'surprise',
#  'dia92utt1': 'disgust',
#  'dia92utt2': 'sadness',
#  'dia92utt3': 'neutral',
#  'dia92utt4': 'neutral',
#  'dia92utt5': 'neutral',
#  'dia92utt6': 'neutral',
#  'dia92utt7': 'sadness',
#  'dia92utt8': 'sadness',
#  'dia92utt9': 'neutral',
#  'dia92utt10': 'neutral',
#  'dia92utt11': 'neutral',
#  'dia92utt12': 'neutral',
#  'dia92utt13': 'neutral',
#  'dia92utt14': 'neutral',
#  'dia92utt15': 'neutral',
#  'dia92utt16': 'neutral',
#  'dia92utt17': 'joy',
#  'dia92utt18': 'neutral',
#  'dia92utt19': 'neutral',
#  'dia92utt20': 'anger',
#  'dia93utt1': 'neutral',
#  'dia93utt2': 'joy',
#  'dia93utt3': 'neutral',
#  'dia93utt4': 'joy',
#  'dia93utt5': 'neutral',
#  'dia93utt6': 'neutral',
#  'dia93utt7': 'neutral',
#  'dia93utt8': 'neutral',
#  'dia93utt9': 'disgust',
#  'dia93utt10': 'disgust',
#  'dia93utt11': 'sadness',
#  'dia93utt12': 'neutral',
#  'dia93utt13': 'neutral',
#  'dia93utt14': 'neutral',
#  'dia93utt15': 'disgust',
#  'dia93utt16': 'sadness',
#  'dia94utt1': 'surprise',
#  'dia94utt2': 'neutral',
#  'dia94utt3': 'surprise',
#  'dia95utt1': 'neutral',
#  'dia95utt2': 'neutral',
#  'dia95utt3': 'neutral',
#  'dia95utt4': 'sadness',
#  'dia95utt5': 'surprise',
#  'dia95utt6': 'joy',
#  'dia95utt7': 'surprise',
#  'dia95utt8': 'neutral',
#  'dia97utt1': 'neutral',
#  'dia97utt2': 'neutral',
#  'dia97utt3': 'disgust',
#  'dia97utt4': 'sadness',
#  'dia97utt5': 'neutral',
#  'dia97utt6': 'surprise',
#  'dia98utt1': 'neutral',
#  'dia98utt2': 'sadness',
#  'dia98utt3': 'anger',
#  'dia98utt4': 'neutral',
#  'dia98utt5': 'sadness',
#  'dia98utt6': 'neutral',
#  'dia98utt7': 'joy',
#  'dia98utt8': 'neutral',
#  'dia98utt9': 'neutral',
#  'dia98utt10': 'neutral',
#  'dia98utt11': 'neutral',
#  'dia98utt12': 'joy',
#  'dia99utt1': 'neutral',
#  'dia99utt2': 'neutral',
#  'dia99utt3': 'neutral',
#  'dia99utt4': 'neutral',
#  'dia99utt5': 'joy',
#  'dia99utt6': 'joy',
#  'dia99utt7': 'neutral',
#  'dia99utt8': 'neutral',
#  'dia99utt9': 'neutral',
#  'dia99utt10': 'surprise',
#  'dia99utt11': 'surprise',
#  'dia99utt12': 'surprise',
#  'dia99utt13': 'anger',
#  'dia100utt1': 'anger',
#  'dia100utt2': 'anger',
#  'dia100utt3': 'anger',
#  'dia100utt4': 'anger',
#  'dia100utt5': 'anger',
#  'dia102utt1': 'neutral',
#  'dia102utt2': 'joy',
#  'dia102utt3': 'surprise',
#  'dia102utt4': 'neutral',
#  'dia102utt5': 'surprise',
#  'dia102utt6': 'neutral',
#  'dia102utt7': 'surprise',
#  'dia102utt8': 'neutral',
#  'dia103utt1': 'neutral',
#  'dia103utt2': 'neutral',
#  'dia103utt3': 'neutral',
#  'dia103utt4': 'neutral',
#  'dia103utt5': 'neutral',
#  'dia103utt6': 'neutral',
#  'dia103utt7': 'neutral',
#  'dia103utt8': 'neutral',
#  'dia103utt9': 'neutral',
#  'dia103utt10': 'surprise',
#  'dia103utt11': 'surprise',
#  'dia103utt12': 'neutral',
#  'dia103utt13': 'disgust',
#  'dia103utt14': 'neutral',
#  'dia103utt15': 'neutral',
#  'dia104utt1': 'neutral',
#  'dia104utt2': 'neutral',
#  'dia104utt3': 'sadness',
#  'dia104utt4': 'anger',
#  'dia104utt5': 'sadness',
#  'dia104utt6': 'sadness',
#  'dia104utt7': 'joy',
#  'dia104utt8': 'joy',
#  'dia104utt9': 'neutral',
#  'dia104utt10': 'sadness',
#  'dia104utt11': 'neutral',
#  'dia104utt12': 'neutral',
#  'dia104utt13': 'neutral',
#  'dia104utt14': 'neutral',
#  'dia104utt15': 'joy',
#  'dia104utt16': 'neutral',
#  'dia104utt17': 'neutral',
#  'dia104utt18': 'neutral',
#  'dia104utt19': 'joy',
#  'dia105utt1': 'neutral',
#  'dia105utt2': 'surprise',
#  'dia105utt3': 'joy',
#  'dia105utt4': 'neutral',
#  'dia105utt5': 'neutral',
#  'dia105utt6': 'neutral',
#  'dia105utt7': 'neutral',
#  'dia105utt8': 'neutral',
#  'dia105utt9': 'surprise',
#  'dia105utt10': 'neutral',
#  'dia106utt1': 'neutral',
#  'dia106utt2': 'joy',
#  'dia106utt3': 'joy',
#  'dia106utt4': 'neutral',
#  'dia106utt5': 'joy',
#  'dia107utt1': 'surprise',
#  'dia107utt2': 'joy',
#  'dia107utt3': 'joy',
#  'dia107utt4': 'joy',
#  'dia108utt1': 'neutral',
#  'dia108utt2': 'neutral',
#  'dia108utt3': 'neutral',
#  'dia108utt4': 'neutral',
#  'dia108utt5': 'neutral',
#  'dia108utt6': 'neutral',
#  'dia108utt7': 'neutral',
#  'dia108utt8': 'neutral',
#  'dia108utt9': 'surprise',
#  'dia108utt10': 'surprise',
#  'dia109utt1': 'neutral',
#  'dia109utt2': 'neutral',
#  'dia109utt3': 'neutral',
#  'dia109utt4': 'fear',
#  'dia110utt1': 'neutral',
#  'dia110utt2': 'neutral',
#  'dia110utt3': 'neutral',
#  'dia110utt4': 'neutral',
#  'dia113utt1': 'joy',
#  'dia113utt2': 'neutral',
#  'dia113utt3': 'neutral',
#  'dia113utt4': 'neutral',
#  'dia113utt5': 'neutral',
#  'dia113utt6': 'neutral',
#  'dia113utt7': 'neutral',
#  'dia113utt8': 'surprise',
#  'dia114utt1': 'surprise',
#  'dia114utt2': 'joy',
#  'dia114utt3': 'surprise',
#  'dia114utt4': 'joy',
#  'dia114utt5': 'surprise',
#  'dia115utt1': 'neutral',
#  'dia115utt2': 'neutral',
#  'dia115utt3': 'joy',
#  'dia115utt4': 'neutral',
#  'dia115utt5': 'neutral',
#  'dia117utt1': 'anger',
#  'dia117utt2': 'anger',
#  'dia117utt3': 'disgust',
#  'dia118utt1': 'neutral',
#  'dia118utt2': 'neutral',
#  'dia118utt3': 'neutral',
#  'dia118utt4': 'neutral',
#  'dia118utt5': 'neutral',
#  'dia119utt1': 'neutral',
#  'dia119utt2': 'surprise',
#  'dia119utt3': 'neutral',
#  'dia119utt4': 'sadness',
#  'dia119utt5': 'sadness',
#  'dia119utt6': 'sadness',
#  'dia119utt7': 'neutral',
#  'dia119utt8': 'surprise',
#  'dia119utt9': 'neutral',
#  'dia119utt10': 'joy',
#  'dia119utt11': 'neutral',
#  'dia119utt12': 'surprise',
#  'dia119utt13': 'neutral',
#  'dia119utt14': 'sadness',
#  'dia119utt15': 'sadness',
#  'dia119utt16': 'sadness',
#  'dia119utt17': 'sadness',
#  'dia120utt1': 'anger',
#  'dia120utt2': 'neutral',
#  'dia120utt3': 'joy',
#  'dia120utt4': 'surprise',
#  'dia120utt5': 'neutral',
#  'dia120utt6': 'surprise',
#  'dia120utt7': 'neutral',
#  'dia120utt8': 'disgust',
#  'dia120utt9': 'surprise',
#  'dia120utt10': 'neutral',
#  'dia120utt11': 'joy',
#  'dia121utt1': 'neutral',
#  'dia121utt2': 'neutral',
#  'dia121utt3': 'neutral',
#  'dia121utt4': 'surprise',
#  'dia121utt5': 'neutral',
#  'dia121utt6': 'neutral',
#  'dia121utt7': 'neutral',
#  ...}

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Assuming that train_embeddings, train_files, and emotions_df are already defined and correctly ordered
# Let's fit the OneHotEncoder to all unique emotions
encoder = OneHotEncoder(sparse=False)
emotions = emotions_df['emotion'].unique().reshape(-1, 1)
encoder.fit(emotions)

# Create a dictionary mapping from dialogue IDs to lists of tuples (utterance_id, embedding, emotion)
dialogues = {}
for filename, embedding in zip(train_files, train_embeddings):
    parts = filename.split('utt')
    dialogue_id = parts[0]
    utterance_id = int(parts[1])
    if dialogue_id not in dialogues:
        dialogues[dialogue_id] = []
    emotion = emotion_dict[filename]
    dialogues[dialogue_id].append((utterance_id, embedding, emotion))

# Adjust the concatenation code
X_train_cause = []

for dialogue, utterances in dialogues.items():
    utterances.sort(key=lambda x: x[0])  # Sort the utterances by ID to ensure i <= j
    for i in range(len(utterances)):
        for j in range(i, len(utterances)):
            embedding_i = utterances[i][1].reshape(1, -1)  # Reshape to a 2D array with 1 row
            embedding_j = utterances[j][1].reshape(1, -1)  # Reshape to a 2D array with 1 row
            utterance_j_key = 'dia' + dialogue.replace('dia', '') + 'utt' + str(utterances[j][0])

            if utterance_j_key in emotion_dict:
                emotion_j = emotion_dict[utterance_j_key]
                # One-hot encode the emotion
                emotion_encoded = encoder.transform([[emotion_j]])
                # Concatenate along axis 1 to place them side by side
                combined_features = np.concatenate((embedding_j, embedding_i, emotion_encoded), axis=1)
                X_train_cause.append(combined_features.flatten())  # Flatten to get a 1D array
            else:
                print(f"Key not found in emotion_dict: {utterance_j_key}")

# Convert the list to a numpy array if necessary
X_train_cause = np.array(X_train_cause)
# Out:
# /project/msoleyma_1026/ecp-cause-pair/ecp-venv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
X_train_cause
# Out:
# array([[-0.02084827, -0.06246319,  0.00747706, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.00999819, -0.0926351 , -0.0242518 , ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.01629469, -0.05975849, -0.00135158, ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [ 0.05378028,  0.01437453, -0.02753302, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.01150594, -0.05341088, -0.01951805, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.05389216, -0.02884472, -0.00816385, ...,  0.        ,
#          0.        ,  1.        ]])

# %%
import json
import pandas as pd
import os

# Helper function to extract the relevant data from JSON
def extract_emotion_cause_data(json_file):
    """ Extracts cause and effect data from the JSON file. """
    with open(json_file, 'r') as file:
        data = json.load(file)
    
    rows = []
    for conversation in data:
        conversation_id = conversation['conversation_ID']
        if 'emotion-cause_pairs' in conversation:
            for pair in conversation['emotion-cause_pairs']:
                effect, cause = pair
                effect_utterance_id = int(effect.split('_')[0])  # Extract utterance ID and convert to int
                cause_utterance_id = int(cause)
                rows.append({
                    'conversation_ID': conversation_id,
                    'cause_utterance_ID': cause_utterance_id,
                    'effect_utterance_ID': effect_utterance_id
                })
    return rows

# Define the directory where CSV files will be saved
output_directory = '/project/msoleyma_1026/ecp-cause-pair/script_mlp/assets'
os.makedirs(output_directory, exist_ok=True)  # Create directory if it does not exist

# Define paths to JSON files
train_json = '/project/msoleyma_1026/ecp-cause-pair/json_files/train.json'
test_json = '/project/msoleyma_1026/ecp-cause-pair/json_files/test.json'

# Extract data
train_data = extract_emotion_cause_data(train_json)
test_data = extract_emotion_cause_data(test_json)

# Convert to pandas DataFrame
train_df = pd.DataFrame(train_data)
test_df = pd.DataFrame(test_data)

# Define paths for the CSV files
train_csv_path = os.path.join(output_directory, 'train_cause.csv')
test_csv_path = os.path.join(output_directory, 'test_cause.csv')
combined_csv_path = os.path.join(output_directory, 'combined_cause.csv')

# Save to CSV
train_df.to_csv(train_csv_path, index=False)
test_df.to_csv(test_csv_path, index=False)

# Combine both dataframes
combined_df = pd.concat([train_df, test_df])
combined_df.to_csv(combined_csv_path, index=False)

print("CSV files created successfully at:", output_directory)
# Out:
# CSV files created successfully at: /project/msoleyma_1026/ecp-cause-pair/script_mlp/assets

# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# Load the CSV file
csv_file_path = '/project/msoleyma_1026/ecp-cause-pair/script_mlp/assets/combined_cause.csv'
emotion_cause_df = pd.read_csv(csv_file_path)

# Convert the DataFrame to a dictionary for faster lookup
emotion_cause_dict = {}
for _, row in emotion_cause_df.iterrows():
    conv_id = 'dia' + str(row['conversation_ID'])
    pair = (row['effect_utterance_ID'], row['cause_utterance_ID'])
    if conv_id not in emotion_cause_dict:
        emotion_cause_dict[conv_id] = []
    emotion_cause_dict[conv_id].append(pair)

print("Emotion-cause pairs dictionary (first 5 entries):", list(emotion_cause_dict.items())[:5])

# Assuming train_embeddings, train_files, and emotions_df are already defined and correctly ordered
encoder = OneHotEncoder(sparse=False)
emotions = emotions_df['emotion'].unique().reshape(-1, 1)
encoder.fit(emotions)

dialogues = {}
for filename, embedding in zip(train_files, train_embeddings):
    parts = filename.split('utt')
    dialogue_id = parts[0]
    utterance_id = int(parts[1])
    if dialogue_id not in dialogues:
        dialogues[dialogue_id] = []
    emotion = emotion_dict[filename]
    dialogues[dialogue_id].append((utterance_id, embedding, emotion))

print("Number of dialogues processed:", len(dialogues))

X_train_cause = []
Y_train_cause = []

for dialogue, utterances in dialogues.items():
    utterances.sort(key=lambda x: x[0])
    for i in range(len(utterances)):
        for j in range(i, len(utterances)):
            embedding_i = utterances[i][1].reshape(1, -1)
            embedding_j = utterances[j][1].reshape(1, -1)
            if (utterances[j][0], utterances[i][0]) in emotion_cause_dict.get(dialogue, []):
                label = 1
            else:
                label = 0
            utterance_j_key = dialogue + 'utt' + str(utterances[j][0])
            if utterance_j_key in emotion_dict:
                emotion_j = emotion_dict[utterance_j_key]
                emotion_encoded = encoder.transform([[emotion_j]])
                combined_features = np.concatenate((embedding_j, embedding_i, emotion_encoded), axis=1)
                X_train_cause.append(combined_features.flatten())
                Y_train_cause.append(label)


X_train_cause = np.array(X_train_cause)
Y_train_cause = np.array(Y_train_cause)

print("Shape of X_train_cause:", X_train_cause.shape)
print("Shape of Y_train_cause:", Y_train_cause.shape)
# Out:
# Emotion-cause pairs dictionary (first 5 entries): [('dia1', [(3, 1), (3, 3), (4, 1), (4, 3), (4, 4), (5, 1), (5, 3), (5, 4)]), ('dia2', [(1, 1), (3, 3)]), ('dia3', [(3, 3), (6, 4), (6, 5), (6, 6), (7, 5), (7, 6), (7, 7), (9, 5), (9, 8), (9, 9)]), ('dia5', [(1, 3), (3, 3)]), ('dia6', [(3, 1), (3, 2), (3, 3), (6, 4), (6, 5), (8, 7)])]
# Number of dialogues processed: 1113
# /project/msoleyma_1026/ecp-cause-pair/ecp-venv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# Shape of X_train_cause: (78200, 5127)
# Shape of Y_train_cause: (78200,)

# %%
X_train_cause
# Out:
# array([[-0.02084827, -0.06246319,  0.00747706, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.00999819, -0.0926351 , -0.0242518 , ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.01629469, -0.05975849, -0.00135158, ...,  0.        ,
#          1.        ,  0.        ],
#        ...,
#        [ 0.05378028,  0.01437453, -0.02753302, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.01150594, -0.05341088, -0.01951805, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.05389216, -0.02884472, -0.00816385, ...,  0.        ,
#          0.        ,  1.        ]])

# %%
# Assuming test_embeddings and test_files are already defined and correctly ordered
# Assuming emotion_model is your trained model for predicting emotions

# Predict emotions for all test utterances
# Flatten the test embeddings if they are not 2D
# Assume test_embeddings is an array of shape (num_samples, sequence_length, num_features)
# We want to flatten the last two dimensions
#test_embeddings_flattened = test_embeddings.reshape(test_embeddings.shape[0], -1)

# Now predict emotions using the flattened embeddings
test_emotions_predicted = mlp.predict(X_test_emotion)


# Create a dictionary mapping test filenames to predicted emotions
test_emotion_dict = {filename: emotion for filename, emotion in zip(test_files, test_emotions_predicted)}

# Initialize X_test_cause and Y_test_cause
X_test_cause = []
Y_test_cause = []

# Process test dialogues similarly to training dialogues
test_dialogues = {}
for filename, embedding in zip(test_files, test_embeddings):
    parts = filename.split('utt')
    dialogue_id = parts[0]
    utterance_id = int(parts[1])
    if dialogue_id not in test_dialogues:
        test_dialogues[dialogue_id] = []
    predicted_emotion = test_emotion_dict[filename]
    test_dialogues[dialogue_id].append((utterance_id, embedding, predicted_emotion))

# Build X_test_cause and Y_test_cause
for dialogue, utterances in test_dialogues.items():
    utterances.sort(key=lambda x: x[0])
    for i in range(len(utterances)):
        for j in range(i, len(utterances)):
            embedding_i = utterances[i][1].reshape(1, -1)
            embedding_j = utterances[j][1].reshape(1, -1)
            label = int((utterances[j][0], utterances[i][0]) in emotion_cause_dict.get(dialogue, []))
            emotion_j = utterances[j][2]
            emotion_encoded = encoder.transform([[emotion_j]])
            combined_features = np.concatenate((embedding_j, embedding_i, emotion_encoded), axis=1)
            X_test_cause.append(combined_features.flatten())
            Y_test_cause.append(label)

X_test_cause = np.array(X_test_cause)
Y_test_cause = np.array(Y_test_cause)

# %%
print("Shape of X_train_cause:", X_test_cause.shape)
print("Shape of Y_train_cause:", Y_test_cause.shape)
# Out:
# Shape of X_train_cause: (18004, 5127)
# Shape of Y_train_cause: (18004,)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, classification_report

# Sample snippet to fit an MLPClassifier on the train and test data

# Initialize the MLPClassifier with one hidden layer of 100 units, and a maximum of 300 iterations
mlp= MLPClassifier(hidden_layer_sizes=(100,), max_iter=300, activation='relu', solver='adam', learning_rate_init=0.001, random_state=42)

# Fit the MLPClassifier to your training data
# Replace X_train_cause and Y_train_cause with your actual training data and labels
mlp.fit(X_train_cause, Y_train_cause)

# After fitting, you can predict the test labels
Y_pred_test = mlp.predict(X_test_cause)

# Then evaluate the performance of the classifier on the test data
test_accuracy = accuracy_score(Y_test_cause, Y_pred_test)
print(f'Test Accuracy: {test_accuracy:.4f}')
# For a detailed classification report
test_report = classification_report(Y_test_cause, Y_pred_test)
print("Test Set Classification Report:")
print(test_report)
test_f1_score = f1_score(Y_test_cause, Y_pred_test, average='weighted')  # Calculate weighted F1 score
print(f'Test F1 Score: {test_f1_score:.4f}')  # Print F1 score

# Emotion-Cause Relationship Accuracy
emotion_cause_accuracy = accuracy_score(Y_test_cause, Y_pred_test)
print(f"Emotion-Cause Relationship Accuracy: {emotion_cause_accuracy:.4f}")
# Out:
# Test Accuracy: 0.8817
# Test Set Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.94      0.93     16211
#            1       0.39      0.34      0.36      1793
#
#     accuracy                           0.88     18004
#    macro avg       0.66      0.64      0.65     18004
# weighted avg       0.87      0.88      0.88     18004
#
# Test F1 Score: 0.8779
# Emotion-Cause Relationship Accuracy: 0.8817

# %%
# Combined Accuracy
combined_accuracy = (emotion_detection_accuracy + emotion_cause_accuracy) / 2
print(f"Combined Accuracy: {combined_accuracy:.4f}")
# Out:
# Combined Accuracy: 0.7135
